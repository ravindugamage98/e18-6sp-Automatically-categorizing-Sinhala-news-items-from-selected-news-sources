# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
data = pd.read_csv('../artifacts/Sinhala_news_articles.csv')

# %%
data.head()
# Out:
#                                                Title          Label
# 0               කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක  International
# 1  ආර්ථික විද්‍යාව පිළිබඳ නොබෙල් ත්‍යාගය ඇමරිකානු...  International
# 2        ඉන්දියාවේ කොරෝනා ආසාදිතයන් 71 ලක්ෂය ඉක්මවයි  International
# 3  කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...  International
# 4                          නේපාල සංචාරක ඇමතිට කොරෝනා  International

# %% [markdown]
# ## Data Preprocessing

# %%
data.shape
# Out:
# (26420, 2)

# %%
data.duplicated().sum()
# Out:
# 796

# %%
data = data.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (25624, 2)

# %%
data.isnull().sum()
# Out:
# Title    0
# Label    0
# dtype: int64

# %%
data.Label.value_counts()
# Out:
# Label
# International    11880
# Sport             8928
# Business          4816
# Name: count, dtype: int64

# %%
data.Label.value_counts().plot.pie(autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Text Preprocessing

# %%
import re
import string

# %%
data["Title"].head(5)
# Out:
# 0                 කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක
# 1    ආර්ථික විද්‍යාව පිළිබඳ නොබෙල් ත්‍යාගය ඇමරිකානු...
# 2          ඉන්දියාවේ කොරෝනා ආසාදිතයන් 71 ලක්ෂය ඉක්මවයි
# 3    කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...
# 4                            නේපාල සංචාරක ඇමතිට කොරෝනා
# Name: Title, dtype: object

# %% [markdown]
# ##### remove links

# %%
data["Title"] = data['Title'].apply(lambda x: " ".join(re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags=re.MULTILINE) for x in x.split()))

# %%
data["Title"].head(20)
# Out:
# 0                  කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක
# 1     ආර්ථික විද්‍යාව පිළිබඳ නොබෙල් ත්‍යාගය ඇමරිකානු...
# 2           ඉන්දියාවේ කොරෝනා ආසාදිතයන් 71 ලක්ෂය ඉක්මවයි
# 3     කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...
# 4                             නේපාල සංචාරක ඇමතිට කොරෝනා
# 5     උතුරු කොරියාව ලොව විශාලතම බැලස්ටික් මිසයිලය ප්...
# 6         තායිලන්තයේ බස් රථ අනතුරකින් විසිදෙනෙකු මියයයි
# 7         බ්‍රසීලයේ කොරෝනා මරණ එක්ලක්ෂ පනස් දහස ඉක්මවයි
# 8                   නොබෙල් සාම ත්‍යාගයට ට්‍රම්ප්ගේ නමත්
# 9     ඉන්දු - චීන දේශසීමාවට චීනය 60^000ක අමතර සෙබළුන...
# 10    රුසියාවෙන් වාර්තා වූ වැඩිම ආසාදිතයින් සංඛ්‍යාව...
# 11      කොරෝනා ප්‍රතිකාර නැවතූ බව^ ජනපති ට්‍රම්ප් කියයි
# 12       දකුණු කොරියාවේ මහල් 33 ක ගොඩනැගිල්ලක් ගිනි ගනී
# 13                 රුපියල^ ඩොලරයට සාපේකෂව ශක්තිමත් වෙයි
# 14    කොවිඩ් වැළඳුණු ට්‍රම්ප්^ බයිඩ්න් සමඟ මුහුණට මු...
# 15                          යුරෝපයේ කොරෝනා පැතිරීම ඉහළට
# 16    ආවරණ මැද කෙරුණු ඇමරිකානු උප ජනපති අපේක්ෂකයන්ගේ...
# 17          ජපානය රටවල් 12 ක විදෙස් ගමන් තහනම ඉවත් කරයි
# 18                         ඉරානය සහ නේපාලය යළි වසා දැමේ
# 19    චීනයේ සතුරු ක්‍රියාමාර්ගවල නිරත වන බවට ඇමරිකාන...
# Name: Title, dtype: object

# %% [markdown]
# ##### Remove punctuations

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

data["Title"] = data["Title"].apply(remove_punctuations)

# %%
data["Title"].head(20)
# Out:
# 0                  කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක
# 1     ආර්ථික විද්‍යාව පිළිබඳ නොබෙල් ත්‍යාගය ඇමරිකානු...
# 2           ඉන්දියාවේ කොරෝනා ආසාදිතයන් 71 ලක්ෂය ඉක්මවයි
# 3     කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...
# 4                             නේපාල සංචාරක ඇමතිට කොරෝනා
# 5     උතුරු කොරියාව ලොව විශාලතම බැලස්ටික් මිසයිලය ප්...
# 6         තායිලන්තයේ බස් රථ අනතුරකින් විසිදෙනෙකු මියයයි
# 7         බ්‍රසීලයේ කොරෝනා මරණ එක්ලක්ෂ පනස් දහස ඉක්මවයි
# 8                   නොබෙල් සාම ත්‍යාගයට ට්‍රම්ප්ගේ නමත්
# 9     ඉන්දු  චීන දේශසීමාවට චීනය 60000ක අමතර සෙබළුන් ...
# 10    රුසියාවෙන් වාර්තා වූ වැඩිම ආසාදිතයින් සංඛ්‍යාව...
# 11       කොරෝනා ප්‍රතිකාර නැවතූ බව ජනපති ට්‍රම්ප් කියයි
# 12       දකුණු කොරියාවේ මහල් 33 ක ගොඩනැගිල්ලක් ගිනි ගනී
# 13                  රුපියල ඩොලරයට සාපේකෂව ශක්තිමත් වෙයි
# 14    කොවිඩ් වැළඳුණු ට්‍රම්ප් බයිඩ්න් සමඟ මුහුණට මුහ...
# 15                          යුරෝපයේ කොරෝනා පැතිරීම ඉහළට
# 16    ආවරණ මැද කෙරුණු ඇමරිකානු උප ජනපති අපේක්ෂකයන්ගේ...
# 17          ජපානය රටවල් 12 ක විදෙස් ගමන් තහනම ඉවත් කරයි
# 18                         ඉරානය සහ නේපාලය යළි වසා දැමේ
# 19    චීනයේ සතුරු ක්‍රියාමාර්ගවල නිරත වන බවට ඇමරිකාන...
# Name: Title, dtype: object

# %% [markdown]
# ##### remove numbers

# %%
data["Title"] = data['Title'].str.replace('\d+', '', regex=True)

# %%
data["Title"].head(20)
# Out:
# 0                  කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක
# 1     ආර්ථික විද්‍යාව පිළිබඳ නොබෙල් ත්‍යාගය ඇමරිකානු...
# 2             ඉන්දියාවේ කොරෝනා ආසාදිතයන්  ලක්ෂය ඉක්මවයි
# 3     කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...
# 4                             නේපාල සංචාරක ඇමතිට කොරෝනා
# 5     උතුරු කොරියාව ලොව විශාලතම බැලස්ටික් මිසයිලය ප්...
# 6         තායිලන්තයේ බස් රථ අනතුරකින් විසිදෙනෙකු මියයයි
# 7         බ්‍රසීලයේ කොරෝනා මරණ එක්ලක්ෂ පනස් දහස ඉක්මවයි
# 8                   නොබෙල් සාම ත්‍යාගයට ට්‍රම්ප්ගේ නමත්
# 9     ඉන්දු  චීන දේශසීමාවට චීනය ක අමතර සෙබළුන් යොදවා...
# 10    රුසියාවෙන් වාර්තා වූ වැඩිම ආසාදිතයින් සංඛ්‍යාව...
# 11       කොරෝනා ප්‍රතිකාර නැවතූ බව ජනපති ට්‍රම්ප් කියයි
# 12         දකුණු කොරියාවේ මහල්  ක ගොඩනැගිල්ලක් ගිනි ගනී
# 13                  රුපියල ඩොලරයට සාපේකෂව ශක්තිමත් වෙයි
# 14    කොවිඩ් වැළඳුණු ට්‍රම්ප් බයිඩ්න් සමඟ මුහුණට මුහ...
# 15                          යුරෝපයේ කොරෝනා පැතිරීම ඉහළට
# 16    ආවරණ මැද කෙරුණු ඇමරිකානු උප ජනපති අපේක්ෂකයන්ගේ...
# 17            ජපානය රටවල්  ක විදෙස් ගමන් තහනම ඉවත් කරයි
# 18                         ඉරානය සහ නේපාලය යළි වසා දැමේ
# 19    චීනයේ සතුරු ක්‍රියාමාර්ගවල නිරත වන බවට ඇමරිකාන...
# Name: Title, dtype: object

# %% [markdown]
# ##### remove stopwords

# %%
#!pip install nltk

# %%
import nltk

# %%
nltk.download('stopwords', download_dir='../static/model')
# Out:
# [nltk_data] Downloading package stopwords to ../static/model...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
with open('../static/model/corpora/stopwords/sinhala', 'r', encoding='utf-8') as file:
    sw = file.read().splitlines()

# %%
sw
# Out:
# ['සහ',
#  'සමග',
#  'සමඟ',
#  'අහා',
#  'ආහ්',
#  'ආ',
#  'ඕහෝ',
#  'අනේ',
#  'අඳෝ',
#  'අපොයි',
#  'අපෝ',
#  'අයියෝ',
#  'ආයි',
#  'ඌයි',
#  'චී',
#  'චිහ්',
#  'චික්',
#  'හෝ\u200d',
#  'දෝ',
#  'දෝහෝ',
#  'මෙන්',
#  'සේ',
#  'වැනි',
#  'බඳු',
#  'වන්',
#  'අයුරු',
#  'අයුරින්',
#  'ලෙස',
#  'වැඩි',
#  'ශ්\u200dරී',
#  'හා',
#  'ය',
#  'නිසා',
#  'නිසාවෙන්',
#  'බවට',
#  'බව',
#  'බවෙන්',
#  'නම්',
#  'වැඩි',
#  'සිට',
#  'දී',
#  'මහා',
#  'මහ',
#  'පමණ',
#  'පමණින්',
#  'පමන',
#  'වන',
#  'විට',
#  'විටින්',
#  'මේ',
#  'මෙලෙස',
#  'මෙයින්',
#  'ඇති',
#  'ලෙස',
#  'සිදු',
#  'වශයෙන්',
#  'යන',
#  'සඳහා',
#  'මගින්',
#  'හෝ\u200d',
#  'ඉතා',
#  'ඒ',
#  'එම',
#  'ද',
#  'අතර',
#  'විසින්',
#  'සමග',
#  'පිළිබඳව',
#  'පිළිබඳ',
#  'තුළ',
#  'බව',
#  'වැනි',
#  'මහ',
#  'මෙම',
#  'මෙහි',
#  'මේ',
#  'වෙත',
#  'වෙතින්',
#  'වෙතට',
#  'වෙනුවෙන්',
#  'වෙනුවට',
#  'වෙන',
#  'ගැන',
#  'නෑ',
#  'අනුව',
#  'නව',
#  'පිළිබඳ',
#  'විශේෂ',
#  'දැනට',
#  'එහෙන්',
#  'මෙහෙන්',
#  'එහේ',
#  'මෙහේ',
#  'ම',
#  'තවත්',
#  'තව ',
#  'සහ',
#  'දක්වා',
#  'ට',
#  'ගේ',
#  'එ',
#  'ක',
#  'ක්',
#  'බවත්',
#  'බවද',
#  'මත',
#  'ඇතුලු',
#  'ඇතුළු',
#  'මෙසේ',
#  'වඩා',
#  'වඩාත්ම',
#  'නිති',
#  'නිතිත්',
#  'නිතොර',
#  'නිතර',
#  'ඉක්බිති',
#  'දැන්',
#  'යලි',
#  'පුන',
#  'ඉතින්',
#  'සිට',
#  'සිටන්',
#  'පටන්',
#  'තෙක්',
#  'දක්වා',
#  'සා',
#  'තාක්',
#  'තුවක්',
#  'පවා',
#  'ද',
#  'හෝ\u200d',
#  'වත්',
#  'විනා',
#  'හැර',
#  'මිස',
#  'මුත්',
#  'කිම',
#  'කිම්',
#  'ඇයි',
#  'මන්ද',
#  'හෙවත්',
#  'නොහොත්',
#  'පතා',
#  'පාසා',
#  'ගානෙ',
#  'තව',
#  'ඉතා',
#  'බොහෝ',
#  'වහා',
#  'සෙද',
#  'සැනින්',
#  'හනික',
#  'එම්බා',
#  'එම්බල',
#  'බොල',
#  'නම්',
#  'වනාහි',
#  'කලී',
#  'ඉඳුරා',
#  'අන්න',
#  'ඔන්න',
#  'මෙන්න',
#  'උදෙසා',
#  'පිණිස',
#  'සඳහා',
#  'අරබයා',
#  'නිසා',
#  'එනිසා',
#  'එබැවින්',
#  'බැවින්',
#  'හෙයින්',
#  'සේක්',
#  'සේක',
#  'ගැන',
#  'අනුව',
#  'පරිදි',
#  'විට',
#  'තෙක්',
#  'මෙතෙක්',
#  'මේතාක්',
#  'තුරු',
#  'තුරා',
#  'තුරාවට',
#  'තුලින්',
#  'නමුත්',
#  'එනමුත්',
#  'වස්',
#  'මෙන්',
#  'ලෙස',
#  'පරිදි',
#  'එහෙත්']

# %%
data["Title"].head(20)
# Out:
# 0                  කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක
# 1     ආර්ථික විද්‍යාව පිළිබඳ නොබෙල් ත්‍යාගය ඇමරිකානු...
# 2             ඉන්දියාවේ කොරෝනා ආසාදිතයන්  ලක්ෂය ඉක්මවයි
# 3     කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...
# 4                             නේපාල සංචාරක ඇමතිට කොරෝනා
# 5     උතුරු කොරියාව ලොව විශාලතම බැලස්ටික් මිසයිලය ප්...
# 6         තායිලන්තයේ බස් රථ අනතුරකින් විසිදෙනෙකු මියයයි
# 7         බ්‍රසීලයේ කොරෝනා මරණ එක්ලක්ෂ පනස් දහස ඉක්මවයි
# 8                   නොබෙල් සාම ත්‍යාගයට ට්‍රම්ප්ගේ නමත්
# 9     ඉන්දු  චීන දේශසීමාවට චීනය ක අමතර සෙබළුන් යොදවා...
# 10    රුසියාවෙන් වාර්තා වූ වැඩිම ආසාදිතයින් සංඛ්‍යාව...
# 11       කොරෝනා ප්‍රතිකාර නැවතූ බව ජනපති ට්‍රම්ප් කියයි
# 12         දකුණු කොරියාවේ මහල්  ක ගොඩනැගිල්ලක් ගිනි ගනී
# 13                  රුපියල ඩොලරයට සාපේකෂව ශක්තිමත් වෙයි
# 14    කොවිඩ් වැළඳුණු ට්‍රම්ප් බයිඩ්න් සමඟ මුහුණට මුහ...
# 15                          යුරෝපයේ කොරෝනා පැතිරීම ඉහළට
# 16    ආවරණ මැද කෙරුණු ඇමරිකානු උප ජනපති අපේක්ෂකයන්ගේ...
# 17            ජපානය රටවල්  ක විදෙස් ගමන් තහනම ඉවත් කරයි
# 18                         ඉරානය සහ නේපාලය යළි වසා දැමේ
# 19    චීනයේ සතුරු ක්‍රියාමාර්ගවල නිරත වන බවට ඇමරිකාන...
# Name: Title, dtype: object

# %%
data["Title"] = data["Title"].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

# %%
data["Title"].head(20)
# Out:
# 0                  කොරෝනා වැලඳුණු ට්‍රම්ප් අද ජන රැලියක
# 1     ආර්ථික විද්‍යාව නොබෙල් ත්‍යාගය ඇමරිකානුවන් දෙද...
# 2              ඉන්දියාවේ කොරෝනා ආසාදිතයන් ලක්ෂය ඉක්මවයි
# 3     කළු ජාතිකයෙකු ඩොලර් මිලියනයක වන්දි ඉල්ලා ටෙක්ස...
# 4                             නේපාල සංචාරක ඇමතිට කොරෝනා
# 5     උතුරු කොරියාව ලොව විශාලතම බැලස්ටික් මිසයිලය ප්...
# 6         තායිලන්තයේ බස් රථ අනතුරකින් විසිදෙනෙකු මියයයි
# 7         බ්‍රසීලයේ කොරෝනා මරණ එක්ලක්ෂ පනස් දහස ඉක්මවයි
# 8                   නොබෙල් සාම ත්‍යාගයට ට්‍රම්ප්ගේ නමත්
# 9     ඉන්දු චීන දේශසීමාවට චීනය අමතර සෙබළුන් යොදවා චෝදනා
# 10    රුසියාවෙන් වාර්තා වූ වැඩිම ආසාදිතයින් සංඛ්‍යාව...
# 11          කොරෝනා ප්‍රතිකාර නැවතූ ජනපති ට්‍රම්ප් කියයි
# 12            දකුණු කොරියාවේ මහල් ගොඩනැගිල්ලක් ගිනි ගනී
# 13                  රුපියල ඩොලරයට සාපේකෂව ශක්තිමත් වෙයි
# 14    කොවිඩ් වැළඳුණු ට්‍රම්ප් බයිඩ්න් මුහුණට මුහුණ ව...
# 15                          යුරෝපයේ කොරෝනා පැතිරීම ඉහළට
# 16    ආවරණ මැද කෙරුණු ඇමරිකානු උප ජනපති අපේක්ෂකයන්ගේ...
# 17               ජපානය රටවල් විදෙස් ගමන් තහනම ඉවත් කරයි
# 18                            ඉරානය නේපාලය යළි වසා දැමේ
# 19    චීනයේ සතුරු ක්‍රියාමාර්ගවල නිරත ඇමරිකානු රාජ්‍...
# Name: Title, dtype: object

# %% [markdown]
# #### Stemming

# %%
with open('../static/model/stem_dictionary.txt', 'r', encoding='utf-8') as file:
    sd = file.read().splitlines()

# %%
sd
# Out:
# ['අංකද\tඅංක',
#  'අංකය\tඅංක',
#  'අංකයක්\tඅංක',
#  'අංකයට\tඅංක',
#  'අංකයටද\tඅංක',
#  'අංකයන්ට\tඅංක',
#  'අංකයන්ටද\tඅංක',
#  'අංකවල\tඅංක',
#  'අංකවලට\tඅංක',
#  'අංකවලින්\tඅංක',
#  'අංගණයට\tඅංගණය',
#  'අංගණයේ\tඅංගණය',
#  'අංගනය\tඅංගන',
#  'අංගනයක\tඅංගන',
#  'අංගනයක්\tඅංගන',
#  'අංගයක්\tඅංගය',
#  'අංගවලින්\tඅංගවල',
#  'අංගොඩට\tඅංගොඩ',
#  'අංගෝපාංගයන්\tඅංගෝපාංග',
#  'අංශභාගය\tඅංශභාග',
#  'අංශයකට\tඅංශය',
#  'අංශයකම\tඅංශය',
#  'අංශයක්\tඅංශය',
#  'අංශයකින්\tඅංශය',
#  'අංශයකින්ම\tඅංශය',
#  'අංශයට\tඅංශය',
#  'අංශයටත්\tඅංශය',
#  'අංශයටද\tඅංශය',
#  'අංශයන්\tඅංශය',
#  'අංශයන්ගෙන්\tඅංශය',
#  'අංශයන්ගේ\tඅංශය',
#  'අංශයන්හි\tඅංශය',
#  'අංශයෙන්\tඅංශය',
#  'අංශයෙන්ද\tඅංශය',
#  'අංශවලට\tඅංශවල',
#  'අංශවලින්\tඅංශවල',
#  'අකටයුත්තකට\tඅකටයුත්ත',
#  'අකටයුත්තක්\tඅකටයුත්ත',
#  'අකටයුතුකම්වලට\tඅකටයුතුකම්',
#  'අකටයුතුකම්වලින්\tඅකටයුතුකම්',
#  'අකණ්ඩව\tඅකණ්ඩ',
#  'අකමැත්තක්\tඅකමැත්ත',
#  'අකමැත්තකින්\tඅකමැත්ත',
#  'අකමැත්තද\tඅකමැත්ත',
#  'අකමැත්තෙන්\tඅකමැත්ත',
#  'අකමැතිවී\tඅකමැතිව',
#  'අකමැතිවීම\tඅකමැතිව',
#  'අකමැතිවූ\tඅකමැතිව',
#  'අකරතැබ්බය\tඅකරතැබ්බ',
#  'අකර්මණ්යය\tඅකර්මණ්ය',
#  'අකලංකගේ\tඅකලංක',
#  'අක්කගේ\tඅක්ක',
#  'අක්කයි\tඅක්ක',
#  'අක්කරක්\tඅක්කර',
#  'අක්කරපත්තුව\tඅක්කරපත්තු',
#  'අක්කරපත්තුවේ\tඅක්කරපත්තු',
#  'අක්කරයකට\tඅක්කරයක',
#  'අක්කරයක්\tඅක්කරයක',
#  'අක්කරෙයිපත්තුව\tඅක්කරෙයිපත්තු',
#  'අක්කරෙයිපත්තුවට\tඅක්කරෙයිපත්තු',
#  'අක්කරෙයිපත්තුවේ\tඅක්කරෙයිපත්තු',
#  'අක්කරේපත්තුව\tඅක්කරේපත්තු',
#  'අක්කරේපත්තුවේ\tඅක්කරේපත්තු',
#  'අක්කලාගේ\tඅක්කලා',
#  'අක්කාට\tඅක්කා',
#  'අක්කාව\tඅක්කා',
#  'අක්තපත්රය\tඅක්තපත්ර',
#  'අක්තාර්ට\tඅක්තාර්',
#  'අක්මාල්ගේ\tඅක්මාල්',
#  'අක්මාල්ට\tඅක්මාල්',
#  'අක්මාල්ද\tඅක්මාල්',
#  'අක්රමවත්ව\tඅක්රමවත්',
#  'අක්රම්ට\tඅක්රම්',
#  'අක්රමිකතාවක්\tඅක්රමිකතා',
#  'අක්රමිකතාවන්ගෙන්\tඅක්රමිකතාවන්',
#  'අක්රමිකතාවන්ට\tඅක්රමිකතාවන්',
#  'අක්රමිකතාවයක්\tඅක්රමිකතාවය',
#  'අක්රමිකතාවයන්\tඅක්රමිකතාවය',
#  'අක්රමිකතාවයෙන්\tඅක්රමිකතාවය',
#  'අක්රියවී\tඅක්රියව',
#  'අක්රියවීම\tඅක්රියව',
#  'අක්රීයයි\tඅක්රීය',
#  'අක්රීයව\tඅක්රීය',
#  'අක්ෂරයෙන්\tඅක්ෂර',
#  'අක්ෂරා\tඅක්ෂර',
#  'අක්ෂේගේ\tඅක්ෂේ',
#  'අකාරයටම\tඅකාරයට',
#  'අකාරයෙන්ම\tඅකාරයෙන්',
#  'අකාර්යක්ෂමතාව\tඅකාර්යක්ෂමතා',
#  'අකාර්යක්ෂමතාවයෙන්\tඅකාර්යක්ෂමතාවය',
#  'අකැමැත්තෙන්\tඅකැමැත්ත',
#  'අකියාවලින්\tඅකියා',
#  'අකිලගෙන්\tඅකිල',
#  'අකිලගේ\tඅකිල',
#  'අකිලට\tඅකිල',
#  'අකිලා\tඅකිල',
#  'අකිලීමේ\tඅකිල',
#  'අකුණුද\tඅකුණු',
#  'අකුරක්\tඅකුර',
#  'අකුරටම\tඅකුරට',
#  'අකුරැස්සට\tඅකුරැස්ස',
#  'අකුරැස්සම\tඅකුරැස්ස',
#  'අකුරැස්සේ\tඅකුරැස්ස',
#  'අකුලක්\tඅකුල',
#  'අඛණ්ඩතාවය\tඅඛණ්ඩතාව',
#  'අඛණ්ඩතාවයට\tඅඛණ්ඩතාව',
#  'අඛණ්ඩවම\tඅඛණ්ඩව',
#  'අඛන්ඩව\tඅඛන්ඩ',
#  'අගට\tඅග',
#  'අගටම\tඅග',
#  'අගතියක්\tඅගතිය',
#  'අගතියට\tඅගතිය',
#  'අගනගරයේ\tඅගනගරය',
#  'අගනාම\tඅගනා',
#  'අගනුවරක්\tඅගනුවර',
#  'අගනුවරට\tඅගනුවර',
#  'අගභාගයේ\tඅගභාගය',
#  'අගමැතිකම\tඅගමැති',
#  'අගමැතිට\tඅගමැති',
#  'අගමැතිටත්\tඅගමැති',
#  'අගමැතිටයි\tඅගමැති',
#  'අගමැතිණිය\tඅගමැති',
#  'අගමැතිණියටත්\tඅගමැති',
#  'අගමැතිතුමන්\tඅගමැති',
#  'අගමැතිතුමන්ගෙන්\tඅගමැති',
#  'අගමැතිතුමන්ගේ\tඅගමැති',
#  'අගමැතිතුමන්ද\tඅගමැති',
#  'අගමැතිතුමා\tඅගමැති',
#  'අගමැතිතුමාගෙ\tඅගමැති',
#  'අගමැතිතුමාගෙන්\tඅගමැති',
#  'අගමැතිතුමාගේ\tඅගමැති',
#  'අගමැතිතුමාට\tඅගමැති',
#  'අගමැතිතුමාටත්\tඅගමැති',
#  'අගමැතිනි\tඅගමැති',
#  'අගමැතිනිගේ\tඅගමැති',
#  'අගමැතිනිය\tඅගමැති',
#  'අගමැතිනියගේ\tඅගමැති',
#  'අගමැතිවරයාගේ\tඅගමැති',
#  'අගමැතිවරයාගේත්\tඅගමැති',
#  'අගමැතිවරු\tඅගමැති',
#  'අගමැතිවරුන්\tඅගමැති',
#  'අගමැතිවරුන්ට\tඅගමැති',
#  'අගයකට\tඅගයක',
#  'අගයනවා\tඅගයන',
#  'අගයන්\tඅගයන',
#  'අගරදගුරුගෙන්\tඅගරදගුරු',
#  'අගරදගුරුගේ\tඅගරදගුරු',
#  'අගරදගුරුතුමන්ගෙන්\tඅගරදගුරුතුමන්',
#  'අගරදගුරුතුමන්ට\tඅගරදගුරුතුමන්',
#  'අගලක්ම\tඅගලක්',
#  'අගලක්වත්\tඅගලක්',
#  'අගලවත්තේ\tඅගලවත්ත',
#  'අගවිනිසුරුගේ\tඅගවිනිසුරු',
#  'අගවිනිසුරුට\tඅගවිනිසුරු',
#  'අගහිගකම්වලින්\tඅගහිගකම්',
#  'අගහිඟකම්වලට\tඅගහිඟකම්',
#  'අග්ගලා\tඅග්ගල',
#  'අග්රමාත්යවරයාගෙන්\tඅග්රමාත්යවරයා',
#  'අග්රමාත්යවරයාගේ\tඅග්රමාත්යවරයා',
#  'අග්රමාත්යවරයාට\tඅග්රමාත්යවරයා',
#  'අග්රමාත්යවරයාව\tඅග්රමාත්යවරයා',
#  'අග්රාමාත්ය\tඅග්රාමාත්',
#  'අග්රාමාත්යවරයාගෙන්\tඅග්රාමාත්යවරයා',
#  'අග්රාමාත්යවරායාගේ\tඅග්රාමාත්යවරා',
#  'අග්රාමාත්යවරියගෙන්\tඅග්රාමාත්යවරිය',
#  'අග්රාමාත්යවරියට\tඅග්රාමාත්යවරිය',
#  'අග්රාමාත්යවරුන්\tඅග්රාමාත්යවරු',
#  'අගාඩ්ගේ\tඅගාඩ්',
#  'අගුණකොලපැලැස්සේ\tඅගුණකොලපැලැස්ස',
#  'අගුණකොළපැලැස්සේ\tඅගුණකොළපැලැස්ස',
#  'අගුණුකොලපැලැස්සේ\tඅගුණුකොලපැලැස්ස',
#  'අගුණුකොළපැලැස්සේ\tඅගුණුකොළපැලැස්ස',
#  'අගුනුකොළපැලැස්සේ\tඅගුනුකොළපැලැස්ස',
#  'අගුලක්\tඅගුල',
#  'අගුල්\tඅගුල',
#  'අගෝස්තුවෙන්\tඅගෝස්තු',
#  'අගෝස්තුවේ\tඅගෝස්තු',
#  'අගෞරවය\tඅගෞරව',
#  'අගෞරවයක්\tඅගෞරව',
#  'අඟලක්ම\tඅඟලක්',
#  'අඟලක්වත්\tඅඟලක්',
#  'අඟවනවා\tඅඟවන',
#  'අඟහරුගේ\tඅඟහරු',
#  'අඟහරුවාදායි\tඅඟහරුවාදා',
#  'අඟුණුකොලපැලැස්සේ\tඅඟුණුකොලපැලැස්ස',
#  'අඟුරුවලට\tඅඟුරු',
#  'අඟුලානේ\tඅඟුලාන',
#  'අචලාගෙන්\tඅචලා',
#  'අචලාට\tඅචලා',
#  'අච්චිලාගේ\tඅච්චි',
#  'අචාර්යවරුන්\tඅචාර්ය',
#  'අජන්තගෙන්\tඅජන්ත',
#  'අජන්තන්\tඅජන්ත',
#  'අජන්තා\tඅජන්ත',
#  'අජිත්ගේ\tඅජිත්',
#  'අටකට\tඅටක',
#  'අටක්ද\tඅටක්',
#  'අටටම\tඅටට',
#  'අටදහසකට\tඅටදහසක',
#  'අටදහසක්\tඅටදහසක',
#  'අටදෙනාගේ\tඅටදෙනා',
#  'අටදෙනෙකුගෙන්\tඅටදෙනෙකු',
#  'අටදෙනෙකුගේ\tඅටදෙනෙකු',
#  'අටදෙනෙකුට\tඅටදෙනෙකු',
#  'අටදෙනෙකුද\tඅටදෙනෙකු',
#  'අටමස්ථානයට\tඅටමස්ථානය',
#  'අටලක්ෂයක\tඅටලක්ෂ',
#  'අටලක්ෂයකට\tඅටලක්ෂ',
#  'අටසියක්\tඅටසියක',
#  'අටසියයකට\tඅටසියයක',
#  'අට්ටාලය\tඅට්ටාල',
#  'අට්ටාලයක\tඅට්ටාල',
#  'අට්ටාලයකට\tඅට්ටාල',
#  'අට්ටාලයක්\tඅට්ටාල',
#  'අට්ටාලවලට\tඅට්ටාලවල',
#  'අඩංගුයි\tඅඩංගු',
#  'අඩංගුවට\tඅඩංගුව',
#  'අඩංගුවන\tඅඩංගුව',
#  'අඩංගුවීම\tඅඩංගුව',
#  'අඩංගුවේ\tඅඩංගුව',
#  'අඩකට\tඅඩක',
#  'අඩකටත්\tඅඩක',
#  'අඩක්\tඅඩක',
#  'අඩපණයි\tඅඩපණ',
#  'අඩවියකට\tඅඩවියක',
#  'අඩවියක්\tඅඩවියක',
#  'අඩවියකින්\tඅඩවියක',
#  'අඩවියෙන්ද\tඅඩවියෙන්',
#  'අඩවියෙහිද\tඅඩවියෙහි',
#  'අඩවියේම\tඅඩවියේ',
#  'අඩවිවලට\tඅඩවිවල',
#  'අඩවිවලින්\tඅඩවිවල',
#  'අඩාලයි\tඅඩාල',
#  'අඩාලව\tඅඩාල',
#  'අඩාලවීමක්ද\tඅඩාලවීමක්',
#  'අඩිතාලමක්\tඅඩිතාලම',
#  'අඩිතාලමයි\tඅඩිතාලම',
#  'අඩිතාලම්\tඅඩිතාලම',
#  'අඩිපාරේම\tඅඩිපාරේ',
#  'අඩියක්\tඅඩියක',
#  'අඩුකරලා\tඅඩුකරල',
#  'අඩුකිරීමක්\tඅඩුකිරීම',
#  'අඩුකිරීමට\tඅඩුකිරීම',
#  'අඩුකිරීමටත්\tඅඩුකිරීම',
#  'අඩුකිරීමත්\tඅඩුකිරීම',
#  'අඩුකිරීම්\tඅඩුකිරීම',
#  'අඩුකිරීමේ\tඅඩුකිරීම',
#  'අඩුපාඩුවකට\tඅඩුපාඩුව',
#  'අඩුපාඩුවක්\tඅඩුපාඩුව',
#  'අඩුවක්\tඅඩුව',
#  'අඩුවිමක්\tඅඩුවිම',
#  'අඩුවිමට\tඅඩුවිම',
#  'අඩුවියන්\tඅඩුවිය',
#  'අඩුවීමක්\tඅඩුවීම',
#  'අඩුවුවත්\tඅඩුවුව',
#  'අඩුවුවද\tඅඩුවුව',
#  'අඩුවූයේ\tඅඩුවූ',
#  'අඩුවූවත්\tඅඩුවූ',
#  'අඩුවෙනවා\tඅඩුවෙන',
#  'අඩුවෙන්\tඅඩුවෙන',
#  'අඩුවෙනුත්\tඅඩුවෙනු',
#  'අණකට\tඅණ',
#  'අණදීමක්\tඅණද',
#  'අණදුන්\tඅණද',
#  'අණපනත්වල\tඅණපනත්',
#  'අණපනත්වලට\tඅණපනත්',
#  'අණ්ඩුවෙන්\tඅණ්ඩුව',
#  'අණ්ඩුවේ\tඅණ්ඩුව',
#  'අණාවරණය\tඅණාවරණ',
#  'අණාවරණයන්\tඅණාවරණ',
#  'අණාවරනය\tඅණාවරන',
#  'අඬකටත්\tඅඬක',
#  'අඬාල\tඅඬා',
#  'අතකට\tඅතක',
#  'අතක්\tඅතක',
#  'අතකින්\tඅතක',
#  'අතකොලූවක්\tඅතකොලූ',
#  'අතකොළුවක්\tඅතකොළු',
#  'අතගාන\tඅතගා',
#  'අතගාන්න\tඅතගා',
#  'අතගාමින්\tඅතගා',
#  'අතදීමක්\tඅතදී',
#  'අතදීමට\tඅතදී',
#  'අතපත්තුගෙන්\tඅතපත්තු',
#  'අතපත්තුගේ\tඅතපත්තු',
#  'අතපත්තුට\tඅතපත්තු',
#  'අතපත්තුයි\tඅතපත්තු',
#  'අතපසුවීම\tඅතපසුවී',
#  'අතපසුවීමක්\tඅතපසුවී',
#  'අතපසුවීමකින්\tඅතපසුවී',
#  'අතපසුවීම්\tඅතපසුවී',
#  'අතපෙවීම්වලින්\tඅතපෙවීම්',
#  'අතමිටේ\tඅතමිට',
#  'අතරටද\tඅතරට',
#  'අතරතුරදියි\tඅතරතුරදි',
#  'අතරතුරදීද\tඅතරතුරදී',
#  'අතරතුරදීය\tඅතරතුරදී',
#  'අතරතුරදීයි\tඅතරතුරදී',
#  'අතරමංවන්නට\tඅතරමංව',
#  'අතරමංවු\tඅතරමංව',
#  'අතරමංවූ\tඅතරමංව',
#  'අතරමගට\tඅතරමග',
#  'අතරමන්ව\tඅතරමන්',
#  'අතරමැදියන්\tඅතරමැදි',
#  'අතරමැදියන්ගෙන්\tඅතරමැදි',
#  'අතරමැදියන්ගේ\tඅතරමැදි',
#  'අතරමැදියන්ට\tඅතරමැදි',
#  'අතරමැදියා\tඅතරමැදි',
#  'අතරමැදියෙකු\tඅතරමැදි',
#  'අතරමැදියෙකුගේ\tඅතරමැදි',
#  'අතරයිතරඟය\tඅතරයිතරඟ',
#  'අතරවරයන්\tඅතරවර',
#  'අතරවරයන්ට\tඅතරවර',
#  'අතරවාරයේදීය\tඅතරවාරයේදී',
#  'අතරුදන්ව\tඅතරුදන්',
#  'අතවරය\tඅතවර',
#  'අතවරයකට\tඅතවර',
#  'අතවරයක්\tඅතවර',
#  'අතවරයට\tඅතවර',
#  'අතවරයන්\tඅතවර',
#  'අතවරයන්ට\tඅතවර',
#  'අතහරින\tඅතහරි',
#  'අතහරිනවා\tඅතහරි',
#  'අතහරින්න\tඅතහරි',
#  'අතහරින්නට\tඅතහරි',
#  'අතහැරලා\tඅතහැරල',
#  'අතහැරිය\tඅතහැරි',
#  'අතහැරියා\tඅතහැරි',
#  'අතහැරියේ\tඅතහැරි',
#  'අතහැරීමට\tඅතහැරීම',
#  'අතහැරීමෙන්\tඅතහැරීම',
#  'අත්අඩංගුවට\tඅත්අඩංගුව',
#  'අත්කරගත්\tඅත්කරගත',
#  'අත්කරගැනීමට\tඅත්කරගැනීම',
#  'අත්කරගැනීමෙන්\tඅත්කරගැනීම',
#  'අත්කරදෙනු\tඅත්කරදෙන',
#  'අත්තකට\tඅත්තක',
#  'අත්තක්\tඅත්තක',
#  'අත්තනායකගේ\tඅත්තනායක',
#  'අත්තනායකට\tඅත්තනායක',
#  'අත්තනෝමතිකව\tඅත්තනෝමතික',
#  'අත්තම්මාගේ\tඅත්තම්මා',
#  'අත්තම්මාට\tඅත්තම්මා',
#  'අත්තිඩියෙ\tඅත්තිඩිය',
#  'අත්තිඩියේ\tඅත්තිඩිය',
#  'අත්තිවාරම්\tඅත්තිවාරම',
#  'අත්තිවාරමෙන්\tඅත්තිවාරම',
#  'අත්දැකීමකට\tඅත්දැකීමක',
#  'අත්දැකීමක්\tඅත්දැකීමක',
#  'අත්දැකීම්වලට\tඅත්දැකීම්',
#  'අත්පත්කරගැනීම්\tඅත්පත්කරගැනීම',
#  'අත්පත්රිකාව\tඅත්පත්රිකා',
#  'අත්පත්රිකාවක්\tඅත්පත්රිකා',
#  'අත්පත්රිකාවකින්\tඅත්පත්රිකා',
#  'අත්පත්රිකාවට\tඅත්පත්රිකා',
#  'අත්පත්රිකාවේ\tඅත්පත්රිකා',
#  'අත්පාවලට\tඅත්පා',
#  'අත්පොතක්\tඅත්පොත',
#  'අත්පොතද\tඅත්පොත',
#  'අත්බෝම්බයක්\tඅත්බෝම්බය',
#  'අත්යාවශ්යම\tඅත්යාවශ්ය',
#  'අත්යාවශ්යය\tඅත්යාවශ්ය',
#  'අත්යාවශ්යයි\tඅත්යාවශ්ය',
#  'අත්යාවශ්යව\tඅත්යාවශ්ය',
#  'අත්ලාන්තික්\tඅත්ලාන්තික',
#  'අත්වන\tඅත්ව',
#  'අත්වන්නට\tඅත්ව',
#  'අත්වන්නේ\tඅත්ව',
#  'අත්වනු\tඅත්ව',
#  'අත්වයේ\tඅත්ව',
#  'අත්වල\tඅත්ව',
#  'අත්වැරැද්දක්\tඅත්වැරැද්ද',
#  'අත්වැරැද්දකින්\tඅත්වැරැද්ද',
#  'අත්වැලක්\tඅත්වැල',
#  'අත්වැල්\tඅත්වැල',
#  'අත්විඳින\tඅත්විඳි',
#  'අත්විඳිනවා\tඅත්විඳි',
#  'අත්විඳින්න\tඅත්විඳි',
#  'අත්වීමට\tඅත්වී',
#  'අත්වූයේ\tඅත්වූ',
#  'අත්වෙන්නේ\tඅත්වෙන්න',
#  'අත්වේද\tඅත්වේ',
#  'අත්වේවා\tඅත්වේ',
#  'අත්සනක්\tඅත්සන',
#  'අත්සනට\tඅත්සන',
#  'අත්සනත්\tඅත්සන',
#  'අත්සනද\tඅත්සන',
#  'අත්සන්\tඅත්සන',
#  'අත්හදාබැලීමක්\tඅත්හදාබැලීමක',
#  'අත්හදාබැලීම්වලට\tඅත්හදාබැලීම්',
#  'අත්හදාබැලූනු\tඅත්හදාබැලූ',
#  'අත්හරිනවා\tඅත්හරින',
#  'අත්හරින්නට\tඅත්හරින්න',
#  'අත්හරීමට\tඅත්හරී',
#  'අත්හැරියා\tඅත්හැරිය',
#  'අත්හැරීමට\tඅත්හැරීම',
#  'අත්හැරීමත්\tඅත්හැරීම',
#  'අත්හිටවුූ\tඅත්හිටවු',
#  'අත්හිටවූයේ\tඅත්හිටවූ',
#  'අත්හිටවූවද\tඅත්හිටවූ',
#  'අත්හිටවූවා\tඅත්හිටවූ',
#  'අත්හිටුවනවා\tඅත්හිටුවන',
#  'අත්හිටුවීමට\tඅත්හිටුවීම',
#  'අත්හිටුවීමටත්\tඅත්හිටුවීම',
#  'අත්හිටුවුවා\tඅත්හිටුවුව',
#  'අතැතිවයි\tඅතැතිව',
#  'අතින්ද\tඅතින්',
#  'අතින්ම\tඅතින්',
#  'අතිරික්තය\tඅතිරික්ත',
#  'අතිරික්තයක්\tඅතිරික්ත',
#  'අතිරික්තව\tඅතිරික්ත',
#  'අතිරිත්තය\tඅතිරිත්ත',
#  'අතිරිත්තයක්\tඅතිරිත්ත',
#  'අතිශයින්\tඅතිශය',
#  'අතිසාර්ථකව\tඅතිසාර්ථක',
#  'අතීතය\tඅතීත',
#  'අතීතයක\tඅතීත',
#  'අතීතයකට\tඅතීත',
#  'අතීතයක්\tඅතීත',
#  'අතීතයට\tඅතීත',
#  'අතීතයේද\tඅතීතයේ',
#  'අතීසාරයට\tඅතීසාරය',
#  'අතුකෝරලගේ\tඅතුකෝරල',
#  'අතුකෝරලට\tඅතුකෝරල',
#  'අතුකෝරළගේ\tඅතුකෝරළ',
#  'අතුකෝරළට\tඅතුකෝරළ',
#  'අතුකෝරාළගෙන්\tඅතුකෝරාළ',
#  'අතුගාන්න\tඅතුගා',
#  'අතුරතුරදීය\tඅතුරතුරදී',
#  'අතුරලියේ\tඅතුරලිය',
#  'අතුරුගිරියේ\tඅතුරුගිරිය',
#  'අතුරුදන්වන\tඅතුරුදන්ව',
#  'අතුරුදන්වයි\tඅතුරුදන්ව',
#  'අතුරුදන්වී\tඅතුරුදන්ව',
#  'අතුරුදන්වීම\tඅතුරුදන්ව',
#  'අතුරුදන්වීමක්\tඅතුරුදන්ව',
#  'අතුරුදන්වීමට\tඅතුරුදන්ව',
#  'අතුරුදන්වුයේ\tඅතුරුදන්වු',
#  'අතුරුදන්වුවන්\tඅතුරුදන්වු',
#  'අතුරුදන්වුවන්ගේ\tඅතුරුදන්වු',
#  'අතුරුදන්වූන්ගේ\tඅතුරුදන්වූ',
#  'අතුරුදන්වූවන්\tඅතුරුදන්වූ',
#  'අතුරුදන්වූවන්ගේ\tඅතුරුදන්වූ',
#  'අතුරුදහන්ව\tඅතුරුදහන්',
#  'අතුරුදහන්වීම\tඅතුරුදහන්වී',
#  'අතුරුදහන්වූවන්\tඅතුරුදහන්වූ',
#  'අතුරුදහන්වූවන්ගේ\tඅතුරුදහන්වූ',
#  'අතුලත්\tඅතුල',
#  'අතුවලින්\tඅතුවල',
#  'අතුළත්\tඅතුළත',
#  'අදටත්\tඅදට',
#  'අදමා\tඅදම',
#  'අදයිතරගයේ\tඅදයිතරගය',
#  'අදයිතරඟයේ\tඅදයිතරඟය',
#  'අදවන්\tඅදවන',
#  'අදහන්න\tඅදහන්',
#  'අදහසක්\tඅදහසක',
#  'අදහසකින්\tඅදහසකි',
#  'අදහස්ද\tඅදහස්',
#  'අදහස්ය\tඅදහස්',
#  'අදහස්ල\tඅදහස්',
#  'අදහස්වලට\tඅදහස්වල',
#  'අදහස්වලින්\tඅදහස්වල',
#  'අදළා\tඅදළ',
#  'අද්දරආරච්චිව\tඅද්දරආරච්චි',
#  'අදායමක්\tඅදායම',
#  'අදායම්\tඅදායම',
#  'අදාලවයි\tඅදාලව',
#  'අදාළවත්\tඅදාළව',
#  'අදාළවද\tඅදාළව',
#  'අදාළවන\tඅදාළව',
#  'අදාළවය\tඅදාළව',
#  'අදිකරණයට\tඅදිකරණය',
#  'අදිකරණයේ\tඅදිකරණය',
#  'අදිකාරම්ගේ\tඅදිකාරම්',
#  'අදිකාරියේ\tඅදිකාරිය',
#  'අදිටන්\tඅදිටන',
#  'අදිටනින්\tඅදිටන',
#  'අදිනවද\tඅදින',
#  'අදිනවා\tඅදින',
#  'අදින්\tඅදින',
#  'අදින්නට\tඅදින්න',
#  'අදින්නත්\tඅදින්න',
#  'අදින්නේ\tඅදින්න',
#  'අදියරකට\tඅදියරක',
#  'අදියරක්\tඅදියරක',
#  'අදියරයක්\tඅදියරය',
#  'අදියරයට\tඅදියරය',
#  'අදියරයන්\tඅදියරය',
#  'අදූරදර්ශීව\tඅදූරදර්ශී',
#  'අදෝනාව\tඅදෝනා',
#  'අදෝනාවෙන්\tඅදෝනා',
#  'අධයාපනයේ\tඅධයාපනය',
#  'අධ්යක්ෂකවරයකුගේම\tඅධ්යක්ෂකවරයකු',
#  'අධ්යක්ෂකවරයාගේ\tඅධ්යක්ෂකවරයා',
#  'අධ්යක්ෂකවරයාට\tඅධ්යක්ෂකවරයා',
#  'අධ්යක්ෂකවරයෙකුගේ\tඅධ්යක්ෂකවරයෙකු',
#  'අධ්යක්ෂකවරියගේ\tඅධ්යක්ෂකවරිය',
#  'අධ්යක්ෂකවරුන්ගේ\tඅධ්යක්ෂකවරුන්',
#  'අධ්යක්ෂකවරුන්ට\tඅධ්යක්ෂකවරුන්',
#  'අධ්යක්ෂණයක්\tඅධ්යක්ෂණය',
#  'අධ්යක්ෂවරයාගෙන්\tඅධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයාගේ\tඅධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයාට\tඅධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයාද\tඅධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයෙකුගේ\tඅධ්යක්ෂවරයෙකු',
#  'අධ්යක්ෂවරියකගෙන්\tඅධ්යක්ෂවරියක',
#  'අධ්යක්ෂවරියක්\tඅධ්යක්ෂවරියක',
#  'අධ්යක්ෂවරුන්\tඅධ්යක්ෂවරු',
#  'අධ්යක්ෂවරුන්ගෙන්\tඅධ්යක්ෂවරු',
#  'අධ්යක්ෂවරුන්ගේ\tඅධ්යක්ෂවරු',
#  'අධ්යක්ෂවරුන්ට\tඅධ්යක්ෂවරු',
#  'අධ්යක්ෂිකාව\tඅධ්යක්ෂිකා',
#  'අධ්යක්ෂිකාවක\tඅධ්යක්ෂිකා',
#  'අධ්යක්ෂිකාවක්\tඅධ්යක්ෂිකා',
#  'අධ්යක්ෂිකාවට\tඅධ්යක්ෂිකා',
#  'අධ්යනය\tඅධ්යන',
#  'අධ්යනයක\tඅධ්යන',
#  'අධ්යපනය\tඅධ්යපන',
#  'අධ්යයනයකදීයි\tඅධ්යයනයකදී',
#  'අධ්යයනයන්\tඅධ්යයනයන',
#  'අධ්යයනයන්වල\tඅධ්යයනයන',
#  'අධ්යයනාංශයේ\tඅධ්යයනාංශය',
#  'අධ්යානයට\tඅධ්යාන',
#  'අධ්යාපනයකට\tඅධ්යාපනය',
#  'අධ්යාපනයක්\tඅධ්යාපනය',
#  'අධ්යාපනයට\tඅධ්යාපනය',
#  'අධ්යාපනයටත්\tඅධ්යාපනය',
#  'අධ්යාපනයත්\tඅධ්යාපනය',
#  'අධ්යාපනයද\tඅධ්යාපනය',
#  'අධ්යාපනයම\tඅධ්යාපනය',
#  'අධ්යාපනයෙන්ද\tඅධ්යාපනයෙන්',
#  'අධිකණයක්\tඅධිකණ',
#  'අධිකණයේ\tඅධිකණ',
#  'අධිකරණක්\tඅධිකරණ',
#  'අධිකරණට\tඅධිකරණ',
#  'අධිකරණයකට\tඅධිකරණයක',
#  'අධිකරණයක්ද\tඅධිකරණයක්',
#  'අධිකරණයටත්\tඅධිකරණයට',
#  'අධිකරණයටද\tඅධිකරණයට',
#  'අධිකරණයටයි\tඅධිකරණයට',
#  'අධිකරණයන්ට\tඅධිකරණයන්',
#  'අධිකරණයේත්\tඅධිකරණයේ',
#  'අධිකරණයේදීත්\tඅධිකරණයේදී',
#  'අධිකරණවලට\tඅධිකරණවල',
#  'අධිකරණවලින්\tඅධිකරණවල',
#  'අධිකරනය\tඅධිකරන',
#  'අධිකරනයට\tඅධිකරන',
#  'අධිකරියට\tඅධිකරිය',
#  'අධිකරියයි\tඅධිකරිය',
#  'අධිකරීවරයාට\tඅධිකරී',
#  'අධික්ෂණය\tඅධික්ෂණ',
#  'අධික්ෂණයක\tඅධික්ෂණ',
#  'අධික්ෂණයක්\tඅධික්ෂණ',
#  'අධිකාරම\tඅධිකාර',
#  'අධිකාරම්\tඅධිකාර',
#  'අධිකාරය\tඅධිකාර',
#  'අධිකාරිගෙන්\tඅධිකාරි',
#  'අධිකාරිට\tඅධිකාරි',
#  'අධිකාරියකට\tඅධිකාරියක',
#  'අධිකාරියක්\tඅධිකාරියක',
#  'අධිකාරියටත්\tඅධිකාරියට',
#  'අධිකාරියටද\tඅධිකාරියට',
#  'අධිකාරියටය\tඅධිකාරියට',
#  'අධිකාරියේත්\tඅධිකාරියේ',
#  'අධිකාරියේද\tඅධිකාරියේ',
#  'අධිකාරිවරයාගෙන්\tඅධිකාරිවරයා',
#  'අධිකාරිවරයාගේ\tඅධිකාරිවරයා',
#  'අධිකාරිවරයාට\tඅධිකාරිවරයා',
#  'අධිකාරිවරයෙකුගේ\tඅධිකාරිවරයෙකු',
#  'අධිකාරිවරියගෙන්\tඅධිකාරිවරිය',
#  'අධිකාරිවරියන්\tඅධිකාරිවරිය',
#  'අධිකාරිවරුන්\tඅධිකාරිවරු',
#  'අධිකාරීට\tඅධිකාරී',
#  'අධිකාරීත්වයකින්\tඅධිකාරීත්වය',
#  'අධිකාරීන්ට\tඅධිකාරීන්',
#  'අධිකාරීයට\tඅධිකාරීය',
#  'අධිකාරීයටත්\tඅධිකාරීය',
#  'අධිකාරීයේ\tඅධිකාරීය',
#  'අධිකාරීවරයකුගේ\tඅධිකාරීවරයකු',
#  'අධිකාරීවරයාගෙන්\tඅධිකාරීවරයා',
#  'අධිකාරීවරයාගේ\tඅධිකාරීවරයා',
#  'අධිකාරීවරයාට\tඅධිකාරීවරයා',
#  'අධිකාරීවරයාත්\tඅධිකාරීවරයා',
#  'අධිකාරීවරයෙකුගේ\tඅධිකාරීවරයෙකු',
#  'අධිකාරීවරියගේ\tඅධිකාරීවරිය',
#  'අධිකාරීවරියන්\tඅධිකාරීවරිය',
#  'අධිකාරීවරුන්\tඅධිකාරීවරු',
#  'අධිකාරීවරුන්ට\tඅධිකාරීවරු',
#  'අධිචෝදනාවලට\tඅධිචෝදනා',
#  'අධිත්යනාත්ගේ\tඅධිත්යනාත්',
#  'අධිපත්ය\tඅධිපත්',
#  'අධිපතිගෙන්\tඅධිපති',
#  'අධිපතිගේ\tඅධිපති',
#  'අධිපතිට\tඅධිපති',
#  'අධිපතිත්\tඅධිපති',
#  'අධිපතිවරයාගෙන්\tඅධිපතිවරයා',
#  'අධිපතිවරයාගේ\tඅධිපතිවරයා',
#  'අධිපතිවරයාට\tඅධිපතිවරයා',
#  'අධිපතිවරයාද\tඅධිපතිවරයා',
#  'අධිපතිවරයාව\tඅධිපතිවරයා',
#  'අධිපතිවරුන්ගේ\tඅධිපතිවරුන්',
#  'අධිබලති\tඅධිබල',
#  'අධිභාරය\tඅධිභාර',
#  'අධිභාරයක්\tඅධිභාර',
#  'අධිරාජයාගේ\tඅධිරාජයා',
#  'අධිරාජයාටත්\tඅධිරාජයා',
#  'අධිරාජ්යයට\tඅධිරාජ්ය',
#  'අධිරාජ්යයා\tඅධිරාජ්ය',
#  'අධිරාජ්යයාගෙන්\tඅධිරාජ්ය',
#  'අධිරාජ්යයාගේ\tඅධිරාජ්ය',
#  'අධිරාජ්යයාට\tඅධිරාජ්ය',
#  'අධිරාජ්යවාදීන්\tඅධිරාජ්යවාදී',
#  'අධිරාජ්යවාදීන්ගේ\tඅධිරාජ්යවාදී',
#  'අධිවේගය\tඅධිවේග',
#  'අධිවේගයට\tඅධිවේග',
#  'අධිවේගයටත්\tඅධිවේග',
#  'අධිවේගයේ\tඅධිවේග',
#  'අධිවේගයේත්\tඅධිවේග',
#  'අධිවේගයේදී\tඅධිවේග',
#  'අධිවේගියේ\tඅධිවේගි',
#  'අධිශිෂ්යත්වයක්\tඅධිශිෂ්යත්වය',
#  'අධිෂ්ඨානය\tඅධිෂ්ඨාන',
#  'අධීකරණය\tඅධීකරණ',
#  'අධීකරණයට\tඅධීකරණ',
#  'අධීකරණයෙන්\tඅධීකරණ',
#  'අධීක්ෂණය\tඅධීක්ෂණ',
#  'අධීක්ෂණයකට\tඅධීක්ෂණ',
#  'අධීක්ෂණයක්\tඅධීක්ෂණ',
#  'අධීක්ෂණයකින්\tඅධීක්ෂණ',
#  'අධීක්ෂණයට\tඅධීක්ෂණ',
#  'අධීක්ෂණයන්\tඅධීක්ෂණ',
#  'අධීක්ෂණයෙන්\tඅධීක්ෂණ',
#  'අධීක්ෂණයේ\tඅධීක්ෂණ',
#  'අධීකාරිය\tඅධීකාරි',
#  'අධීකාරියේ\tඅධීකාරි',
#  'අධෛර්යට\tඅධෛර්ය',
#  'අනතරට\tඅනතර',
#  'අනතර්\tඅනතර',
#  'අනතුරකට\tඅනතුරක',
#  'අනතුරක්ක්\tඅනතුරක්',
#  'අනතුරටත්\tඅනතුරට',
#  'අනතුරවයි\tඅනතුරව',
#  'අනතුරිකින්\tඅනතුරි',
#  'අනතුරින්\tඅනතුරි',
#  'අනතුරුදායකයි\tඅනතුරුදායක',
#  'අනතුරුවත්\tඅනතුරුව',
#  'අනතුරුවද\tඅනතුරුව',
#  'අනතුරුවය\tඅනතුරුව',
#  'අනතුරුවලකා\tඅනතුරුවල',
#  'අනතුරුවලට\tඅනතුරුවල',
#  'අනතුරුවලින්\tඅනතුරුවල',
#  'අනන්තයි\tඅනන්ත',
#  'අනන්තවත්\tඅනන්ත',
#  'අනන්යතාව\tඅනන්යතා',
#  'අනන්යතාවක්\tඅනන්යතා',
#  'අනන්යතාවට\tඅනන්යතා',
#  'අනන්යතාවයක්\tඅනන්යතාවය',
#  'අනන්යතාවයකින්\tඅනන්යතාවය',
#  'අනන්යතාවයන්\tඅනන්යතාවය',
#  'අනන්යතාවයයි\tඅනන්යතාවය',
#  'අනපේක්ෂිතව\tඅනපේක්ෂිත',
#  'අනවබෝධයෙන්\tඅනවබෝධය',
#  'අනවශ්යම\tඅනවශ්ය',
#  'අනවශ්යය\tඅනවශ්ය',
#  'අනවශ්යයයි\tඅනවශ්ය',
#  'අනවශ්යයි\tඅනවශ්ය',
#  'අනවශ්යව\tඅනවශ්ය',
#  'අනවසරයෙන්\tඅනවසර',
#  'අනවසරෙන්\tඅනවසර',
#  'අන්තයකම\tඅන්තයක',
#  'අන්තයක්\tඅන්තයක',
#  'අන්තයකින්\tඅන්තයක',
#  'අන්තයටම\tඅන්තයට',
#  'අන්තයේදීත්\tඅන්තයේදී',
#  'අන්තරජාලයට\tඅන්තරජාලය',
#  'අන්තර්ගතය\tඅන්තර්ගත',
#  'අන්තර්ගතයන්\tඅන්තර්ගත',
#  'අන්තර්ගතයි\tඅන්තර්ගත',
#  'අන්තර්ගතවේ\tඅන්තර්ගතව',
#  'අන්තර්ජාතිකව\tඅන්තර්ජාතික',
#  'අන්තර්ජාලය\tඅන්තර්ජාල',
#  'අන්තර්ජාලයට\tඅන්තර්ජාල',
#  'අන්තර්ජාලයටත්\tඅන්තර්ජාල',
#  'අන්තරේට\tඅන්තරේ',
#  'අන්තවාදයකට\tඅන්තවාදය',
#  'අන්තවාදිගේ\tඅන්තවාදි',
#  'අන්තවාදින්\tඅන්තවාදි',
#  'අන්තවාදින්ට\tඅන්තවාදි',
#  'අන්තවාදියා\tඅන්තවාදි',
#  'අන්තවාදියෙකු\tඅන්තවාදි',
#  'අන්තවාදීන්\tඅන්තවාදී',
#  'අන්තවාදීන්ගෙන්\tඅන්තවාදී',
#  'අන්තවාදීන්ගේ\tඅන්තවාදී',
#  'අන්තවාදීන්ට\tඅන්තවාදී',
#  'අන්තවාදීව\tඅන්තවාදී',
#  'අන්ත්රවල\tඅන්ත්ර',
#  'අන්තිමට\tඅන්තිම',
#  'අන්තිමයා\tඅන්තිම',
#  'අන්තිමයි\tඅන්තිම',
#  'අන්තිමේට\tඅන්තිම',
#  'අන්දමට\tඅන්දම',
#  'අන්දමන්\tඅන්දම',
#  'අන්ධභාවයට\tඅන්ධභාවය',
#  'අන්නෝන්යම\tඅන්නෝන්ය',
#  'අන්යයන්ට\tඅන්ය',
#  'අන්යාගමිකයන්\tඅන්යාගමික',
#  'අන්යාගමිකයින්ට\tඅන්යාගමිකයින්',
#  'අන්සාර්ගෙන්\tඅන්සාර්',
#  'අනාගතය\tඅනාගත',
#  'අනාගතයකට\tඅනාගත',
#  'අනාගතයක්\tඅනාගත',
#  'අනාගතයට\tඅනාගත',
#  'අනාගතයටත්\tඅනාගත',
#  'අනාගතයේත්\tඅනාගතයේ',
#  'අනාථාගාරය\tඅනාථාගාර',
#  'අනාථාගාරයට\tඅනාථාගාර',
#  'අනාථාගාරයෙන්\tඅනාථාගාර',
#  'අනාථාගාරයේ\tඅනාථාගාර',
#  'අනාථාගාරයේදී\tඅනාථාගාර',
#  'අනාරාධිතවම\tඅනාරාධිතව',
#  'අනාවණය\tඅනාවණ',
#  'අනාවරණය\tඅනාවරණ',
#  'අනාවරණයකට\tඅනාවරණ',
#  'අනාවරණයවීම\tඅනාවරණයවී',
#  'අනාවරණවී\tඅනාවරණව',
#  'අනාවරනය\tඅනාවරන',
#  'අනාවැකියක්\tඅනාවැකිය',
#  'අනාවැකිවලින්\tඅනාවැකිවල',
#  'අනික්\tඅනික',
#  'අනිකා\tඅනික',
#  'අනිද්දා\tඅනිද්ද',
#  'අනිද්දාට\tඅනිද්ද',
#  'අනින්\tඅනින',
#  'අනින්නට\tඅනින්න',
#  'අනින්නෙ\tඅනින්න',
#  'අනින්නේ\tඅනින්න',
#  'අනියත්\tඅනියත',
#  'අනියුක්තව\tඅනියුක්ත',
#  'අනිවාරයෙන්ම\tඅනිවාරයෙන්',
#  'අනිවාර්යය\tඅනිවාර්ය',
#  'අනිවාර්යයි\tඅනිවාර්ය',
#  'අනිවාර්යයෙන්ම\tඅනිවාර්යයෙන්',
#  'අනිවාර්යෙන්ම\tඅනිවාර්යෙන්',
#  'අනීකා\tඅනී',
#  'අනීතිකව\tඅනීතික',
#  'අනුකම්පාව\tඅනුකම්පා',
#  'අනුකම්පාවක්\tඅනුකම්පා',
#  'අනුකම්පාවෙන්\tඅනුකම්පා',
#  'අනුකමිටුව\tඅනුකමිටු',
#  'අනුකමිටුවකට\tඅනුකමිටු',
#  'අනුකමිටුවක්\tඅනුකමිටු',
#  'අනුකමිටුවට\tඅනුකමිටු',
#  'අනුකමිටුවල\tඅනුකමිටු',
#  'අනුකමිටුවලින්\tඅනුකමිටු',
#  'අනුකමිටුවේ\tඅනුකමිටු',
#  'අනුකරණයට\tඅනුකරණය',
#  'අනුකුලව\tඅනුකුල',
#  'අනුකූලතාව\tඅනුකූලතා',
#  'අනුකූලවන\tඅනුකූලව',
#  'අනුකූලවම\tඅනුකූලව',
#  'අනුකූලවයි\tඅනුකූලව',
#  'අනුඛණ්ඩයට\tඅනුඛණ්ඩ',
#  'අනුගතව\tඅනුගත',
#  'අනුග්රහයක්\tඅනුග්රහය',
#  'අනුග්රහයද\tඅනුග්රහය',
#  'අනුග්රහයෙන්\tඅනුග්රහය',
#  'අනුග්රාහකත්වයද\tඅනුග්රාහකත්වය',
#  'අනුග්රාහකත්වයෙන්\tඅනුග්රාහකත්වය',
#  'අනුගාමිකයන්ගෙන්\tඅනුගාමිකයන්',
#  'අනුගාමිකයන්ගේ\tඅනුගාමිකයන්',
#  'අනුගාමිකයන්ට\tඅනුගාමිකයන්',
#  'අනුත්තරා\tඅනුත්තර',
#  'අනුදැනීමෙන්\tඅනුදැන',
#  'අනුදැනුම\tඅනුදැන',
#  'අනුදැනුමකින්\tඅනුදැන',
#  'අනුනවය\tඅනුනව',
#  'අනුන්ගෙන්\tඅනුන්',
#  'අනුන්ගේ\tඅනුන්',
#  'අනුන්ට\tඅනුන්',
#  'අනුනාහිමියන්\tඅනුනාහිමි',
#  'අනුනාහිමියන්ගෙන්\tඅනුනාහිමි',
#  'අනුනාහිමියන්ගේ\tඅනුනාහිමි',
#  'අනුනාහිමිවරුන්\tඅනුනාහිමි',
#  'අනුප්රාප්තිකයා\tඅනුප්රාප්තික',
#  'අනුප්රාප්තිකයෙකු\tඅනුප්රාප්තික',
#  'අනුපාතයකට\tඅනුපාතය',
#  'අනුපාතයක්ද\tඅනුපාතයක්',
#  'අනුපාතවලට\tඅනුපාතවල',
#  'අනුපාතිකය\tඅනුපාතික',
#  'අනුපාතිකයක්\tඅනුපාතික',
#  'අනුපාතිකයන්ට\tඅනුපාතික',
#  'අනුපාතිකයේ\tඅනුපාතික',
#  'අනුබද්ධව\tඅනුබද්ධ',
#  'අනුබද්ධවයි\tඅනුබද්ධ',
#  'අනුබද්ධිතව\tඅනුබද්ධිත',
#  'අනුබලදීම\tඅනුබලදී',
#  'අනුබලදීමක්\tඅනුබලදී',
#  'අනුබලදීමේ\tඅනුබලදී',
#  'අනුබලයක්\tඅනුබලය',
#  'අනුභවයට\tඅනුභවය',
#  'අනුභවයෙන්\tඅනුභවය',
#  'අනුමතයි\tඅනුමත',
#  'අනුමැතිය\tඅනුමැති',
#  'අනුමැතියක්\tඅනුමැති',
#  'අනුමැතීන්ගෙන්\tඅනුමැතීන්',
#  'අනුමැතීන්ට\tඅනුමැතීන්',
#  'අනුයුක්තව\tඅනුයුක්ත',
#  'අනුයුක්තවයි\tඅනුයුක්ත',
#  'අනුයුත්තව\tඅනුයුත්ත',
#  'අනුරපුරට\tඅනුරපුර',
#  'අනුරපුරයට\tඅනුරපුර',
#  'අනුරපුරයෙන්\tඅනුරපුර',
#  'අනුරපුරයේ\tඅනුරපුර',
#  'අනුරපුරයේදී\tඅනුරපුර',
#  'අනුරාධපුරට\tඅනුරාධපුර',
#  'අනුරාධපුරය\tඅනුරාධපුර',
#  'අනුරාධපුරයට\tඅනුරාධපුර',
#  'අනුරාධපුරයටත්\tඅනුරාධපුර',
#  'අනුරාධපුරයේත්\tඅනුරාධපුරයේ',
#  'අනුරාධපුරේට\tඅනුරාධපුරේ',
#  'අනුරුද්ධගෙන්\tඅනුරුද්ධ',
#  'අනුරුද්ධට\tඅනුරුද්ධ',
#  'අනුරුවක්\tඅනුරුව',
#  'අනුශාසකවරුන්ට\tඅනුශාසකවරුන්',
#  'අනුශාසනාව\tඅනුශාසනා',
#  'අනුශාසනාවක්\tඅනුශාසනා',
#  'අනුශාසනාවලින්\tඅනුශාසනා',
#  'අනුශූරතාවය\tඅනුශූරතාව',
#  'අනුශූරතාවෙන්\tඅනුශූරතාව',
#  'අනුශූරයන්ට\tඅනුශූරයන්',
#  'අනුෂ්කා\tඅනුෂ්ක',
#  'අනුෂාන්\tඅනුෂා',
#  'අනුෂිකා\tඅනුෂික',
#  'අනුස්මරණය\tඅනුස්මරණ',
#  'අනුස්මරණයට\tඅනුස්මරණ',
#  'අනුස්මරණීය\tඅනුස්මරණ',
#  'අනුහසක්\tඅනුහස',
#  'අනූදහසක්\tඅනූදහසක',
#  'අනූනව\tඅනූන',
#  'අනූවකට\tඅනූව',
#  'අනූවක්\tඅනූව',
#  'අනූෂා\tඅනූෂ',
#  'අනෙකත්\tඅනෙක',
#  'අනෙක්\tඅනෙක',
#  'අනෙකාගේ\tඅනෙකා',
#  'අනෙකුත්\tඅනෙකු',
#  'අඳුනක්\tඅඳුන',
#  'අඳුන්\tඅඳුන',
#  'අඳූරු\tඅඳූර',
#  'අපක්ෂපාතිව\tඅපක්ෂපාති',
#  'අපක්ෂපාතීත්වයට\tඅපක්ෂපාතීත්වය',
#  'අපකීර්තිමත්ම\tඅපකීර්තිමත්',
#  'අපකීර්තියක්\tඅපකීර්තිය',
#  'අපකීර්තියට\tඅපකීර්තිය',
#  'අපගමනයකට\tඅපගමනය',
#  'අපගමනයක්\tඅපගමනය',
#  'අපගමනයන්\tඅපගමනය',
#  'අපගමනයයි\tඅපගමනය',
#  'අපගේද\tඅපගේ',
#  'අපචාරය\tඅපචාර',
#  'අපචාරයට\tඅපචාර',
#  'අපචාරයන්\tඅපචාර',
#  'අපචාරයන්ගෙන්\tඅපචාර',
#  'අපචාරයන්ට\tඅපචාර',
#  'අපජලය\tඅපජල',
#  'අපජලයේ\tඅපජල',
#  'අපටත්\tඅපට',
#  'අපටද\tඅපට',
#  'අපතේයාමක්\tඅපතේයාම',
#  'අපද්රව්යයක්\tඅපද්රව්යය',
#  'අපද්රව්යවලට\tඅපද්රව්යවල',
#  'අපද්රව්යවලින්\tඅපද්රව්යවල',
#  'අපදාවන්ට\tඅපදාවන්',
#  'අපනයනකරුවන්ගේ\tඅපනයනකරුවන්',
#  'අපනයනකරුවන්ට\tඅපනයනකරුවන්',
#  'අපනයනකරුවන්ටත්\tඅපනයනකරුවන්',
#  'අපනයනකරුවන්ද\tඅපනයනකරුවන්',
#  'අපනයනයටත්\tඅපනයනයට',
#  'අපනයනයටද\tඅපනයනයට',
#  'අපනයනයන්ට\tඅපනයනයන්',
#  'අපනයනයන්හි\tඅපනයනයන්',
#  'අපනයනවලට\tඅපනයනවල',
#  'අපමණයි\tඅපමණ',
#  'අපයෝජනය\tඅපයෝජන',
#  'අපයෝජනයකට\tඅපයෝජන',
#  'අපයෝජනයක්\tඅපයෝජන',
#  'අපයෝජනයට\tඅපයෝජන',
#  'අපයෝජනයන්\tඅපයෝජන',
#  'අපයෝජනයන්ගෙන්\tඅපයෝජන',
#  'අපරාජිතව\tඅපරාජිත',
#  'අපරාධකරුගේ\tඅපරාධකරු',
#  'අපරාධකරුට\tඅපරාධකරු',
#  'අපරාධකරුවකු\tඅපරාධකරු',
#  'අපරාධකරුවන්\tඅපරාධකරු',
#  'අපරාධකරුවන්ගේ\tඅපරාධකරු',
#  'අපරාධකරුවන්ට\tඅපරාධකරු',
#  'අපරාධයකට\tඅපරාධය',
#  'අපරාධයක්\tඅපරාධය',
#  'අපරාධයට\tඅපරාධය',
#  'අපරාධයන්\tඅපරාධය',
#  'අපරාධයන්ට\tඅපරාධය',
#  'අපරාධයෙන්\tඅපරාධය',
#  'අපරාධයේ\tඅපරාධය',
#  'අපරාධවලට\tඅපරාධවල',
#  'අපරාධවලින්\tඅපරාධවල',
#  'අපරික්ෂාකාරිව\tඅපරික්ෂාකාරි',
#  'අපරික්ෂාකාරීව\tඅපරික්ෂාකාරී',
#  'අපරීක්ෂාකාරීව\tඅපරීක්ෂාකාරී',
#  'අපලයක්\tඅපල',
#  'අපලයෙන්\tඅපල',
#  'අපවත්\tඅපව',
#  'අපවත්වන\tඅපවත්ව',
#  'අපවත්වීම\tඅපවත්වී',
#  'අපවාදයක්\tඅපවාද',
#  'අපවාදවලට\tඅපවාද',
#  'අපවිත්රවීම\tඅපවිත්රවී',
#  'අපස්මාරය\tඅපස්මාර',
#  'අපහරණය\tඅපහරණ',
#  'අපහරණයට\tඅපහරණ',
#  'අපහසයක්\tඅපහස',
#  'අපහසයට\tඅපහස',
#  'අපහසු\tඅපහස',
#  'අපහසුතාත්\tඅපහසුතා',
#  'අපහසුතාව\tඅපහසුතා',
#  'අපහසුතාවක\tඅපහසුතා',
#  'අපහසුතාවකට\tඅපහසුතා',
#  'අපහසුතාවටයි\tඅපහසුතාවට',
#  'අපහසුතාවන්ට\tඅපහසුතාවන්',
#  'අපහසුතාවයකට\tඅපහසුතාවය',
#  'අපහසුතාවයන්ට\tඅපහසුතාවයන්',
#  'අපහාසක්\tඅපහාස',
#  'අපහාසත්\tඅපහාස',
#  'අපහාසයක්\tඅපහාස',
#  'අපහාසයට\tඅපහාස',
#  'අප්පච්චිට\tඅප්පච්චි',
#  'අප්පච්චිව\tඅප්පච්චි',
#  'අප්පුගේ\tඅප්පු',
#  'අප්රමාණව\tඅප්රමාණ',
#  'අප්රසාදයක්\tඅප්රසාදය',
#  'අප්රසාදයට\tඅප්රසාදය',
#  'අප්රසාදයෙන්\tඅප්රසාදය',
#  'අප්රාණිකව\tඅප්රාණික',
#  'අප්රිකාණුවන්\tඅප්රිකාණු',
#  'අප්රිකානුවන්\tඅප්රිකානු',
#  'අප්රිකානුවන්ගෙන්\tඅප්රිකානු',
#  'අප්රිකානුවන්ට\tඅප්රිකානු',
#  'අප්රිකාවක්\tඅප්රිකාව',
#  'අප්රිකාවට\tඅප්රිකාව',
#  'අප්රිකාවටත්\tඅප්රිකාව',
#  'අප්රිකාවේදී\tඅප්රිකාව',
#  'අප්රිකාවේදීත්\tඅප්රිකාව',
#  'අප්රිකාවේ\tඅප්රිකාව',
#  'අපැහැදිලිකම\tඅපැහැදිලි',
#  'අපිට\tඅපි',
#  'අපිටම\tඅපි',
#  'අපිටමට\tඅපි',
#  'අපිටමම\tඅපි',
#  'අපිම\tඅපි',
#  'අපිමයි\tඅපි',
#  'අපිරිසිදුවීම\tඅපිරිසිදුව',
#  'අපිව\tඅපි',
#  'අපිවත්\tඅපි',
#  'අපි්රකානු\tඅපි්රකා',
#  'අපි්රකාව\tඅපි්රකා',
#  'අපි්රකාවට\tඅපි්රකා',
#  'අපි්රකාවේ\tඅපි්රකා',
#  'අපූරුවට\tඅපූරු',
#  'අපෙක්ෂාව\tඅපෙක්ෂා',
#  'අපෙක්ෂාවෙන්\tඅපෙක්ෂා',
#  'අපේකම\tඅපේ',
#  'අපේකෂකයන්ගේ\tඅපේකෂකයන්',
#  'අපේකෂාවයි\tඅපේකෂා',
#  'අපේකෂාවෙන්\tඅපේකෂා',
#  'අපේක්ෂකත්වයක්\tඅපේක්ෂක',
#  'අපේක්ෂකත්වයේ\tඅපේක්ෂක',
#  'අපේක්ෂකයන්\tඅපේක්ෂක',
#  'අපේක්ෂකයන්ගෙන්\tඅපේක්ෂක',
#  'අපේක්ෂකයන්ගේ\tඅපේක්ෂක',
#  'අපේක්ෂකයන්ට\tඅපේක්ෂක',
#  'අපේක්ෂකයාට\tඅපේක්ෂක',
#  'අපේක්ෂකයාත්\tඅපේක්ෂක',
#  'අපේක්ෂකයාව\tඅපේක්ෂක',
#  'අපේක්ෂකයින්ගේ\tඅපේක්ෂක',
#  'අපේක්ෂකයින්ට\tඅපේක්ෂක',
#  'අපේක්ෂකයෙකුට\tඅපේක්ෂක',
#  'අපේක්ෂණයක්\tඅපේක්ෂණ',
#  'අපේක්ෂණයේ\tඅපේක්ෂණ',
#  'අපේක්ෂාවක්\tඅපේක්ෂාවක',
#  'අපේක්ෂාවකින්\tඅපේක්ෂාවක',
#  'අපේක්ෂාවන්ට\tඅපේක්ෂාවන්',
#  'අපේක්ෂිකාව\tඅපේක්ෂිකා',
#  'අපේක්ෂිකාවක\tඅපේක්ෂිකා',
#  'අපේක්ෂිකාවකට\tඅපේක්ෂිකා',
#  'අපේක්ෂිකාවක්\tඅපේක්ෂිකා',
#  'අපේක්ෂිකාවන්\tඅපේක්ෂිකා',
#  'අපේක්ෂිකාවන්ට\tඅපේක්ෂිකා',
#  'අපේක්ෂිතය\tඅපේක්ෂිත',
#  'අපේගමේ\tඅපේගම',
#  'අපේ්ක්ෂකයාව\tඅපේ්ක්ෂකයා',
#  ...]

# %%
Dict = {}
for row in sd:
  word = row.split('\t')
  Dict[word[0]] = word[1]

# %%
Dict
# Out:
# {'අංකද': 'අංක',
#  'අංකය': 'අංක',
#  'අංකයක්': 'අංක',
#  'අංකයට': 'අංක',
#  'අංකයටද': 'අංක',
#  'අංකයන්ට': 'අංක',
#  'අංකයන්ටද': 'අංක',
#  'අංකවල': 'අංක',
#  'අංකවලට': 'අංක',
#  'අංකවලින්': 'අංක',
#  'අංගණයට': 'අංගණය',
#  'අංගණයේ': 'අංගණය',
#  'අංගනය': 'අංගන',
#  'අංගනයක': 'අංගන',
#  'අංගනයක්': 'අංගන',
#  'අංගයක්': 'අංගය',
#  'අංගවලින්': 'අංගවල',
#  'අංගොඩට': 'අංගොඩ',
#  'අංගෝපාංගයන්': 'අංගෝපාංග',
#  'අංශභාගය': 'අංශභාග',
#  'අංශයකට': 'අංශය',
#  'අංශයකම': 'අංශය',
#  'අංශයක්': 'අංශය',
#  'අංශයකින්': 'අංශය',
#  'අංශයකින්ම': 'අංශය',
#  'අංශයට': 'අංශය',
#  'අංශයටත්': 'අංශය',
#  'අංශයටද': 'අංශය',
#  'අංශයන්': 'අංශය',
#  'අංශයන්ගෙන්': 'අංශය',
#  'අංශයන්ගේ': 'අංශය',
#  'අංශයන්හි': 'අංශය',
#  'අංශයෙන්': 'අංශය',
#  'අංශයෙන්ද': 'අංශය',
#  'අංශවලට': 'අංශවල',
#  'අංශවලින්': 'අංශවල',
#  'අකටයුත්තකට': 'අකටයුත්ත',
#  'අකටයුත්තක්': 'අකටයුත්ත',
#  'අකටයුතුකම්වලට': 'අකටයුතුකම්',
#  'අකටයුතුකම්වලින්': 'අකටයුතුකම්',
#  'අකණ්ඩව': 'අකණ්ඩ',
#  'අකමැත්තක්': 'අකමැත්ත',
#  'අකමැත්තකින්': 'අකමැත්ත',
#  'අකමැත්තද': 'අකමැත්ත',
#  'අකමැත්තෙන්': 'අකමැත්ත',
#  'අකමැතිවී': 'අකමැතිව',
#  'අකමැතිවීම': 'අකමැතිව',
#  'අකමැතිවූ': 'අකමැතිව',
#  'අකරතැබ්බය': 'අකරතැබ්බ',
#  'අකර්මණ්යය': 'අකර්මණ්ය',
#  'අකලංකගේ': 'අකලංක',
#  'අක්කගේ': 'අක්ක',
#  'අක්කයි': 'අක්ක',
#  'අක්කරක්': 'අක්කර',
#  'අක්කරපත්තුව': 'අක්කරපත්තු',
#  'අක්කරපත්තුවේ': 'අක්කරපත්තු',
#  'අක්කරයකට': 'අක්කරයක',
#  'අක්කරයක්': 'අක්කරයක',
#  'අක්කරෙයිපත්තුව': 'අක්කරෙයිපත්තු',
#  'අක්කරෙයිපත්තුවට': 'අක්කරෙයිපත්තු',
#  'අක්කරෙයිපත්තුවේ': 'අක්කරෙයිපත්තු',
#  'අක්කරේපත්තුව': 'අක්කරේපත්තු',
#  'අක්කරේපත්තුවේ': 'අක්කරේපත්තු',
#  'අක්කලාගේ': 'අක්කලා',
#  'අක්කාට': 'අක්කා',
#  'අක්කාව': 'අක්කා',
#  'අක්තපත්රය': 'අක්තපත්ර',
#  'අක්තාර්ට': 'අක්තාර්',
#  'අක්මාල්ගේ': 'අක්මාල්',
#  'අක්මාල්ට': 'අක්මාල්',
#  'අක්මාල්ද': 'අක්මාල්',
#  'අක්රමවත්ව': 'අක්රමවත්',
#  'අක්රම්ට': 'අක්රම්',
#  'අක්රමිකතාවක්': 'අක්රමිකතා',
#  'අක්රමිකතාවන්ගෙන්': 'අක්රමිකතාවන්',
#  'අක්රමිකතාවන්ට': 'අක්රමිකතාවන්',
#  'අක්රමිකතාවයක්': 'අක්රමිකතාවය',
#  'අක්රමිකතාවයන්': 'අක්රමිකතාවය',
#  'අක්රමිකතාවයෙන්': 'අක්රමිකතාවය',
#  'අක්රියවී': 'අක්රියව',
#  'අක්රියවීම': 'අක්රියව',
#  'අක්රීයයි': 'අක්රීය',
#  'අක්රීයව': 'අක්රීය',
#  'අක්ෂරයෙන්': 'අක්ෂර',
#  'අක්ෂරා': 'අක්ෂර',
#  'අක්ෂේගේ': 'අක්ෂේ',
#  'අකාරයටම': 'අකාරයට',
#  'අකාරයෙන්ම': 'අකාරයෙන්',
#  'අකාර්යක්ෂමතාව': 'අකාර්යක්ෂමතා',
#  'අකාර්යක්ෂමතාවයෙන්': 'අකාර්යක්ෂමතාවය',
#  'අකැමැත්තෙන්': 'අකැමැත්ත',
#  'අකියාවලින්': 'අකියා',
#  'අකිලගෙන්': 'අකිල',
#  'අකිලගේ': 'අකිල',
#  'අකිලට': 'අකිල',
#  'අකිලා': 'අකිල',
#  'අකිලීමේ': 'අකිල',
#  'අකුණුද': 'අකුණු',
#  'අකුරක්': 'අකුර',
#  'අකුරටම': 'අකුරට',
#  'අකුරැස්සට': 'අකුරැස්ස',
#  'අකුරැස්සම': 'අකුරැස්ස',
#  'අකුරැස්සේ': 'අකුරැස්ස',
#  'අකුලක්': 'අකුල',
#  'අඛණ්ඩතාවය': 'අඛණ්ඩතාව',
#  'අඛණ්ඩතාවයට': 'අඛණ්ඩතාව',
#  'අඛණ්ඩවම': 'අඛණ්ඩව',
#  'අඛන්ඩව': 'අඛන්ඩ',
#  'අගට': 'අග',
#  'අගටම': 'අග',
#  'අගතියක්': 'අගතිය',
#  'අගතියට': 'අගතිය',
#  'අගනගරයේ': 'අගනගරය',
#  'අගනාම': 'අගනා',
#  'අගනුවරක්': 'අගනුවර',
#  'අගනුවරට': 'අගනුවර',
#  'අගභාගයේ': 'අගභාගය',
#  'අගමැතිකම': 'අගමැති',
#  'අගමැතිට': 'අගමැති',
#  'අගමැතිටත්': 'අගමැති',
#  'අගමැතිටයි': 'අගමැති',
#  'අගමැතිණිය': 'අගමැති',
#  'අගමැතිණියටත්': 'අගමැති',
#  'අගමැතිතුමන්': 'අගමැති',
#  'අගමැතිතුමන්ගෙන්': 'අගමැති',
#  'අගමැතිතුමන්ගේ': 'අගමැති',
#  'අගමැතිතුමන්ද': 'අගමැති',
#  'අගමැතිතුමා': 'අගමැති',
#  'අගමැතිතුමාගෙ': 'අගමැති',
#  'අගමැතිතුමාගෙන්': 'අගමැති',
#  'අගමැතිතුමාගේ': 'අගමැති',
#  'අගමැතිතුමාට': 'අගමැති',
#  'අගමැතිතුමාටත්': 'අගමැති',
#  'අගමැතිනි': 'අගමැති',
#  'අගමැතිනිගේ': 'අගමැති',
#  'අගමැතිනිය': 'අගමැති',
#  'අගමැතිනියගේ': 'අගමැති',
#  'අගමැතිවරයාගේ': 'අගමැති',
#  'අගමැතිවරයාගේත්': 'අගමැති',
#  'අගමැතිවරු': 'අගමැති',
#  'අගමැතිවරුන්': 'අගමැති',
#  'අගමැතිවරුන්ට': 'අගමැති',
#  'අගයකට': 'අගයක',
#  'අගයනවා': 'අගයන',
#  'අගයන්': 'අගයන',
#  'අගරදගුරුගෙන්': 'අගරදගුරු',
#  'අගරදගුරුගේ': 'අගරදගුරු',
#  'අගරදගුරුතුමන්ගෙන්': 'අගරදගුරුතුමන්',
#  'අගරදගුරුතුමන්ට': 'අගරදගුරුතුමන්',
#  'අගලක්ම': 'අගලක්',
#  'අගලක්වත්': 'අගලක්',
#  'අගලවත්තේ': 'අගලවත්ත',
#  'අගවිනිසුරුගේ': 'අගවිනිසුරු',
#  'අගවිනිසුරුට': 'අගවිනිසුරු',
#  'අගහිගකම්වලින්': 'අගහිගකම්',
#  'අගහිඟකම්වලට': 'අගහිඟකම්',
#  'අග්ගලා': 'අග්ගල',
#  'අග්රමාත්යවරයාගෙන්': 'අග්රමාත්යවරයා',
#  'අග්රමාත්යවරයාගේ': 'අග්රමාත්යවරයා',
#  'අග්රමාත්යවරයාට': 'අග්රමාත්යවරයා',
#  'අග්රමාත්යවරයාව': 'අග්රමාත්යවරයා',
#  'අග්රාමාත්ය': 'අග්රාමාත්',
#  'අග්රාමාත්යවරයාගෙන්': 'අග්රාමාත්යවරයා',
#  'අග්රාමාත්යවරායාගේ': 'අග්රාමාත්යවරා',
#  'අග්රාමාත්යවරියගෙන්': 'අග්රාමාත්යවරිය',
#  'අග්රාමාත්යවරියට': 'අග්රාමාත්යවරිය',
#  'අග්රාමාත්යවරුන්': 'අග්රාමාත්යවරු',
#  'අගාඩ්ගේ': 'අගාඩ්',
#  'අගුණකොලපැලැස්සේ': 'අගුණකොලපැලැස්ස',
#  'අගුණකොළපැලැස්සේ': 'අගුණකොළපැලැස්ස',
#  'අගුණුකොලපැලැස්සේ': 'අගුණුකොලපැලැස්ස',
#  'අගුණුකොළපැලැස්සේ': 'අගුණුකොළපැලැස්ස',
#  'අගුනුකොළපැලැස්සේ': 'අගුනුකොළපැලැස්ස',
#  'අගුලක්': 'අගුල',
#  'අගුල්': 'අගුල',
#  'අගෝස්තුවෙන්': 'අගෝස්තු',
#  'අගෝස්තුවේ': 'අගෝස්තු',
#  'අගෞරවය': 'අගෞරව',
#  'අගෞරවයක්': 'අගෞරව',
#  'අඟලක්ම': 'අඟලක්',
#  'අඟලක්වත්': 'අඟලක්',
#  'අඟවනවා': 'අඟවන',
#  'අඟහරුගේ': 'අඟහරු',
#  'අඟහරුවාදායි': 'අඟහරුවාදා',
#  'අඟුණුකොලපැලැස්සේ': 'අඟුණුකොලපැලැස්ස',
#  'අඟුරුවලට': 'අඟුරු',
#  'අඟුලානේ': 'අඟුලාන',
#  'අචලාගෙන්': 'අචලා',
#  'අචලාට': 'අචලා',
#  'අච්චිලාගේ': 'අච්චි',
#  'අචාර්යවරුන්': 'අචාර්ය',
#  'අජන්තගෙන්': 'අජන්ත',
#  'අජන්තන්': 'අජන්ත',
#  'අජන්තා': 'අජන්ත',
#  'අජිත්ගේ': 'අජිත්',
#  'අටකට': 'අටක',
#  'අටක්ද': 'අටක්',
#  'අටටම': 'අටට',
#  'අටදහසකට': 'අටදහසක',
#  'අටදහසක්': 'අටදහසක',
#  'අටදෙනාගේ': 'අටදෙනා',
#  'අටදෙනෙකුගෙන්': 'අටදෙනෙකු',
#  'අටදෙනෙකුගේ': 'අටදෙනෙකු',
#  'අටදෙනෙකුට': 'අටදෙනෙකු',
#  'අටදෙනෙකුද': 'අටදෙනෙකු',
#  'අටමස්ථානයට': 'අටමස්ථානය',
#  'අටලක්ෂයක': 'අටලක්ෂ',
#  'අටලක්ෂයකට': 'අටලක්ෂ',
#  'අටසියක්': 'අටසියක',
#  'අටසියයකට': 'අටසියයක',
#  'අට්ටාලය': 'අට්ටාල',
#  'අට්ටාලයක': 'අට්ටාල',
#  'අට්ටාලයකට': 'අට්ටාල',
#  'අට්ටාලයක්': 'අට්ටාල',
#  'අට්ටාලවලට': 'අට්ටාලවල',
#  'අඩංගුයි': 'අඩංගු',
#  'අඩංගුවට': 'අඩංගුව',
#  'අඩංගුවන': 'අඩංගුව',
#  'අඩංගුවීම': 'අඩංගුව',
#  'අඩංගුවේ': 'අඩංගුව',
#  'අඩකට': 'අඩක',
#  'අඩකටත්': 'අඩක',
#  'අඩක්': 'අඩක',
#  'අඩපණයි': 'අඩපණ',
#  'අඩවියකට': 'අඩවියක',
#  'අඩවියක්': 'අඩවියක',
#  'අඩවියකින්': 'අඩවියක',
#  'අඩවියෙන්ද': 'අඩවියෙන්',
#  'අඩවියෙහිද': 'අඩවියෙහි',
#  'අඩවියේම': 'අඩවියේ',
#  'අඩවිවලට': 'අඩවිවල',
#  'අඩවිවලින්': 'අඩවිවල',
#  'අඩාලයි': 'අඩාල',
#  'අඩාලව': 'අඩාල',
#  'අඩාලවීමක්ද': 'අඩාලවීමක්',
#  'අඩිතාලමක්': 'අඩිතාලම',
#  'අඩිතාලමයි': 'අඩිතාලම',
#  'අඩිතාලම්': 'අඩිතාලම',
#  'අඩිපාරේම': 'අඩිපාරේ',
#  'අඩියක්': 'අඩියක',
#  'අඩුකරලා': 'අඩුකරල',
#  'අඩුකිරීමක්': 'අඩුකිරීම',
#  'අඩුකිරීමට': 'අඩුකිරීම',
#  'අඩුකිරීමටත්': 'අඩුකිරීම',
#  'අඩුකිරීමත්': 'අඩුකිරීම',
#  'අඩුකිරීම්': 'අඩුකිරීම',
#  'අඩුකිරීමේ': 'අඩුකිරීම',
#  'අඩුපාඩුවකට': 'අඩුපාඩුව',
#  'අඩුපාඩුවක්': 'අඩුපාඩුව',
#  'අඩුවක්': 'අඩුව',
#  'අඩුවිමක්': 'අඩුවිම',
#  'අඩුවිමට': 'අඩුවිම',
#  'අඩුවියන්': 'අඩුවිය',
#  'අඩුවීමක්': 'අඩුවීම',
#  'අඩුවුවත්': 'අඩුවුව',
#  'අඩුවුවද': 'අඩුවුව',
#  'අඩුවූයේ': 'අඩුවූ',
#  'අඩුවූවත්': 'අඩුවූ',
#  'අඩුවෙනවා': 'අඩුවෙන',
#  'අඩුවෙන්': 'අඩුවෙන',
#  'අඩුවෙනුත්': 'අඩුවෙනු',
#  'අණකට': 'අණ',
#  'අණදීමක්': 'අණද',
#  'අණදුන්': 'අණද',
#  'අණපනත්වල': 'අණපනත්',
#  'අණපනත්වලට': 'අණපනත්',
#  'අණ්ඩුවෙන්': 'අණ්ඩුව',
#  'අණ්ඩුවේ': 'අණ්ඩුව',
#  'අණාවරණය': 'අණාවරණ',
#  'අණාවරණයන්': 'අණාවරණ',
#  'අණාවරනය': 'අණාවරන',
#  'අඬකටත්': 'අඬක',
#  'අඬාල': 'අඬා',
#  'අතකට': 'අතක',
#  'අතක්': 'අතක',
#  'අතකින්': 'අතක',
#  'අතකොලූවක්': 'අතකොලූ',
#  'අතකොළුවක්': 'අතකොළු',
#  'අතගාන': 'අතගා',
#  'අතගාන්න': 'අතගා',
#  'අතගාමින්': 'අතගා',
#  'අතදීමක්': 'අතදී',
#  'අතදීමට': 'අතදී',
#  'අතපත්තුගෙන්': 'අතපත්තු',
#  'අතපත්තුගේ': 'අතපත්තු',
#  'අතපත්තුට': 'අතපත්තු',
#  'අතපත්තුයි': 'අතපත්තු',
#  'අතපසුවීම': 'අතපසුවී',
#  'අතපසුවීමක්': 'අතපසුවී',
#  'අතපසුවීමකින්': 'අතපසුවී',
#  'අතපසුවීම්': 'අතපසුවී',
#  'අතපෙවීම්වලින්': 'අතපෙවීම්',
#  'අතමිටේ': 'අතමිට',
#  'අතරටද': 'අතරට',
#  'අතරතුරදියි': 'අතරතුරදි',
#  'අතරතුරදීද': 'අතරතුරදී',
#  'අතරතුරදීය': 'අතරතුරදී',
#  'අතරතුරදීයි': 'අතරතුරදී',
#  'අතරමංවන්නට': 'අතරමංව',
#  'අතරමංවු': 'අතරමංව',
#  'අතරමංවූ': 'අතරමංව',
#  'අතරමගට': 'අතරමග',
#  'අතරමන්ව': 'අතරමන්',
#  'අතරමැදියන්': 'අතරමැදි',
#  'අතරමැදියන්ගෙන්': 'අතරමැදි',
#  'අතරමැදියන්ගේ': 'අතරමැදි',
#  'අතරමැදියන්ට': 'අතරමැදි',
#  'අතරමැදියා': 'අතරමැදි',
#  'අතරමැදියෙකු': 'අතරමැදි',
#  'අතරමැදියෙකුගේ': 'අතරමැදි',
#  'අතරයිතරඟය': 'අතරයිතරඟ',
#  'අතරවරයන්': 'අතරවර',
#  'අතරවරයන්ට': 'අතරවර',
#  'අතරවාරයේදීය': 'අතරවාරයේදී',
#  'අතරුදන්ව': 'අතරුදන්',
#  'අතවරය': 'අතවර',
#  'අතවරයකට': 'අතවර',
#  'අතවරයක්': 'අතවර',
#  'අතවරයට': 'අතවර',
#  'අතවරයන්': 'අතවර',
#  'අතවරයන්ට': 'අතවර',
#  'අතහරින': 'අතහරි',
#  'අතහරිනවා': 'අතහරි',
#  'අතහරින්න': 'අතහරි',
#  'අතහරින්නට': 'අතහරි',
#  'අතහැරලා': 'අතහැරල',
#  'අතහැරිය': 'අතහැරි',
#  'අතහැරියා': 'අතහැරි',
#  'අතහැරියේ': 'අතහැරි',
#  'අතහැරීමට': 'අතහැරීම',
#  'අතහැරීමෙන්': 'අතහැරීම',
#  'අත්අඩංගුවට': 'අත්අඩංගුව',
#  'අත්කරගත්': 'අත්කරගත',
#  'අත්කරගැනීමට': 'අත්කරගැනීම',
#  'අත්කරගැනීමෙන්': 'අත්කරගැනීම',
#  'අත්කරදෙනු': 'අත්කරදෙන',
#  'අත්තකට': 'අත්තක',
#  'අත්තක්': 'අත්තක',
#  'අත්තනායකගේ': 'අත්තනායක',
#  'අත්තනායකට': 'අත්තනායක',
#  'අත්තනෝමතිකව': 'අත්තනෝමතික',
#  'අත්තම්මාගේ': 'අත්තම්මා',
#  'අත්තම්මාට': 'අත්තම්මා',
#  'අත්තිඩියෙ': 'අත්තිඩිය',
#  'අත්තිඩියේ': 'අත්තිඩිය',
#  'අත්තිවාරම්': 'අත්තිවාරම',
#  'අත්තිවාරමෙන්': 'අත්තිවාරම',
#  'අත්දැකීමකට': 'අත්දැකීමක',
#  'අත්දැකීමක්': 'අත්දැකීමක',
#  'අත්දැකීම්වලට': 'අත්දැකීම්',
#  'අත්පත්කරගැනීම්': 'අත්පත්කරගැනීම',
#  'අත්පත්රිකාව': 'අත්පත්රිකා',
#  'අත්පත්රිකාවක්': 'අත්පත්රිකා',
#  'අත්පත්රිකාවකින්': 'අත්පත්රිකා',
#  'අත්පත්රිකාවට': 'අත්පත්රිකා',
#  'අත්පත්රිකාවේ': 'අත්පත්රිකා',
#  'අත්පාවලට': 'අත්පා',
#  'අත්පොතක්': 'අත්පොත',
#  'අත්පොතද': 'අත්පොත',
#  'අත්බෝම්බයක්': 'අත්බෝම්බය',
#  'අත්යාවශ්යම': 'අත්යාවශ්ය',
#  'අත්යාවශ්යය': 'අත්යාවශ්ය',
#  'අත්යාවශ්යයි': 'අත්යාවශ්ය',
#  'අත්යාවශ්යව': 'අත්යාවශ්ය',
#  'අත්ලාන්තික්': 'අත්ලාන්තික',
#  'අත්වන': 'අත්ව',
#  'අත්වන්නට': 'අත්ව',
#  'අත්වන්නේ': 'අත්ව',
#  'අත්වනු': 'අත්ව',
#  'අත්වයේ': 'අත්ව',
#  'අත්වල': 'අත්ව',
#  'අත්වැරැද්දක්': 'අත්වැරැද්ද',
#  'අත්වැරැද්දකින්': 'අත්වැරැද්ද',
#  'අත්වැලක්': 'අත්වැල',
#  'අත්වැල්': 'අත්වැල',
#  'අත්විඳින': 'අත්විඳි',
#  'අත්විඳිනවා': 'අත්විඳි',
#  'අත්විඳින්න': 'අත්විඳි',
#  'අත්වීමට': 'අත්වී',
#  'අත්වූයේ': 'අත්වූ',
#  'අත්වෙන්නේ': 'අත්වෙන්න',
#  'අත්වේද': 'අත්වේ',
#  'අත්වේවා': 'අත්වේ',
#  'අත්සනක්': 'අත්සන',
#  'අත්සනට': 'අත්සන',
#  'අත්සනත්': 'අත්සන',
#  'අත්සනද': 'අත්සන',
#  'අත්සන්': 'අත්සන',
#  'අත්හදාබැලීමක්': 'අත්හදාබැලීමක',
#  'අත්හදාබැලීම්වලට': 'අත්හදාබැලීම්',
#  'අත්හදාබැලූනු': 'අත්හදාබැලූ',
#  'අත්හරිනවා': 'අත්හරින',
#  'අත්හරින්නට': 'අත්හරින්න',
#  'අත්හරීමට': 'අත්හරී',
#  'අත්හැරියා': 'අත්හැරිය',
#  'අත්හැරීමට': 'අත්හැරීම',
#  'අත්හැරීමත්': 'අත්හැරීම',
#  'අත්හිටවුූ': 'අත්හිටවු',
#  'අත්හිටවූයේ': 'අත්හිටවූ',
#  'අත්හිටවූවද': 'අත්හිටවූ',
#  'අත්හිටවූවා': 'අත්හිටවූ',
#  'අත්හිටුවනවා': 'අත්හිටුවන',
#  'අත්හිටුවීමට': 'අත්හිටුවීම',
#  'අත්හිටුවීමටත්': 'අත්හිටුවීම',
#  'අත්හිටුවුවා': 'අත්හිටුවුව',
#  'අතැතිවයි': 'අතැතිව',
#  'අතින්ද': 'අතින්',
#  'අතින්ම': 'අතින්',
#  'අතිරික්තය': 'අතිරික්ත',
#  'අතිරික්තයක්': 'අතිරික්ත',
#  'අතිරික්තව': 'අතිරික්ත',
#  'අතිරිත්තය': 'අතිරිත්ත',
#  'අතිරිත්තයක්': 'අතිරිත්ත',
#  'අතිශයින්': 'අතිශය',
#  'අතිසාර්ථකව': 'අතිසාර්ථක',
#  'අතීතය': 'අතීත',
#  'අතීතයක': 'අතීත',
#  'අතීතයකට': 'අතීත',
#  'අතීතයක්': 'අතීත',
#  'අතීතයට': 'අතීත',
#  'අතීතයේද': 'අතීතයේ',
#  'අතීසාරයට': 'අතීසාරය',
#  'අතුකෝරලගේ': 'අතුකෝරල',
#  'අතුකෝරලට': 'අතුකෝරල',
#  'අතුකෝරළගේ': 'අතුකෝරළ',
#  'අතුකෝරළට': 'අතුකෝරළ',
#  'අතුකෝරාළගෙන්': 'අතුකෝරාළ',
#  'අතුගාන්න': 'අතුගා',
#  'අතුරතුරදීය': 'අතුරතුරදී',
#  'අතුරලියේ': 'අතුරලිය',
#  'අතුරුගිරියේ': 'අතුරුගිරිය',
#  'අතුරුදන්වන': 'අතුරුදන්ව',
#  'අතුරුදන්වයි': 'අතුරුදන්ව',
#  'අතුරුදන්වී': 'අතුරුදන්ව',
#  'අතුරුදන්වීම': 'අතුරුදන්ව',
#  'අතුරුදන්වීමක්': 'අතුරුදන්ව',
#  'අතුරුදන්වීමට': 'අතුරුදන්ව',
#  'අතුරුදන්වුයේ': 'අතුරුදන්වු',
#  'අතුරුදන්වුවන්': 'අතුරුදන්වු',
#  'අතුරුදන්වුවන්ගේ': 'අතුරුදන්වු',
#  'අතුරුදන්වූන්ගේ': 'අතුරුදන්වූ',
#  'අතුරුදන්වූවන්': 'අතුරුදන්වූ',
#  'අතුරුදන්වූවන්ගේ': 'අතුරුදන්වූ',
#  'අතුරුදහන්ව': 'අතුරුදහන්',
#  'අතුරුදහන්වීම': 'අතුරුදහන්වී',
#  'අතුරුදහන්වූවන්': 'අතුරුදහන්වූ',
#  'අතුරුදහන්වූවන්ගේ': 'අතුරුදහන්වූ',
#  'අතුලත්': 'අතුල',
#  'අතුවලින්': 'අතුවල',
#  'අතුළත්': 'අතුළත',
#  'අදටත්': 'අදට',
#  'අදමා': 'අදම',
#  'අදයිතරගයේ': 'අදයිතරගය',
#  'අදයිතරඟයේ': 'අදයිතරඟය',
#  'අදවන්': 'අදවන',
#  'අදහන්න': 'අදහන්',
#  'අදහසක්': 'අදහසක',
#  'අදහසකින්': 'අදහසකි',
#  'අදහස්ද': 'අදහස්',
#  'අදහස්ය': 'අදහස්',
#  'අදහස්ල': 'අදහස්',
#  'අදහස්වලට': 'අදහස්වල',
#  'අදහස්වලින්': 'අදහස්වල',
#  'අදළා': 'අදළ',
#  'අද්දරආරච්චිව': 'අද්දරආරච්චි',
#  'අදායමක්': 'අදායම',
#  'අදායම්': 'අදායම',
#  'අදාලවයි': 'අදාලව',
#  'අදාළවත්': 'අදාළව',
#  'අදාළවද': 'අදාළව',
#  'අදාළවන': 'අදාළව',
#  'අදාළවය': 'අදාළව',
#  'අදිකරණයට': 'අදිකරණය',
#  'අදිකරණයේ': 'අදිකරණය',
#  'අදිකාරම්ගේ': 'අදිකාරම්',
#  'අදිකාරියේ': 'අදිකාරිය',
#  'අදිටන්': 'අදිටන',
#  'අදිටනින්': 'අදිටන',
#  'අදිනවද': 'අදින',
#  'අදිනවා': 'අදින',
#  'අදින්': 'අදින',
#  'අදින්නට': 'අදින්න',
#  'අදින්නත්': 'අදින්න',
#  'අදින්නේ': 'අදින්න',
#  'අදියරකට': 'අදියරක',
#  'අදියරක්': 'අදියරක',
#  'අදියරයක්': 'අදියරය',
#  'අදියරයට': 'අදියරය',
#  'අදියරයන්': 'අදියරය',
#  'අදූරදර්ශීව': 'අදූරදර්ශී',
#  'අදෝනාව': 'අදෝනා',
#  'අදෝනාවෙන්': 'අදෝනා',
#  'අධයාපනයේ': 'අධයාපනය',
#  'අධ්යක්ෂකවරයකුගේම': 'අධ්යක්ෂකවරයකු',
#  'අධ්යක්ෂකවරයාගේ': 'අධ්යක්ෂකවරයා',
#  'අධ්යක්ෂකවරයාට': 'අධ්යක්ෂකවරයා',
#  'අධ්යක්ෂකවරයෙකුගේ': 'අධ්යක්ෂකවරයෙකු',
#  'අධ්යක්ෂකවරියගේ': 'අධ්යක්ෂකවරිය',
#  'අධ්යක්ෂකවරුන්ගේ': 'අධ්යක්ෂකවරුන්',
#  'අධ්යක්ෂකවරුන්ට': 'අධ්යක්ෂකවරුන්',
#  'අධ්යක්ෂණයක්': 'අධ්යක්ෂණය',
#  'අධ්යක්ෂවරයාගෙන්': 'අධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයාගේ': 'අධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයාට': 'අධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයාද': 'අධ්යක්ෂවරයා',
#  'අධ්යක්ෂවරයෙකුගේ': 'අධ්යක්ෂවරයෙකු',
#  'අධ්යක්ෂවරියකගෙන්': 'අධ්යක්ෂවරියක',
#  'අධ්යක්ෂවරියක්': 'අධ්යක්ෂවරියක',
#  'අධ්යක්ෂවරුන්': 'අධ්යක්ෂවරු',
#  'අධ්යක්ෂවරුන්ගෙන්': 'අධ්යක්ෂවරු',
#  'අධ්යක්ෂවරුන්ගේ': 'අධ්යක්ෂවරු',
#  'අධ්යක්ෂවරුන්ට': 'අධ්යක්ෂවරු',
#  'අධ්යක්ෂිකාව': 'අධ්යක්ෂිකා',
#  'අධ්යක්ෂිකාවක': 'අධ්යක්ෂිකා',
#  'අධ්යක්ෂිකාවක්': 'අධ්යක්ෂිකා',
#  'අධ්යක්ෂිකාවට': 'අධ්යක්ෂිකා',
#  'අධ්යනය': 'අධ්යන',
#  'අධ්යනයක': 'අධ්යන',
#  'අධ්යපනය': 'අධ්යපන',
#  'අධ්යයනයකදීයි': 'අධ්යයනයකදී',
#  'අධ්යයනයන්': 'අධ්යයනයන',
#  'අධ්යයනයන්වල': 'අධ්යයනයන',
#  'අධ්යයනාංශයේ': 'අධ්යයනාංශය',
#  'අධ්යානයට': 'අධ්යාන',
#  'අධ්යාපනයකට': 'අධ්යාපනය',
#  'අධ්යාපනයක්': 'අධ්යාපනය',
#  'අධ්යාපනයට': 'අධ්යාපනය',
#  'අධ්යාපනයටත්': 'අධ්යාපනය',
#  'අධ්යාපනයත්': 'අධ්යාපනය',
#  'අධ්යාපනයද': 'අධ්යාපනය',
#  'අධ්යාපනයම': 'අධ්යාපනය',
#  'අධ්යාපනයෙන්ද': 'අධ්යාපනයෙන්',
#  'අධිකණයක්': 'අධිකණ',
#  'අධිකණයේ': 'අධිකණ',
#  'අධිකරණක්': 'අධිකරණ',
#  'අධිකරණට': 'අධිකරණ',
#  'අධිකරණයකට': 'අධිකරණයක',
#  'අධිකරණයක්ද': 'අධිකරණයක්',
#  'අධිකරණයටත්': 'අධිකරණයට',
#  'අධිකරණයටද': 'අධිකරණයට',
#  'අධිකරණයටයි': 'අධිකරණයට',
#  'අධිකරණයන්ට': 'අධිකරණයන්',
#  'අධිකරණයේත්': 'අධිකරණයේ',
#  'අධිකරණයේදීත්': 'අධිකරණයේදී',
#  'අධිකරණවලට': 'අධිකරණවල',
#  'අධිකරණවලින්': 'අධිකරණවල',
#  'අධිකරනය': 'අධිකරන',
#  'අධිකරනයට': 'අධිකරන',
#  'අධිකරියට': 'අධිකරිය',
#  'අධිකරියයි': 'අධිකරිය',
#  'අධිකරීවරයාට': 'අධිකරී',
#  'අධික්ෂණය': 'අධික්ෂණ',
#  'අධික්ෂණයක': 'අධික්ෂණ',
#  'අධික්ෂණයක්': 'අධික්ෂණ',
#  'අධිකාරම': 'අධිකාර',
#  'අධිකාරම්': 'අධිකාර',
#  'අධිකාරය': 'අධිකාර',
#  'අධිකාරිගෙන්': 'අධිකාරි',
#  'අධිකාරිට': 'අධිකාරි',
#  'අධිකාරියකට': 'අධිකාරියක',
#  'අධිකාරියක්': 'අධිකාරියක',
#  'අධිකාරියටත්': 'අධිකාරියට',
#  'අධිකාරියටද': 'අධිකාරියට',
#  'අධිකාරියටය': 'අධිකාරියට',
#  'අධිකාරියේත්': 'අධිකාරියේ',
#  'අධිකාරියේද': 'අධිකාරියේ',
#  'අධිකාරිවරයාගෙන්': 'අධිකාරිවරයා',
#  'අධිකාරිවරයාගේ': 'අධිකාරිවරයා',
#  'අධිකාරිවරයාට': 'අධිකාරිවරයා',
#  'අධිකාරිවරයෙකුගේ': 'අධිකාරිවරයෙකු',
#  'අධිකාරිවරියගෙන්': 'අධිකාරිවරිය',
#  'අධිකාරිවරියන්': 'අධිකාරිවරිය',
#  'අධිකාරිවරුන්': 'අධිකාරිවරු',
#  'අධිකාරීට': 'අධිකාරී',
#  'අධිකාරීත්වයකින්': 'අධිකාරීත්වය',
#  'අධිකාරීන්ට': 'අධිකාරීන්',
#  'අධිකාරීයට': 'අධිකාරීය',
#  'අධිකාරීයටත්': 'අධිකාරීය',
#  'අධිකාරීයේ': 'අධිකාරීය',
#  'අධිකාරීවරයකුගේ': 'අධිකාරීවරයකු',
#  'අධිකාරීවරයාගෙන්': 'අධිකාරීවරයා',
#  'අධිකාරීවරයාගේ': 'අධිකාරීවරයා',
#  'අධිකාරීවරයාට': 'අධිකාරීවරයා',
#  'අධිකාරීවරයාත්': 'අධිකාරීවරයා',
#  'අධිකාරීවරයෙකුගේ': 'අධිකාරීවරයෙකු',
#  'අධිකාරීවරියගේ': 'අධිකාරීවරිය',
#  'අධිකාරීවරියන්': 'අධිකාරීවරිය',
#  'අධිකාරීවරුන්': 'අධිකාරීවරු',
#  'අධිකාරීවරුන්ට': 'අධිකාරීවරු',
#  'අධිචෝදනාවලට': 'අධිචෝදනා',
#  'අධිත්යනාත්ගේ': 'අධිත්යනාත්',
#  'අධිපත්ය': 'අධිපත්',
#  'අධිපතිගෙන්': 'අධිපති',
#  'අධිපතිගේ': 'අධිපති',
#  'අධිපතිට': 'අධිපති',
#  'අධිපතිත්': 'අධිපති',
#  'අධිපතිවරයාගෙන්': 'අධිපතිවරයා',
#  'අධිපතිවරයාගේ': 'අධිපතිවරයා',
#  'අධිපතිවරයාට': 'අධිපතිවරයා',
#  'අධිපතිවරයාද': 'අධිපතිවරයා',
#  'අධිපතිවරයාව': 'අධිපතිවරයා',
#  'අධිපතිවරුන්ගේ': 'අධිපතිවරුන්',
#  'අධිබලති': 'අධිබල',
#  'අධිභාරය': 'අධිභාර',
#  'අධිභාරයක්': 'අධිභාර',
#  'අධිරාජයාගේ': 'අධිරාජයා',
#  'අධිරාජයාටත්': 'අධිරාජයා',
#  'අධිරාජ්යයට': 'අධිරාජ්ය',
#  'අධිරාජ්යයා': 'අධිරාජ්ය',
#  'අධිරාජ්යයාගෙන්': 'අධිරාජ්ය',
#  'අධිරාජ්යයාගේ': 'අධිරාජ්ය',
#  'අධිරාජ්යයාට': 'අධිරාජ්ය',
#  'අධිරාජ්යවාදීන්': 'අධිරාජ්යවාදී',
#  'අධිරාජ්යවාදීන්ගේ': 'අධිරාජ්යවාදී',
#  'අධිවේගය': 'අධිවේග',
#  'අධිවේගයට': 'අධිවේග',
#  'අධිවේගයටත්': 'අධිවේග',
#  'අධිවේගයේ': 'අධිවේග',
#  'අධිවේගයේත්': 'අධිවේග',
#  'අධිවේගයේදී': 'අධිවේග',
#  'අධිවේගියේ': 'අධිවේගි',
#  'අධිශිෂ්යත්වයක්': 'අධිශිෂ්යත්වය',
#  'අධිෂ්ඨානය': 'අධිෂ්ඨාන',
#  'අධීකරණය': 'අධීකරණ',
#  'අධීකරණයට': 'අධීකරණ',
#  'අධීකරණයෙන්': 'අධීකරණ',
#  'අධීක්ෂණය': 'අධීක්ෂණ',
#  'අධීක්ෂණයකට': 'අධීක්ෂණ',
#  'අධීක්ෂණයක්': 'අධීක්ෂණ',
#  'අධීක්ෂණයකින්': 'අධීක්ෂණ',
#  'අධීක්ෂණයට': 'අධීක්ෂණ',
#  'අධීක්ෂණයන්': 'අධීක්ෂණ',
#  'අධීක්ෂණයෙන්': 'අධීක්ෂණ',
#  'අධීක්ෂණයේ': 'අධීක්ෂණ',
#  'අධීකාරිය': 'අධීකාරි',
#  'අධීකාරියේ': 'අධීකාරි',
#  'අධෛර්යට': 'අධෛර්ය',
#  'අනතරට': 'අනතර',
#  'අනතර්': 'අනතර',
#  'අනතුරකට': 'අනතුරක',
#  'අනතුරක්ක්': 'අනතුරක්',
#  'අනතුරටත්': 'අනතුරට',
#  'අනතුරවයි': 'අනතුරව',
#  'අනතුරිකින්': 'අනතුරි',
#  'අනතුරින්': 'අනතුරි',
#  'අනතුරුදායකයි': 'අනතුරුදායක',
#  'අනතුරුවත්': 'අනතුරුව',
#  'අනතුරුවද': 'අනතුරුව',
#  'අනතුරුවය': 'අනතුරුව',
#  'අනතුරුවලකා': 'අනතුරුවල',
#  'අනතුරුවලට': 'අනතුරුවල',
#  'අනතුරුවලින්': 'අනතුරුවල',
#  'අනන්තයි': 'අනන්ත',
#  'අනන්තවත්': 'අනන්ත',
#  'අනන්යතාව': 'අනන්යතා',
#  'අනන්යතාවක්': 'අනන්යතා',
#  'අනන්යතාවට': 'අනන්යතා',
#  'අනන්යතාවයක්': 'අනන්යතාවය',
#  'අනන්යතාවයකින්': 'අනන්යතාවය',
#  'අනන්යතාවයන්': 'අනන්යතාවය',
#  'අනන්යතාවයයි': 'අනන්යතාවය',
#  'අනපේක්ෂිතව': 'අනපේක්ෂිත',
#  'අනවබෝධයෙන්': 'අනවබෝධය',
#  'අනවශ්යම': 'අනවශ්ය',
#  'අනවශ්යය': 'අනවශ්ය',
#  'අනවශ්යයයි': 'අනවශ්ය',
#  'අනවශ්යයි': 'අනවශ්ය',
#  'අනවශ්යව': 'අනවශ්ය',
#  'අනවසරයෙන්': 'අනවසර',
#  'අනවසරෙන්': 'අනවසර',
#  'අන්තයකම': 'අන්තයක',
#  'අන්තයක්': 'අන්තයක',
#  'අන්තයකින්': 'අන්තයක',
#  'අන්තයටම': 'අන්තයට',
#  'අන්තයේදීත්': 'අන්තයේදී',
#  'අන්තරජාලයට': 'අන්තරජාලය',
#  'අන්තර්ගතය': 'අන්තර්ගත',
#  'අන්තර්ගතයන්': 'අන්තර්ගත',
#  'අන්තර්ගතයි': 'අන්තර්ගත',
#  'අන්තර්ගතවේ': 'අන්තර්ගතව',
#  'අන්තර්ජාතිකව': 'අන්තර්ජාතික',
#  'අන්තර්ජාලය': 'අන්තර්ජාල',
#  'අන්තර්ජාලයට': 'අන්තර්ජාල',
#  'අන්තර්ජාලයටත්': 'අන්තර්ජාල',
#  'අන්තරේට': 'අන්තරේ',
#  'අන්තවාදයකට': 'අන්තවාදය',
#  'අන්තවාදිගේ': 'අන්තවාදි',
#  'අන්තවාදින්': 'අන්තවාදි',
#  'අන්තවාදින්ට': 'අන්තවාදි',
#  'අන්තවාදියා': 'අන්තවාදි',
#  'අන්තවාදියෙකු': 'අන්තවාදි',
#  'අන්තවාදීන්': 'අන්තවාදී',
#  'අන්තවාදීන්ගෙන්': 'අන්තවාදී',
#  'අන්තවාදීන්ගේ': 'අන්තවාදී',
#  'අන්තවාදීන්ට': 'අන්තවාදී',
#  'අන්තවාදීව': 'අන්තවාදී',
#  'අන්ත්රවල': 'අන්ත්ර',
#  'අන්තිමට': 'අන්තිම',
#  'අන්තිමයා': 'අන්තිම',
#  'අන්තිමයි': 'අන්තිම',
#  'අන්තිමේට': 'අන්තිම',
#  'අන්දමට': 'අන්දම',
#  'අන්දමන්': 'අන්දම',
#  'අන්ධභාවයට': 'අන්ධභාවය',
#  'අන්නෝන්යම': 'අන්නෝන්ය',
#  'අන්යයන්ට': 'අන්ය',
#  'අන්යාගමිකයන්': 'අන්යාගමික',
#  'අන්යාගමිකයින්ට': 'අන්යාගමිකයින්',
#  'අන්සාර්ගෙන්': 'අන්සාර්',
#  'අනාගතය': 'අනාගත',
#  'අනාගතයකට': 'අනාගත',
#  'අනාගතයක්': 'අනාගත',
#  'අනාගතයට': 'අනාගත',
#  'අනාගතයටත්': 'අනාගත',
#  'අනාගතයේත්': 'අනාගතයේ',
#  'අනාථාගාරය': 'අනාථාගාර',
#  'අනාථාගාරයට': 'අනාථාගාර',
#  'අනාථාගාරයෙන්': 'අනාථාගාර',
#  'අනාථාගාරයේ': 'අනාථාගාර',
#  'අනාථාගාරයේදී': 'අනාථාගාර',
#  'අනාරාධිතවම': 'අනාරාධිතව',
#  'අනාවණය': 'අනාවණ',
#  'අනාවරණය': 'අනාවරණ',
#  'අනාවරණයකට': 'අනාවරණ',
#  'අනාවරණයවීම': 'අනාවරණයවී',
#  'අනාවරණවී': 'අනාවරණව',
#  'අනාවරනය': 'අනාවරන',
#  'අනාවැකියක්': 'අනාවැකිය',
#  'අනාවැකිවලින්': 'අනාවැකිවල',
#  'අනික්': 'අනික',
#  'අනිකා': 'අනික',
#  'අනිද්දා': 'අනිද්ද',
#  'අනිද්දාට': 'අනිද්ද',
#  'අනින්': 'අනින',
#  'අනින්නට': 'අනින්න',
#  'අනින්නෙ': 'අනින්න',
#  'අනින්නේ': 'අනින්න',
#  'අනියත්': 'අනියත',
#  'අනියුක්තව': 'අනියුක්ත',
#  'අනිවාරයෙන්ම': 'අනිවාරයෙන්',
#  'අනිවාර්යය': 'අනිවාර්ය',
#  'අනිවාර්යයි': 'අනිවාර්ය',
#  'අනිවාර්යයෙන්ම': 'අනිවාර්යයෙන්',
#  'අනිවාර්යෙන්ම': 'අනිවාර්යෙන්',
#  'අනීකා': 'අනී',
#  'අනීතිකව': 'අනීතික',
#  'අනුකම්පාව': 'අනුකම්පා',
#  'අනුකම්පාවක්': 'අනුකම්පා',
#  'අනුකම්පාවෙන්': 'අනුකම්පා',
#  'අනුකමිටුව': 'අනුකමිටු',
#  'අනුකමිටුවකට': 'අනුකමිටු',
#  'අනුකමිටුවක්': 'අනුකමිටු',
#  'අනුකමිටුවට': 'අනුකමිටු',
#  'අනුකමිටුවල': 'අනුකමිටු',
#  'අනුකමිටුවලින්': 'අනුකමිටු',
#  'අනුකමිටුවේ': 'අනුකමිටු',
#  'අනුකරණයට': 'අනුකරණය',
#  'අනුකුලව': 'අනුකුල',
#  'අනුකූලතාව': 'අනුකූලතා',
#  'අනුකූලවන': 'අනුකූලව',
#  'අනුකූලවම': 'අනුකූලව',
#  'අනුකූලවයි': 'අනුකූලව',
#  'අනුඛණ්ඩයට': 'අනුඛණ්ඩ',
#  'අනුගතව': 'අනුගත',
#  'අනුග්රහයක්': 'අනුග්රහය',
#  'අනුග්රහයද': 'අනුග්රහය',
#  'අනුග්රහයෙන්': 'අනුග්රහය',
#  'අනුග්රාහකත්වයද': 'අනුග්රාහකත්වය',
#  'අනුග්රාහකත්වයෙන්': 'අනුග්රාහකත්වය',
#  'අනුගාමිකයන්ගෙන්': 'අනුගාමිකයන්',
#  'අනුගාමිකයන්ගේ': 'අනුගාමිකයන්',
#  'අනුගාමිකයන්ට': 'අනුගාමිකයන්',
#  'අනුත්තරා': 'අනුත්තර',
#  'අනුදැනීමෙන්': 'අනුදැන',
#  'අනුදැනුම': 'අනුදැන',
#  'අනුදැනුමකින්': 'අනුදැන',
#  'අනුනවය': 'අනුනව',
#  'අනුන්ගෙන්': 'අනුන්',
#  'අනුන්ගේ': 'අනුන්',
#  'අනුන්ට': 'අනුන්',
#  'අනුනාහිමියන්': 'අනුනාහිමි',
#  'අනුනාහිමියන්ගෙන්': 'අනුනාහිමි',
#  'අනුනාහිමියන්ගේ': 'අනුනාහිමි',
#  'අනුනාහිමිවරුන්': 'අනුනාහිමි',
#  'අනුප්රාප්තිකයා': 'අනුප්රාප්තික',
#  'අනුප්රාප්තිකයෙකු': 'අනුප්රාප්තික',
#  'අනුපාතයකට': 'අනුපාතය',
#  'අනුපාතයක්ද': 'අනුපාතයක්',
#  'අනුපාතවලට': 'අනුපාතවල',
#  'අනුපාතිකය': 'අනුපාතික',
#  'අනුපාතිකයක්': 'අනුපාතික',
#  'අනුපාතිකයන්ට': 'අනුපාතික',
#  'අනුපාතිකයේ': 'අනුපාතික',
#  'අනුබද්ධව': 'අනුබද්ධ',
#  'අනුබද්ධවයි': 'අනුබද්ධ',
#  'අනුබද්ධිතව': 'අනුබද්ධිත',
#  'අනුබලදීම': 'අනුබලදී',
#  'අනුබලදීමක්': 'අනුබලදී',
#  'අනුබලදීමේ': 'අනුබලදී',
#  'අනුබලයක්': 'අනුබලය',
#  'අනුභවයට': 'අනුභවය',
#  'අනුභවයෙන්': 'අනුභවය',
#  'අනුමතයි': 'අනුමත',
#  'අනුමැතිය': 'අනුමැති',
#  'අනුමැතියක්': 'අනුමැති',
#  'අනුමැතීන්ගෙන්': 'අනුමැතීන්',
#  'අනුමැතීන්ට': 'අනුමැතීන්',
#  'අනුයුක්තව': 'අනුයුක්ත',
#  'අනුයුක්තවයි': 'අනුයුක්ත',
#  'අනුයුත්තව': 'අනුයුත්ත',
#  'අනුරපුරට': 'අනුරපුර',
#  'අනුරපුරයට': 'අනුරපුර',
#  'අනුරපුරයෙන්': 'අනුරපුර',
#  'අනුරපුරයේ': 'අනුරපුර',
#  'අනුරපුරයේදී': 'අනුරපුර',
#  'අනුරාධපුරට': 'අනුරාධපුර',
#  'අනුරාධපුරය': 'අනුරාධපුර',
#  'අනුරාධපුරයට': 'අනුරාධපුර',
#  'අනුරාධපුරයටත්': 'අනුරාධපුර',
#  'අනුරාධපුරයේත්': 'අනුරාධපුරයේ',
#  'අනුරාධපුරේට': 'අනුරාධපුරේ',
#  'අනුරුද්ධගෙන්': 'අනුරුද්ධ',
#  'අනුරුද්ධට': 'අනුරුද්ධ',
#  'අනුරුවක්': 'අනුරුව',
#  'අනුශාසකවරුන්ට': 'අනුශාසකවරුන්',
#  'අනුශාසනාව': 'අනුශාසනා',
#  'අනුශාසනාවක්': 'අනුශාසනා',
#  'අනුශාසනාවලින්': 'අනුශාසනා',
#  'අනුශූරතාවය': 'අනුශූරතාව',
#  'අනුශූරතාවෙන්': 'අනුශූරතාව',
#  'අනුශූරයන්ට': 'අනුශූරයන්',
#  'අනුෂ්කා': 'අනුෂ්ක',
#  'අනුෂාන්': 'අනුෂා',
#  'අනුෂිකා': 'අනුෂික',
#  'අනුස්මරණය': 'අනුස්මරණ',
#  'අනුස්මරණයට': 'අනුස්මරණ',
#  'අනුස්මරණීය': 'අනුස්මරණ',
#  'අනුහසක්': 'අනුහස',
#  'අනූදහසක්': 'අනූදහසක',
#  'අනූනව': 'අනූන',
#  'අනූවකට': 'අනූව',
#  'අනූවක්': 'අනූව',
#  'අනූෂා': 'අනූෂ',
#  'අනෙකත්': 'අනෙක',
#  'අනෙක්': 'අනෙක',
#  'අනෙකාගේ': 'අනෙකා',
#  'අනෙකුත්': 'අනෙකු',
#  'අඳුනක්': 'අඳුන',
#  'අඳුන්': 'අඳුන',
#  'අඳූරු': 'අඳූර',
#  'අපක්ෂපාතිව': 'අපක්ෂපාති',
#  'අපක්ෂපාතීත්වයට': 'අපක්ෂපාතීත්වය',
#  'අපකීර්තිමත්ම': 'අපකීර්තිමත්',
#  'අපකීර්තියක්': 'අපකීර්තිය',
#  'අපකීර්තියට': 'අපකීර්තිය',
#  'අපගමනයකට': 'අපගමනය',
#  'අපගමනයක්': 'අපගමනය',
#  'අපගමනයන්': 'අපගමනය',
#  'අපගමනයයි': 'අපගමනය',
#  'අපගේද': 'අපගේ',
#  'අපචාරය': 'අපචාර',
#  'අපචාරයට': 'අපචාර',
#  'අපචාරයන්': 'අපචාර',
#  'අපචාරයන්ගෙන්': 'අපචාර',
#  'අපචාරයන්ට': 'අපචාර',
#  'අපජලය': 'අපජල',
#  'අපජලයේ': 'අපජල',
#  'අපටත්': 'අපට',
#  'අපටද': 'අපට',
#  'අපතේයාමක්': 'අපතේයාම',
#  'අපද්රව්යයක්': 'අපද්රව්යය',
#  'අපද්රව්යවලට': 'අපද්රව්යවල',
#  'අපද්රව්යවලින්': 'අපද්රව්යවල',
#  'අපදාවන්ට': 'අපදාවන්',
#  'අපනයනකරුවන්ගේ': 'අපනයනකරුවන්',
#  'අපනයනකරුවන්ට': 'අපනයනකරුවන්',
#  'අපනයනකරුවන්ටත්': 'අපනයනකරුවන්',
#  'අපනයනකරුවන්ද': 'අපනයනකරුවන්',
#  'අපනයනයටත්': 'අපනයනයට',
#  'අපනයනයටද': 'අපනයනයට',
#  'අපනයනයන්ට': 'අපනයනයන්',
#  'අපනයනයන්හි': 'අපනයනයන්',
#  'අපනයනවලට': 'අපනයනවල',
#  'අපමණයි': 'අපමණ',
#  'අපයෝජනය': 'අපයෝජන',
#  'අපයෝජනයකට': 'අපයෝජන',
#  'අපයෝජනයක්': 'අපයෝජන',
#  'අපයෝජනයට': 'අපයෝජන',
#  'අපයෝජනයන්': 'අපයෝජන',
#  'අපයෝජනයන්ගෙන්': 'අපයෝජන',
#  'අපරාජිතව': 'අපරාජිත',
#  'අපරාධකරුගේ': 'අපරාධකරු',
#  'අපරාධකරුට': 'අපරාධකරු',
#  'අපරාධකරුවකු': 'අපරාධකරු',
#  'අපරාධකරුවන්': 'අපරාධකරු',
#  'අපරාධකරුවන්ගේ': 'අපරාධකරු',
#  'අපරාධකරුවන්ට': 'අපරාධකරු',
#  'අපරාධයකට': 'අපරාධය',
#  'අපරාධයක්': 'අපරාධය',
#  'අපරාධයට': 'අපරාධය',
#  'අපරාධයන්': 'අපරාධය',
#  'අපරාධයන්ට': 'අපරාධය',
#  'අපරාධයෙන්': 'අපරාධය',
#  'අපරාධයේ': 'අපරාධය',
#  'අපරාධවලට': 'අපරාධවල',
#  'අපරාධවලින්': 'අපරාධවල',
#  'අපරික්ෂාකාරිව': 'අපරික්ෂාකාරි',
#  'අපරික්ෂාකාරීව': 'අපරික්ෂාකාරී',
#  'අපරීක්ෂාකාරීව': 'අපරීක්ෂාකාරී',
#  'අපලයක්': 'අපල',
#  'අපලයෙන්': 'අපල',
#  'අපවත්': 'අපව',
#  'අපවත්වන': 'අපවත්ව',
#  'අපවත්වීම': 'අපවත්වී',
#  'අපවාදයක්': 'අපවාද',
#  'අපවාදවලට': 'අපවාද',
#  'අපවිත්රවීම': 'අපවිත්රවී',
#  'අපස්මාරය': 'අපස්මාර',
#  'අපහරණය': 'අපහරණ',
#  'අපහරණයට': 'අපහරණ',
#  'අපහසයක්': 'අපහස',
#  'අපහසයට': 'අපහස',
#  'අපහසු': 'අපහස',
#  'අපහසුතාත්': 'අපහසුතා',
#  'අපහසුතාව': 'අපහසුතා',
#  'අපහසුතාවක': 'අපහසුතා',
#  'අපහසුතාවකට': 'අපහසුතා',
#  'අපහසුතාවටයි': 'අපහසුතාවට',
#  'අපහසුතාවන්ට': 'අපහසුතාවන්',
#  'අපහසුතාවයකට': 'අපහසුතාවය',
#  'අපහසුතාවයන්ට': 'අපහසුතාවයන්',
#  'අපහාසක්': 'අපහාස',
#  'අපහාසත්': 'අපහාස',
#  'අපහාසයක්': 'අපහාස',
#  'අපහාසයට': 'අපහාස',
#  'අප්පච්චිට': 'අප්පච්චි',
#  'අප්පච්චිව': 'අප්පච්චි',
#  'අප්පුගේ': 'අප්පු',
#  'අප්රමාණව': 'අප්රමාණ',
#  'අප්රසාදයක්': 'අප්රසාදය',
#  'අප්රසාදයට': 'අප්රසාදය',
#  'අප්රසාදයෙන්': 'අප්රසාදය',
#  'අප්රාණිකව': 'අප්රාණික',
#  'අප්රිකාණුවන්': 'අප්රිකාණු',
#  'අප්රිකානුවන්': 'අප්රිකානු',
#  'අප්රිකානුවන්ගෙන්': 'අප්රිකානු',
#  'අප්රිකානුවන්ට': 'අප්රිකානු',
#  'අප්රිකාවක්': 'අප්රිකාව',
#  'අප්රිකාවට': 'අප්රිකාව',
#  'අප්රිකාවටත්': 'අප්රිකාව',
#  'අප්රිකාවේදී': 'අප්රිකාව',
#  'අප්රිකාවේදීත්': 'අප්රිකාව',
#  'අප්රිකාවේ': 'අප්රිකාව',
#  'අපැහැදිලිකම': 'අපැහැදිලි',
#  'අපිට': 'අපි',
#  'අපිටම': 'අපි',
#  'අපිටමට': 'අපි',
#  'අපිටමම': 'අපි',
#  'අපිම': 'අපි',
#  'අපිමයි': 'අපි',
#  'අපිරිසිදුවීම': 'අපිරිසිදුව',
#  'අපිව': 'අපි',
#  'අපිවත්': 'අපි',
#  'අපි්රකානු': 'අපි්රකා',
#  'අපි්රකාව': 'අපි්රකා',
#  'අපි්රකාවට': 'අපි්රකා',
#  'අපි්රකාවේ': 'අපි්රකා',
#  'අපූරුවට': 'අපූරු',
#  'අපෙක්ෂාව': 'අපෙක්ෂා',
#  'අපෙක්ෂාවෙන්': 'අපෙක්ෂා',
#  'අපේකම': 'අපේ',
#  'අපේකෂකයන්ගේ': 'අපේකෂකයන්',
#  'අපේකෂාවයි': 'අපේකෂා',
#  'අපේකෂාවෙන්': 'අපේකෂා',
#  'අපේක්ෂකත්වයක්': 'අපේක්ෂක',
#  'අපේක්ෂකත්වයේ': 'අපේක්ෂක',
#  'අපේක්ෂකයන්': 'අපේක්ෂක',
#  'අපේක්ෂකයන්ගෙන්': 'අපේක්ෂක',
#  'අපේක්ෂකයන්ගේ': 'අපේක්ෂක',
#  'අපේක්ෂකයන්ට': 'අපේක්ෂක',
#  'අපේක්ෂකයාට': 'අපේක්ෂක',
#  'අපේක්ෂකයාත්': 'අපේක්ෂක',
#  'අපේක්ෂකයාව': 'අපේක්ෂක',
#  'අපේක්ෂකයින්ගේ': 'අපේක්ෂක',
#  'අපේක්ෂකයින්ට': 'අපේක්ෂක',
#  'අපේක්ෂකයෙකුට': 'අපේක්ෂක',
#  'අපේක්ෂණයක්': 'අපේක්ෂණ',
#  'අපේක්ෂණයේ': 'අපේක්ෂණ',
#  'අපේක්ෂාවක්': 'අපේක්ෂාවක',
#  'අපේක්ෂාවකින්': 'අපේක්ෂාවක',
#  'අපේක්ෂාවන්ට': 'අපේක්ෂාවන්',
#  'අපේක්ෂිකාව': 'අපේක්ෂිකා',
#  'අපේක්ෂිකාවක': 'අපේක්ෂිකා',
#  'අපේක්ෂිකාවකට': 'අපේක්ෂිකා',
#  'අපේක්ෂිකාවක්': 'අපේක්ෂිකා',
#  'අපේක්ෂිකාවන්': 'අපේක්ෂිකා',
#  'අපේක්ෂිකාවන්ට': 'අපේක්ෂිකා',
#  'අපේක්ෂිතය': 'අපේක්ෂිත',
#  'අපේගමේ': 'අපේගම',
#  'අපේ්ක්ෂකයාව': 'අපේ්ක්ෂකයා',
#  ...}

# %%
def stemming(text):
    for word in Dict:
        text = text.replace(word, Dict[word])
    return text

data["Title"] = data["Title"].apply(stemming)

# %%
data["Title"].head(20)
# Out:
# 0                    කොරෝනා වැලඳණු ට්‍රම්ප් අද ජන රැලික
# 1     ආර්ථික විද්‍යාව නොබෙල් ත්‍යාගය ඇමරිකාවන් දෙදෙනෙකු
# 2               ඉන්දියාව කොරෝනා ආසාදිතයන් ලක්ෂය ඉක්මවයි
# 3     කළු ජාතිකයෙකු ඩොලර මිලියනයක වන්දි ඉල්ලා ටෙක්සා...
# 4                             නේපාල සංචාරක ඇමතිට කොරෝනා
# 5     උතුරු කොරියාව ලොව විශාලත බැලස්ටික් මිසයිල ප්‍ර...
# 6          තායිලන්තේ බස් රථ අනතුරකින් විසිදෙනෙකු මියයයි
# 7         බ්‍රසීලයේ කොරෝනා මරණ එක්ලක්ෂ පනස් දහස ඉක්මවයි
# 8                   නොබෙල් සාම ත්‍යාගයට ට්‍රම්ප්ගේ නමත්
# 9         ඉන්දු චීන දේශසීමව චීනය අමතර සෙබළු යොදවා චෝදනා
# 10    රුසියාවෙන් වාර්තා වූ වැඩිම ආසාදිතයින් සංඛ්‍යාව...
# 11          කොරෝනා ප්‍රතිකාර නැවතූ ජනපති ට්‍රම්ප් කියයි
# 12             දකුණු කොරියාවේ මහල් ගොඩනැගිල්ක් ගිනි ගනී
# 13                   රුපියල ඩොලරට සාපේකෂව ශක්තිමත් වෙයි
# 14    කොවිඩ් වැළඳුණ ට්‍රම්ප් බයිඩ්න් මුහුණට මුහුණ වි...
# 15                            යුරෝපය කොරෝනා පැතිරී ඉහළට
# 16    ආවරණ මැද කෙරුණු ඇමරිකා උප ජනපති අපේක්ෂකගේ විවා...
# 17                ජපාන රටවල් විදෙස් ගමන් තහනම ඉවත් කරයි
# 18                              ඉරාන නේපාල යළි වසා දැමේ
# 19    චීනයේ සතුරු ක්‍රියාමාර්ගවල නිරත ඇමරිකා රාජ්‍ය ...
# Name: Title, dtype: object

# %%
'''
from nltk.stem import PorterStemmer
ps = PorterStemmer()

data["tweet"] = data["tweet"].apply(lambda x: " ".join(ps.stem(x) for x in x.split()))
data["tweet"].head()
'''
# Out:
# '\nfrom nltk.stem import PorterStemmer\nps = PorterStemmer()\n\ndata["tweet"] = data["tweet"].apply(lambda x: " ".join(ps.stem(x) for x in x.split()))\ndata["tweet"].head()\n'

# %%
data
# Out:
#                                                    Title          Label
# 0                     කොරෝනා වැලඳණු ට්‍රම්ප් අද ජන රැලික  International
# 1      ආර්ථික විද්‍යාව නොබෙල් ත්‍යාගය ඇමරිකාවන් දෙදෙනෙකු  International
# 2                ඉන්දියාව කොරෝනා ආසාදිතයන් ලක්ෂය ඉක්මවයි  International
# 3      කළු ජාතිකයෙකු ඩොලර මිලියනයක වන්දි ඉල්ලා ටෙක්සා...  International
# 4                              නේපාල සංචාරක ඇමතිට කොරෝනා  International
# ...                                                  ...            ...
# 26415                             එක්දින ලංකා සංචිත කෙරේ          Sport
# 26416          ආබාධ ක්‍රීඩකය් දෙනෙකුට හෙට තරඟ අහිමි කරයි          Sport
# 26417                          ලංකා ඕස්ට්‍රේලියා තරඟ හෙට          Sport
# 26418                               බංග්ලාදේශ පාකිස්ථායට          Sport
# 26419                     නවතම ක්‍රිකට් ශ්‍රේණිගත කිරීම්          Sport
#
# [25624 rows x 2 columns]

# %% [markdown]
# ### Building Vocabulary

# %%
from collections import Counter
vocab = Counter()

# %%
vocab
# Out:
# Counter()

# %%
for sentence in data['Title']:
    vocab.update(sentence.split())

# %%
vocab
# Out:
# Counter({'ලංකා': 1602,
#          'ඉන්දියාව': 1339,
#          'ක්\u200dරිකට්': 1038,
#          'තරඟ': 951,
#          'කරයි': 926,
#          'වෙයි': 926,
#          'අද': 852,
#          'මරුට': 798,
#          'කළ': 678,
#          'ලෝක': 616,
#          'ගුවන': 613,
#          'සුපිරි': 597,
#          'ජය': 579,
#          'ඡායාරූප': 569,
#          'අවසන': 569,
#          'ඇමරිකාව': 524,
#          'දකුණු': 512,
#          'ඉහළට': 506,
#          'මිල': 503,
#          'දෙනෙකු': 502,
#          'ටෙස්ට්': 488,
#          'පළමු': 486,
#          'ලකුණු': 473,
#          'වූ': 471,
#          'ඇමරිකා': 462,
#          'උතුරු': 459,
#          'ලංකාට': 456,
#          'යළි': 450,
#          'කියයි': 442,
#          'කට': 420,
#          'යයි': 419,
#          'හැටි': 418,
#          'ජනපති': 407,
#          'ට්\u200dරම්ප්': 368,
#          'ගනී': 356,
#          'කොරියාව': 355,
#          'දෙවන': 352,
#          'එරෙහි': 349,
#          'තරඟේ': 347,
#          'යි': 346,
#          'එක්දින': 346,
#          'ගිය': 341,
#          'කොටස්': 321,
#          'ක්\u200dරීඩා': 313,
#          'දේ': 305,
#          'කෙරේ': 298,
#          'ඇරඹේ': 289,
#          'ජයක්': 286,
#          'එංගලන්ත': 285,
#          'පසු': 275,
#          'කිරීමට': 269,
#          'විස්සයි': 265,
#          'තරඟට': 264,
#          'ඉහළ': 259,
#          'ලොව': 254,
#          'ප්\u200dරහාරයක්': 254,
#          'කණ්ඩාය': 251,
#          'කොරෝනා': 250,
#          'චීන': 247,
#          'වසර': 247,
#          'බංග්ලාදේශ': 246,
#          'පන්දු': 242,
#          'හිටපු': 238,
#          'චීනය': 234,
#          'හෙට': 230,
#          'අගමැති': 223,
#          'අත්අඩංගුව': 222,
#          'වෙඩි': 220,
#          'වී': 219,
#          'කණ්ඩායට': 219,
#          'ඉවත්': 217,
#          'මිලියන': 214,
#          'මාලිංග': 214,
#          'තෙල්': 213,
#          'විස්ස': 210,
#          'හමුද': 204,
#          'බෝම්බ': 203,
#          'වර්ධන': 203,
#          'පහළට': 203,
#          'ආසියානු': 203,
#          'නායකයා': 202,
#          'භූ': 196,
#          'අයිඑස්': 190,
#          'තේ': 190,
#          'පාකිස්තාන': 184,
#          'ඉලක්ක්': 183,
#          'ඩොලර': 181,
#          'ඇමරිකාවේ': 181,
#          'ඝාතන': 181,
#          'කුසලා': 179,
#          'කොදෙව්': 178,
#          'සංචිත': 177,
#          'නවසීලන්තය': 176,
#          'රන්': 176,
#          'IPL': 176,
#          'නැහැ': 175,
#          'කොරියා': 175,
#          'චෝදනා': 174,
#          'පාපන්දු': 174,
#          'ඉනිම': 172,
#          'සැරසේ': 169,
#          'ප්\u200dරහාරයකින්': 166,
#          'දිනය': 165,
#          'දැවැන්ත': 164,
#          'සූදානම්': 164,
#          'පිටිය': 164,
#          'කරමින්': 164,
#          'මියයයි': 163,
#          'කඩා': 163,
#          'මෝදි': 162,
#          'රුසියාව': 159,
#          'කර': 158,
#          'වාසිය': 157,
#          'මැතිව්ස්': 157,
#          'මියගිය': 156,
#          'යානක': 156,
#          'ගිනි': 155,
#          'පාකිස්ථා': 155,
#          'පහත': 154,
#          'පිල': 154,
#          'ජාත්\u200dයන්තර': 153,
#          'ඇමති': 152,
#          'ඉරාන': 151,
#          'ඔලිම්පික්': 150,
#          'වාර්තාව්': 149,
#          'අනතුරු': 148,
#          'නැවත': 148,
#          'කණ්ඩායේ': 147,
#          'චීනයේ': 146,
#          'දෙකක්': 145,
#          'දැඩි': 144,
#          'කාන්තා': 144,
#          'ලංකාේ': 143,
#          'අහිමි': 141,
#          'බ්\u200dරිතාන්\u200dය': 141,
#          'සිදුවූ': 140,
#          'තීරණය': 140,
#          'වේ': 139,
#          'සිම්බාබ්වේ': 139,
#          'ජීවිතක්ෂට': 138,
#          'කින්': 137,
#          'ජග': 136,
#          'වෙනස්': 136,
#          'Update': 136,
#          'තහනම්': 135,
#          'ත්\u200dරස්ත': 135,
#          'රුසියා': 133,
#          'ඉල්ලයි': 131,
#          'ආරක්ෂක': 131,
#          'පිටියට': 131,
#          'සුළි': 130,
#          'සංඛ්\u200dයාව': 129,
#          'කරන': 129,
#          'යුද': 128,
#          'අදයි': 128,
#          'එයි': 128,
#          'අනතුරකින්': 126,
#          'වීඩියෝ': 126,
#          'තුවාල': 125,
#          'තුන්වන': 125,
#          'හමුවේ': 124,
#          'විදේශ': 124,
#          'පරාජය': 124,
#          'ආර්ථික': 123,
#          'ගත්': 123,
#          'සෞදි': 123,
#          'මිසයිල': 122,
#          'බස්': 122,
#          'ප්\u200dරහාර': 122,
#          'වාර්තා': 121,
#          'ඉවත': 121,
#          'න්\u200dයෂ්ටික': 121,
#          'කෝලි': 121,
#          'කොළඹ': 121,
#          'කාසියේ': 121,
#          'මිය': 120,
#          'බිලියන': 120,
#          'රග්බි': 120,
#          'එළවළු': 120,
#          'මරණ': 119,
#          'කල්': 119,
#          'එන': 119,
#          'සිටි': 118,
#          'ඉල්ලා': 116,
#          'ඕස්ට්\u200dරේලියාව': 116,
#          'ප්\u200dරබල': 115,
#          'ණය': 115,
#          'කොදෙව්වන්': 115,
#          'උණුසුම': 114,
#          'ගැනීමට': 114,
#          'දෙයි': 114,
#          'මෝටර්': 114,
#          'දෙදෙනෙකු': 113,
#          'සාකච්ඡා': 113,
#          'රථ': 111,
#          'සංවර්ධන': 111,
#          'වසරේ': 111,
#          'අලුත': 111,
#          'නවසීලන්ත': 110,
#          'තවදුරටත': 110,
#          'ඉල්ලීම': 110,
#          'ජපාන': 109,
#          'සොයා': 109,
#          'අතුරුදන්': 109,
#          'පාසල්': 109,
#          'මණ්ඩල': 108,
#          'ආදායම': 108,
#          'වෙළඳ': 108,
#          'වැඩ': 108,
#          'ගොවීන්': 108,
#          'ජාතික': 107,
#          'පිතිකරු': 107,
#          'ඕස්ට්\u200dරේලියානු': 106,
#          'නිදහස්': 106,
#          'මුම්බායි': 106,
#          'පොලිස්': 104,
#          'ලොවම': 104,
#          'ඉන්දු': 103,
#          'තරග': 103,
#          'පහළ': 103,
#          'මුදල්': 102,
#          'ලබන': 101,
#          'නුවර': 101,
#          'පුහුණුකරු': 101,
#          'සංචාරක': 100,
#          'ට්\u200dරම්ප්ගේ': 100,
#          'සිරියාවේ': 100,
#          'රාජ්\u200dය': 99,
#          'න්': 98,
#          'කඩුලු': 98,
#          'රුපියල': 97,
#          'මැද': 97,
#          'තීරණාත්මක': 97,
#          'කරන්න': 96,
#          'පිරිසක්': 96,
#          'අමුතු': 96,
#          'ක්\u200dරීඩකයා': 96,
#          'අයිපීඑල්': 96,
#          'තහනමක්': 95,
#          'පුටින්': 95,
#          'පෙර': 95,
#          'තරඟෙන්': 95,
#          'කම්පනක්': 93,
#          'ඇෆ්ගනිස්ථානේ': 93,
#          'තුර්කිය': 93,
#          'ක්\u200dරීඩකය්': 93,
#          'දින': 92,
#          'කිරීමේ': 92,
#          'පියවර': 92,
#          'පන්දුව': 92,
#          'කොරියාවේ': 91,
#          'ප්\u200dරකාශයක්': 91,
#          'දුම්රිය': 91,
#          'ගමන්': 90,
#          'මිලදී': 90,
#          'කුඩා': 90,
#          'එල්ල': 89,
#          'කිරීම': 89,
#          'තැන': 89,
#          'සීම': 88,
#          'යුරෝපා': 88,
#          'දිවයින': 87,
#          'පත්': 87,
#          'හැවිරිදි': 87,
#          'අනුමැති': 87,
#          'සහල': 87,
#          'ට්\u200dරම්ප්ගෙන්': 86,
#          'ජල': 86,
#          'පිළ': 86,
#          'තරගාවලිය': 86,
#          'ජනාධිපති': 85,
#          'සටන': 84,
#          'අවදානමක': 84,
#          'හානි': 84,
#          'රට': 84,
#          'පොල්': 84,
#          'පාකිස්ථාය': 84,
#          'කුසලාය': 84,
#          'සංවිධාන': 83,
#          'හදිසි': 83,
#          'ඕස්ට්\u200dරේලියාවට': 83,
#          'බිරිඳ': 83,
#          'අප්\u200dරිකාවට': 83,
#          'යුරෝපය': 82,
#          'බදු': 82,
#          'ඩොනල්ඩ්': 82,
#          'අරඹයි': 82,
#          'තරඟක්': 82,
#          'තොරතුරු': 81,
#          'ගැනේ': 81,
#          'බාධා': 81,
#          'ශූරතා': 81,
#          'කුසල්': 81,
#          'ට්\u200dරම්ප්ට': 80,
#          'ගන්න': 80,
#          'පැමිණි': 80,
#          'අප්\u200dරිකානු': 80,
#          'දූෂණ': 79,
#          'වෙළඳපොල': 79,
#          'මගී': 79,
#          'යානා': 79,
#          'අවුරුදු': 79,
#          'චෙන්නායි': 79,
#          'වෙනසක': 78,
#          'අවධානය': 78,
#          'හේතුවෙ': 78,
#          'සිරියානු': 78,
#          'වාර්තාව': 78,
#          'වෙන්දේසිය': 78,
#          'තරගාවලියේ': 78,
#          'විරෝධතා': 77,
#          'ෆේස්බුක්': 77,
#          'තවම': 77,
#          'අපනයන': 77,
#          'ඉක්මවයි': 76,
#          'ඕස්ට්\u200dරේලියාවේ': 76,
#          'සහය': 76,
#          'ඉදිරියෙන්': 76,
#          'හෙළි': 76,
#          'යොවුන්': 76,
#          'ඔබාමා': 76,
#          'පිළට': 76,
#          'ප්\u200dරථම': 75,
#          'අත්හදා': 75,
#          'මරාගෙන': 75,
#          'සුළු': 75,
#          'වාහන': 75,
#          'මහේල': 75,
#          'අගනුවර': 74,
#          'අඩු': 74,
#          'මැරෙන': 74,
#          'හොංකොං': 74,
#          'ලැබුණු': 74,
#          'තීරණයක්': 74,
#          'අප්\u200dරිකාව': 74,
#          'කතාව': 74,
#          'ආයෝජන': 74,
#          'ICC': 74,
#          'එළිය': 73,
#          'සංගා': 73,
#          'ප්\u200dරධාන': 72,
#          'පුරා': 72,
#          'රංගන': 72,
#          'බිල්පත': 72,
#          'ජපානේ': 71,
#          'ප්\u200dරතික්ෂේප': 71,
#          'විවෘත': 71,
#          'වැටී': 71,
#          'නිෂ්පාදන': 71,
#          'ක්\u200dරීඩක': 71,
#          'ප්\u200dරහාරයෙන්': 71,
#          'තරඟේදී': 71,
#          'රටවල්': 70,
#          'මාස': 70,
#          'ලැව්': 70,
#          'ඉන්දුනීසියාවේ': 70,
#          'එංගලන්තට': 70,
#          'කුසලායේ': 70,
#          'ජයලලිතා': 69,
#          'මෙරට': 69,
#          'පරදා': 69,
#          'චන්දිමාල්': 69,
#          'පිපිරීකින්': 68,
#          'දමයි': 68,
#          'රථයක්': 68,
#          'ප්\u200dරංශ': 68,
#          'වැටේ': 68,
#          'යාන': 68,
#          'හමුවෙයි': 68,
#          'සභාපති': 68,
#          'මූල්\u200dය': 68,
#          'චෝදනාවක්': 67,
#          'ටොන්': 67,
#          'අලුතම': 67,
#          'ප්\u200dරහාරය': 67,
#          'රැසක්': 66,
#          'සම්බාධක': 66,
#          'සිය': 66,
#          'පාකිස්ථායේ': 66,
#          'බලා': 66,
#          'රුපියල්': 66,
#          'අලෙවි': 66,
#          'කාන්තාවක්': 65,
#          'දුන්': 65,
#          'කතා': 65,
#          'වෙළඳපොළ': 65,
#          'ලීග': 65,
#          'පිටියේ': 65,
#          'ආනයනය': 64,
#          'වෙළඳපොලේ': 64,
#          'හදිසියේ': 64,
#          'වරට': 64,
#          'පහර': 64,
#          'ජීවිත': 64,
#          'වගාව': 64,
#          'දැවී': 64,
#          'දෙනෙකුට': 63,
#          'ප්\u200dරහාරයේ': 63,
#          'ඉන්දුනීසියාව': 63,
#          'මවිත': 63,
#          'හේතුව': 62,
#          'පුහුණු': 62,
#          'ගැටුම': 61,
#          'වාර්තාගත': 61,
#          'කටයුතු': 61,
#          'නිෂ්පාදනය': 61,
#          'ආධාර': 61,
#          'බංග්ලාදේශට': 61,
#          'තම': 61,
#          'සමාජ': 61,
#          'ජොං': 60,
#          'සිර': 60,
#          'අවි': 60,
#          'සමාගම': 60,
#          'යානේ': 60,
#          'අත්හිටුවයි': 60,
#          'සිරියාව': 60,
#          'භාණ්ඩගාර': 60,
#          'කමිටු': 60,
#          'අස්වෙයි': 59,
#          'ලබයි': 59,
#          'බලපෑ්': 59,
#          'තුන්': 59,
#          'සම්බන්ධ': 59,
#          'ජයගනී': 59,
#          'දරුණු': 59,
#          'පූර්ව': 59,
#          'සංගක්කාර': 59,
#          'සාම': 58,
#          'චීනයෙන්': 58,
#          'රජය': 58,
#          'ඉන්ධන': 58,
#          'නොවන': 58,
#          'ආහාර': 58,
#          'නීති': 58,
#          'ඉම්රාන්': 58,
#          'ඉන්දියාවෙන්': 57,
#          'පුද්ගලයා': 57,
#          'හමුව': 57,
#          'සුළඟ': 57,
#          'සේවා': 57,
#          'ආරක්ෂාව': 57,
#          'පාකිස්ථායට': 57,
#          'එක': 57,
#          'තරගාවලියට': 57,
#          'වැඩිම': 56,
#          'ලක්ෂ': 56,
#          'ඇඟවීම': 56,
#          'අතරතුර': 56,
#          'ඊයේ': 56,
#          'පරදී': 56,
#          'සහන': 56,
#          'ඕස්ට්\u200dරේලියා': 56,
#          'පන්දුවට': 56,
#          'කෝටි': 55,
#          'ඇෆ්ගනිස්ථාන': 55,
#          'සංචාරයක': 55,
#          'තැබීමකින්': 55,
#          'ගැටුම්': 55,
#          'ඉදිරි': 55,
#          'අමානුෂික': 55,
#          'වලට': 55,
#          'තිසර': 55,
#          'හි': 54,
#          'පාලක': 54,
#          'ගෙන': 54,
#          'පාකිස්තානට': 54,
#          'ඉරාකේ': 53,
#          'සංක්\u200dරමණිකය්': 53,
#          'වැඩපිළිවෙල': 53,
#          'කණ්ඩාය්': 53,
#          'ඉන්දියා': 53,
#          'සිදුව': 52,
#          'දුරකථන': 52,
#          'ළමය': 52,
#          'මුල්': 52,
#          'රජයේ': 52,
#          'ශතක': 52,
#          'පැය': 51,
#          'පිපිරීක්': 51,
#          'සිටින': 51,
#          'එක්': 51,
#          'මුහුදේ': 51,
#          'වගා': 51,
#          'IS': 51,
#          'යන්න': 51,
#          'පකිස්ථානය': 51,
#          'මිලට': 51,
#          'කුසලායට': 51,
#          'ගත': 50,
#          'සැරසෙයි': 50,
#          'ප්\u200dරාන්ත': 50,
#          'ගැනීම': 50,
#          'යේමයේ': 50,
#          'මරු': 50,
#          'මෙහෙයු්': 50,
#          'කම්පනෙන්': 50,
#          'ලොකු': 50,
#          'දේශීය': 50,
#          'පදක්කම්': 50,
#          'ගාන්ධි': 49,
#          'මාලදිවයින': 49,
#          'ගිවිසුමක්': 49,
#          'අතට': 49,
#          'සමුගනී': 49,
#          'දඬුවම': 49,
#          'මාසයේ': 49,
#          'අප්\u200dරිකා': 49,
#          'මාධ්\u200dය': 48,
#          'බ්\u200dරිතාන්\u200dයයේ': 48,
#          'නිදහස': 48,
#          'පාකිස්තානේ': 48,
#          'පරීක්ෂණ': 48,
#          'දිල්ලිය': 48,
#          'නායකත්ව': 48,
#          'ලෝකය': 48,
#          'වනදා': 48,
#          'ලිංගික': 48,
#          'වැඩේ': 48,
#          'පොහොර': 48,
#          'උද්ධමන': 48,
#          'ශතකක්': 48,
#          'ආසාදිතයන්': 47,
#          'ශක්තිමත්': 47,
#          'අභියෝගයක': 47,
#          'ගින්නකින්': 47,
#          'හෙළිවේ': 47,
#          'අනතුරට': 47,
#          'භාර': 47,
#          'කාන්තාවන්': 47,
#          'ඛාන්': 47,
#          'වීඩියෝව': 47,
#          'පොලී': 47,
#          'අයිසීසී': 47,
#          'වටයට': 47,
#          'අන්': 46,
#          'මුහුදු': 46,
#          'සැලසුම්': 46,
#          'ගින්න': 46,
#          'මණ්ඩලේ': 46,
#          'නායක': 46,
#          'අසභ්\u200dය': 46,
#          'තියුණු': 46,
#          'එක්වෙයි': 46,
#          'හිලරි': 46,
#          'වේග': 46,
#          'ඉදිරියේ': 46,
#          'ලේකම්': 45,
#          'කැලිෆෝනියා': 45,
#          'දා': 45,
#          'එක්වර': 45,
#          'ආර්ථිකය': 45,
#          'සංක්\u200dරමණික': 45,
#          'උළෙල': 45,
#          'අනතුර': 45,
#          'ලංකාෙන්': 45,
#          'දිවි': 45,
#          'මහබැංකු': 45,
#          'තේරීම': 45,
#          'ක්\u200dරීඩකයින්': 45,
#          'විදෙස්': 44,
#          'තබයි': 44,
#          'ප්\u200dරකාශයට': 44,
#          'ප්\u200dරහාරක': 44,
#          'හෙළිවෙයි': 44,
#          'වගකීම': 44,
#          'යාමක': 44,
#          'සංචාරය': 44,
#          'බොරතෙල්': 44,
#          'එපා': 44,
#          'දැරියක': 44,
#          'විදුලි': 44,
#          'කොල්කටා': 44,
#          'කළු': 43,
#          'නේපාල': 43,
#          'තහනම': 43,
#          'වෛරස': 43,
#          'ප්\u200dරංශයේ': 43,
#          'වැසේ': 43,
#          'නීතිය': 43,
#          'ජපානට': 43,
#          'බංග්ලාදේශේ': 43,
#          'සමරයි': 43,
#          'පිලිපීන': 43,
#          'අතරට': 43,
#          'බලාපොරොත්තු': 43,
#          'යුතුයි': 43,
#          'දිල්ලි': 43,
#          'තුර්කි': 43,
#          'දෙන්න': 43,
#          'කැඳවයි': 43,
#          'ඉදිරිය': 43,
#          'බටහිර': 43,
#          'අන්තර්': 43,
#          'උළෙලේ': 43,
#          'දිනූ': 43,
#          'දිනයි': 43,
#          'විශාලත': 42,
#          'සෞඛ්\u200dය': 42,
#          'අධික': 42,
#          'මීළඟ': 42,
#          'තර්ජන': 42,
#          'අත්සන': 42,
#          'නයිජීරියාව': 42,
#          'තැබූ': 42,
#          'සිංහයන්': 42,
#          'වැටෙයි': 42,
#          'දරුව': 42,
#          'ගැනීමේ': 42,
#          'හෙළිකරයි': 42,
#          'T': 42,
#          'ප්\u200dරධානියා': 41,
#          'මුදා': 41,
#          'එක්සත': 41,
#          'මියන්මාරේ': 41,
#          'අවස්ථාව': 41,
#          'සටන්': 41,
#          'බැංකුවෙන්': 41,
#          'පිළිගනී': 41,
#          'ගෑස්': 41,
#          'ඉරාක': 41,
#          'කුමරු': 41,
#          'කාලගුණ': 41,
#          'බැංකුව': 41,
#          'රාජස්ථාන': 41,
#          'අභියස': 41,
#          'උපන්': 41,
#          'සංවේදී': 41,
#          'බිඳ': 41,
#          'ලැබූ': 41,
#          'බැංකු': 41,
#          'මව': 41,
#          'දැමූ': 41,
#          'විශිෂ්ඨ': 41,
#          'ඇරඹෙයි': 41,
#          'කියපු': 41,
#          'සුපර්': 41,
#          'තායිලන්තේ': 40,
#          'දහසක': 40,
#          'බලයි': 40,
#          'තත්ත්වයක්': 40,
#          'මැතිවරණය': 40,
#          'හැකි': 40,
#          'විවාහ': 40,
#          'රහස්': 40,
#          'බසී': 40,
#          'ලක්වෙයි': 40,
#          'බලාපොරොත්තුක්': 40,
#          'වායු': 40,
#          'දුෂණය': 40,
#          'පකිස්ථාන': 40,
#          'සැමි': 40,
#          'ශූරයන්': 40,
#          'වසා': 39,
#          'ඡන්ද': 39,
#          'සියයට': 39,
#          'ලන්ඩන්': 39,
#          'ගිහින්': 39,
#          'කිහිපයක්': 39,
#          'වැසිය': 39,
#          'මංගල': 39,
#          'කඳු': 39,
#          'අපරාධය': 39,
#          'වැඩසටහනක': 39,
#          'බෝල්ට්': 39,
#          'දර්ශක': 39,
#          'රාහු්': 38,
#          'තීන්දුව': 38,
#          'බලය': 38,
#          'දෙකක': 38,
#          'අල්ලයි': 38,
#          'මෙහෙයුක්': 38,
#          'ධුරයට': 38,
#          'උපදෙස': 38,
#          'නතර': 38,
#          'ලක්ෂයක': 38,
#          'ඇගවීම': 38,
#          'සුරූපී': 38,
#          'ජංගම': 38,
#          'සංචාරකයින්': 38,
#          'වේගවත්': 38,
#          'ඇමෙරිකා': 38,
#          'රැකියා': 38,
#          'අදත': 38,
#          'දිවුරුම': 38,
#          'රැගෙන': 38,
#          'පරීක්ෂණයක්': 38,
#          'විනාශ': 38,
#          'අසරණ': 38,
#          'ධීවර': 38,
#          'දරුවා': 38,
#          'ලොවක': 38,
#          'සියල්න්': 38,
#          'අලූත': 38,
#          'හම්බන්තොට': 38,
#          'කඩුලූ': 38,
#          'නේපාලේ': 37,
#          'තරුණියක්': 37,
#          'ලක්වූ': 37,
#          'භාණ්ඩ': 37,
#          'සමුළු': 37,
#          'හමුදව': 37,
#          'සිංගප්පූරු': 37,
#          'අවස්ථාව්': 37,
#          'පිලිපීනේ': 37,
#          'තබා': 37,
#          'ඉන්දියානු': 37,
#          'බද්ද': 37,
#          'මෙවර': 37,
#          'හොඳ': 37,
#          'වසරක': 37,
#          'ජයග්\u200dරහණය': 37,
#          'කිරි': 37,
#          'රබර්': 37,
#          'පිටියෙන්': 37,
#          'පරදයි': 37,
#          'පෙරමුණේ': 37,
#          'හතුරුසිංහ': 37,
#          'මැතිවරණ': 36,
#          'අවසානය': 36,
#          'වලින්': 36,
#          'සැකකරු': 36,
#          'අර්ධ': 36,
#          'මියන්මාර': 36,
#          'කටාර': 36,
#          'අපනයනය': 36,
#          'ප්\u200dරාන්තයේ': 36,
#          'පැරිස්': 36,
#          'නොසිතූ': 36,
#          'සිරුරු': 36,
#          'යුතු': 36,
#          'ඉතිහාසය': 36,
#          'මිලේ': 36,
#          'වර්ෂාවෙන්': 36,
#          'වෙළඳපළ': 36,
#          'කන්නයේ': 36,
#          'දර්ශකේ': 36,
#          'මෙන්ඩිස්': 36,
#          'උප': 35,
#          'ගංවතුර': 35,
#          'මුහුදට': 35,
#          'නවතී': 35,
#          'ඇෆ්ගන්': 35,
#          'ප්\u200dරවර්ධන': 35,
#          'සටනට': 35,
#          'ගං': 35,
#          'රුසියාවේ': 35,
#          'නිවාස': 35,
#          'සබඳතා': 35,
#          'තායි': 35,
#          'පසුගිය': 35,
#          'තොරව': 35,
#          'දියණිය': 35,
#          'බර': 35,
#          'කණ්ඩායක්': 35,
#          'සංචිතට': 35,
#          'පදක්කමක': 35,
#          'දිමුත': 35,
#          'ලසිත්': 35,
#          'සංවිධානෙන්': 34,
#          'සටන්කාමීන්': 34,
#          'නවසීලන්තයේ': 34,
#          'ජර්මනිේ': 34,
#          'ගිවිසුමක': 34,
#          'විරෝධය': 34,
#          'ඉතාලි': 34,
#          'යෝජනා': 34,
#          'ආසියාවේ': 34,
#          'මැලේසියා': 34,
#          'වැටුණු': 34,
#          'කාන්තාවක': 34,
#          'නවතම': 34,
#          'වරාය': 34,
#          'අඩුවෙයි': 34,
#          'පිලේ': 34,
#          'උඩපන්දු': 34,
#          'නඩු': 33,
#          'බ්\u200dරසීලයේ': 33,
#          'රුසියාවෙන්': 33,
#          'අධිකරණ': 33,
#          'ගණන': 33,
#          'එක්වූ': 33,
#          'අර්බුදය': 33,
#          'කැබිනට්': 33,
#          'නාවික': 33,
#          'රජු': 33,
#          'ඊශ්\u200dරායල': 33,
#          'ඉරානේ': 33,
#          'අවම': 33,
#          'අඩුව': 33,
#          'සූදානමක': 33,
#          'නුවරට': 33,
#          'නීතිවිරෝධී': 33,
#          'ප්\u200dරහාරවලින්': 33,
#          'ජනපතිගෙන්': 33,
#          'වැටීක්': 33,
#          'තානාපති': 33,
#          'හොඳම': 33,
#          'හිමි': 33,
#          'සංචාරයට': 33,
#          'බිමට': 33,
#          'පුදුම': 33,
#          'දෙයක්': 33,
#          'අයි': 33,
#          'මිලක්': 33,
#          'ක්\u200dරීඩකයෙක්': 33,
#          'බැඳුම්කර': 33,
#          'ශ්\u200dරේණිගත': 33,
#          'හයිද්\u200dරාබාද්': 33,
#          'ධනංජය': 33,
#          'දෝනි': 33,
#          'දකී': 32,
#          'යෝජනාවක්': 32,
#          'දඬුවම්': 32,
#          'නිල': 32,
#          'සයිබර්': 32,
#          'නිරුවත': 32,
#          'මිනිසා': 32,
#          'තත්ත්වය': 32,
#          'ගමන': 32,
#          'ලබා': 32,
#          'තමිල්නාඩු': 32,
#          'පරාජයෙන්': 32,
#          'හයේ': 32,
#          'අගය': 32,
#          'පැරදුම': 32,
#          'පළමුව': 32,
#          'පොත්': 32,
#          'ප්\u200dරහාරයට': 31,
#          'අමාත්\u200dය': 31,
#          'ලැව්ගිනි': 31,
#          'හෙළිදරව්ක්': 31,
#          'හෙලිකොප්ටර්': 31,
#          'කරන්නැයි': 31,
#          'ඒකාබද්ධ': 31,
#          'හිඟයක': 31,
#          'තොග': 31,
#          'බිම': 31,
#          'ඉරානට': 31,
#          'රහස': 31,
#          'සටනේ': 31,
#          'නැංවීට': 31,
#          'කථා': 31,
#          'තුන්කොන්': 31,
#          'යල': 31,
#          'විස්සේ': 31,
#          'මුරලි': 31,
#          'මළල': 31,
#          'නායකය්': 30,
#          'ගැටුම්වලින්': 30,
#          'සහතික': 30,
#          'රිය': 30,
#          'පුද්ගලයින්': 30,
#          'ප්\u200dරතිචාර': 30,
#          'තලෙයිබාන්': 30,
#          'කුණාටු': 30,
#          'හිම': 30,
#          'සූදානමි': 30,
#          'වියට්නාම': 30,
#          'අරාබි': 30,
#          'පලස්තීන': 30,
#          'දස': 30,
#          'පෙරළී': 30,
#          'ගැටුමකින්': 30,
#          'කිහිපයක': 30,
#          'තාවකාලික': 30,
#          'අයර්ලන්ත': 30,
#          'රතු': 30,
#          'අවසර': 30,
#          'දෙදෙනා': 30,
#          'වරම': 30,
#          'ගොස්': 30,
#          'ප්\u200dරතිපත්ති': 30,
#          'සීනි': 30,
#          'අවලංගු': 30,
#          'පෙරමුණට': 30,
#          'කාන්තාව': 30,
#          'තරුණිය': 30,
#          'නිරුවතින්': 30,
#          'පෙම්වතා': 30,
#          'අපේ': 30,
#          'පළතුර': 30,
#          'දිනු': 30,
#          'දුම්රියක': 29,
#          'ගැටී': 29,
#          'මත්ද්\u200dරව්\u200dය': 29,
#          'සටහන්': 29,
#          'නිකුත්': 29,
#          'කල': 29,
#          'වරදී': 29,
#          'කාබුල්': 29,
#          'ගොඩ': 29,
#          'ඉතාලිේ': 29,
#          'යවයි': 29,
#          'තහවුරු': 29,
#          'තරුව': 29,
#          'සතියේ': 29,
#          'සෙල්ෆි': 29,
#          'කියන': 29,
#          'පරදවා': 29,
#          'වෙනිසියුලාව': 29,
#          'සිහිනය': 29,
#          'ඉතිහාසයේ': 29,
#          'නැති': 29,
#          'අස්වැන්න': 29,
#          'මෙහෙම': 29,
#          'වෙළදපොළ': 29,
#          'ළූණු': 29,
#          'සමුගැනීම': 29,
#          'දඟ': 29,
#          'ධවල': 28,
#          'සැක': 28,
#          'සඳ': 28,
#          'නොහැකි': 28,
#          'සන්නද්ධ': 28,
#          'මෙක්සිකෝේ': 28,
#          'පාර්ලිමේන්තුව': 28,
#          'රාජ්\u200dයයේ': 28,
#          'දරුවෙකු': 28,
#          'තායිලන්ත': 28,
#          'හිස': 28,
#          'අන්තර්ජාල': 28,
#          'මැතිවරණයෙන්': 28,
#          'ගණන්': 28,
#          'පිළිතුරු': 28,
#          'නගරයේ': 28,
#          'අඟවයි': 28,
#          'IMF': 28,
#          'සුබ': 28,
#          'අධිවේගී': 28,
#          'සංශෝධන': 28,
#          'යාත්\u200dරාවක්': 28,
#          'ආයතනය': 28,
#          'අයවැය': 28,
#          'කළඹමින්': 28,
#          'පහරදුන්': 28,
#          'ලියාපදිංචිය': 28,
#          'උඩුයටිකුරු': 28,
#          'පැමිණී': 28,
#          'උසේන්': 28,
#          'බැංගලෝර්': 28,
#          'ටෙනිස්': 28,
#          'ගේල්': 28,
#          'කමිටුක්': 28,
#          'රුපියලේ': 28,
#          'ස්ථාවර': 28,
#          'කුරුඳු': 28,
#          'කිරීම්': 28,
#          'ඉරියව්': 28,
#          'කොවිඩ්': 27,
#          'ජනතාව': 27,
#          'ගෝලීය': 27,
#          'දීර්ඝ': 27,
#          'යැවීමට': 27,
#          'පක්ෂ': 27,
#          'ඔත්තු': 27,
#          'දේශපාලන': 27,
#          'පුද්ගලයන්': 27,
#          'නවතයි': 27,
#          'මුහුණු': 27,
#          'සොයන්න': 27,
#          'අපරාධ': 27,
#          'තුන්දෙනෙකු': 27,
#          'තැනට': 27,
#          'නිව්යෝක්': 27,
#          'දැරිය': 27,
#          'මිසයිලක්': 27,
#          'රෝහල්': 27,
#          'සති': 27,
#          'සංගමයෙන්': 27,
#          'දෙකකි': 27,
#          'කුණාටුෙන්': 27,
#          'කැන්ගරු': 27,
#          'ගණනක්': 27,
#          'තිබූ': 27,
#          'ජලය': 27,
#          'ගිවිසුම': 27,
#          'ඉරණම': 27,
#          'නිවේදනක': 27,
#          'ඊජිප්තු': 27,
#          'දැරියන්': 27,
#          'පෙම්වතිය': 27,
#          'ලිංගිකව': 27,
#          'පහරදෙයි': 27,
#          'ධාවන': 27,
#          'පාරිභෝගික': 27,
#          'බංගලාදේශ': 27,
#          'වීසා': 26,
#          'ලෝකයේ': 26,
#          'අයෙක': 26,
#          'නෞකාවක': 26,
#          'තමිල්නාඩුේ': 26,
#          'ගැටේ': 26,
#          'මාරුතය': 26,
#          'විපක්ෂ': 26,
#          'පොලීසිය': 26,
#          'ප්\u200dරසිද්ධ': 26,
#          'අප්\u200dරිකාවේ': 26,
#          'පෞද්ගලික': 26,
#          'ඉන්දියානුවන්': 26,
#          ...})

# %%
len(vocab)
# Out:
# 18928

# %%
data.shape
# Out:
# (25624, 2)

# %%
tokens = [key for key in vocab if vocab[key] > 10]

# %%
tokens
# Out:
# ['කොරෝනා',
#  'ට්\u200dරම්ප්',
#  'අද',
#  'ජන',
#  'ආර්ථික',
#  'නොබෙල්',
#  'ත්\u200dයාගය',
#  'ඇමරිකාවන්',
#  'දෙදෙනෙකු',
#  'ඉන්දියාව',
#  'ආසාදිතයන්',
#  'ලක්ෂය',
#  'ඉක්මවයි',
#  'කළු',
#  'ජාතිකයෙකු',
#  'ඩොලර',
#  'මිලියනයක',
#  'වන්දි',
#  'ඉල්ලා',
#  'එරෙහි',
#  'නඩු',
#  'නේපාල',
#  'සංචාරක',
#  'ඇමතිට',
#  'උතුරු',
#  'කොරියාව',
#  'ලොව',
#  'විශාලත',
#  'මිසයිල',
#  'ප්\u200dරදර්ශනය',
#  'කරයි',
#  'තායිලන්තේ',
#  'බස්',
#  'රථ',
#  'අනතුරකින්',
#  'මියයයි',
#  'බ්\u200dරසීලයේ',
#  'මරණ',
#  'සාම',
#  'ට්\u200dරම්ප්ගේ',
#  'ඉන්දු',
#  'චීන',
#  'දේශසීමව',
#  'චීනය',
#  'අමතර',
#  'සෙබළු',
#  'චෝදනා',
#  'රුසියාවෙන්',
#  'වාර්තා',
#  'වූ',
#  'වැඩිම',
#  'ආසාදිතයින්',
#  'සංඛ්\u200dයාව',
#  'පැය',
#  'විසි',
#  'හතරේ',
#  'ජනපති',
#  'කියයි',
#  'දකුණු',
#  'කොරියාවේ',
#  'මහල්',
#  'ගොඩනැගිල්ක්',
#  'ගිනි',
#  'ගනී',
#  'රුපියල',
#  'ශක්තිමත්',
#  'වෙයි',
#  'කොවිඩ්',
#  'මුහුණ',
#  'ඉල්ලයි',
#  'යුරෝපය',
#  'ඉහළට',
#  'මැද',
#  'ඇමරිකා',
#  'උප',
#  'උණුසුම',
#  'ජපාන',
#  'රටවල්',
#  'විදෙස්',
#  'ගමන්',
#  'තහනම',
#  'ඉවත්',
#  'ඉරාන',
#  'යළි',
#  'වසා',
#  'දැමේ',
#  'චීනයේ',
#  'රාජ්\u200dය',
#  'ලක්ෂ',
#  'නික්ෙයි',
#  'වීඩියෝ',
#  'වෛද්\u200dය',
#  'සී',
#  'වෛරස',
#  'සොයා',
#  'ගත්',
#  'කාර්ය',
#  'මණ්ඩල',
#  'කට',
#  'රාහු්',
#  'ගාන්ධි',
#  'සමූහ',
#  'මියගිය',
#  'හමුවේ',
#  'ට්\u200dරම්ප්ට',
#  'පතයි',
#  'ප්\u200dරංශයේ',
#  'ගංවතුර',
#  'දෙනෙකු',
#  'අතුරුදන්',
#  'වසර',
#  'නැහැ',
#  'ජොං',
#  'අන්',
#  'ධවල',
#  'ලෝක',
#  'නායකය්',
#  'රැසක්',
#  'තරුණියක',
#  'දූෂණ',
#  'කර',
#  'අධිකරණ',
#  'ප්\u200dරධාන',
#  'පිටුපස',
#  'සැක',
#  'ලබන',
#  'වැසේ',
#  'ස්පාඤ්ඤේ',
#  'අගනුවර',
#  'ජපානේ',
#  'කොටස්',
#  'වෙළඳපොල',
#  'මාධ්\u200dය',
#  'දකී',
#  'ප්\u200dරහාර',
#  'නිම',
#  'වේ',
#  'ජග',
#  'ලේකම්',
#  'ප්\u200dරථම',
#  'කුමාර්',
#  'පාකිස්තාන',
#  'සෞඛ්\u200dය',
#  'සංවිධානෙන්',
#  'මෝදි',
#  'පනතට',
#  'විරෝධතා',
#  'උත්සන්න',
#  'ගුවන',
#  'සමාගමෙ',
#  'මගී',
#  'වෙනසක',
#  'ඕස්ට්\u200dරේලියාවේ',
#  'අනතුරක',
#  'මිලියන',
#  'දේශසීම',
#  'ගැටුම',
#  'නායකයින්',
#  'අවධානය',
#  'ගැටුම්වලින්',
#  'මරුට',
#  'ආදායම',
#  'බදු',
#  'තීන්දුව',
#  'නවසීලන්ත',
#  'අගමැතිය',
#  'බලය',
#  'මුහුදු',
#  'තීරයට',
#  'මුහුදට',
#  'කාන්තාවක්',
#  'පිහි',
#  'ප්\u200dරහාරයට',
#  'හත්දෙනෙකු',
#  'අත්අඩංගුව',
#  'පසු',
#  'බල',
#  'හුවමාරුව',
#  'නායකයා',
#  'සහතික',
#  'රිය',
#  'වීසා',
#  'සහිත',
#  'චීනයෙන්',
#  'සහනයක',
#  'සටන්කාමීන්',
#  'පිපිරීක්',
#  'මසුන්',
#  'සඳ',
#  'මතට',
#  'අවදානම',
#  'බ්\u200dරිතාන්\u200dයයේ',
#  'රාත්\u200dරී',
#  'නවසීලන්තය',
#  'පාලන',
#  'සීම',
#  'මාස',
#  'ඇමරිකාවේ',
#  'ඩොනල්ඩ්',
#  'විෂ',
#  'කරන',
#  'ප්\u200dරහාරයක්',
#  'එල්ල',
#  'කිරීමට',
#  'සැලසුම්',
#  'කළ',
#  'අල්කයිඩා',
#  'ඉන්දියාවදී',
#  'ගත',
#  'වී',
#  'ඇමරිකාව',
#  'හෙට',
#  'දෙවන',
#  'කෝටි',
#  'තුනක',
#  'ජනතාව',
#  'සංවිධාන',
#  'සහය',
#  'අනතුරු',
#  'ඇඟවීම',
#  'අධික',
#  'පිරිසකට',
#  'විදුලිය',
#  'අහිමි',
#  'අගමැති',
#  'හි',
#  'දැවැන්ත',
#  'ගින්න',
#  'පුද්ගලයින්',
#  'ගණන',
#  'දෙකක',
#  'ඕස්ට්\u200dරේලියාවෙන්',
#  'නොවේ',
#  'ලෝකයේ',
#  'සංවර්ධන',
#  'දෙකක්',
#  'සටන',
#  'නවතී',
#  'පාර්ලිමේන්තු',
#  'දෙනෙකුට',
#  'පාලක',
#  'නායකත්වට',
#  'අමාත්\u200dය',
#  'අයිස්',
#  'යයි',
#  'නේපාලේ',
#  'අල්ලයි',
#  'ලැව්ගිනි',
#  'මාලදිවයින',
#  'ආරක්ෂක',
#  'ගිවිසුමක්',
#  'ගෝලීය',
#  'ප්\u200dරතිචාර',
#  'යෝජනාවක්',
#  'සම්මත',
#  'කරගනී',
#  'භූ',
#  'කම්පනක්',
#  'ඇෆ්ගන්',
#  'රජය',
#  'තලේබාන්',
#  'සාකච්ඡා',
#  'ඇරඹේ',
#  'ඉරාකේ',
#  'සිටින',
#  'හමුද',
#  'අඩු',
#  'කෙරේ',
#  'ජාතිකයින්',
#  'දහසක',
#  'තහනමක්',
#  'ලැව්',
#  'අක්කර',
#  'විනාශයි',
#  'ඇෆ්ගනිස්ථාන',
#  'ජනාධිපති',
#  'ඉලක්ක',
#  'කරගෙන',
#  'බෝම්බ',
#  'ප්\u200dරහාරයකින්',
#  'වෙඩි',
#  'තැබීමක්',
#  'තරුණියක්',
#  'ඉන්දියාවෙන්',
#  'වාර්තාගත',
#  'අත්හදා',
#  'බලයි',
#  'සුඩානේ',
#  'නීතිය',
#  'ඉවත',
#  'මධ්\u200dයම',
#  'එංගලන්තේ',
#  'අයෙක',
#  'තුවාල',
#  'මැතිවරණ',
#  'ප්\u200dරවර්ධන',
#  'එක්වූ',
#  'බෝට්ටු',
#  'ඕස්ට්\u200dරේලියානු',
#  'දීර්ඝ',
#  'පැසිෆික්',
#  'සාගරයේ',
#  'සැරසේ',
#  'එන්නත',
#  'තුන්වන',
#  'පරීක්ෂාවට',
#  'ජපානට',
#  'අර්බුදය',
#  'සාකච්ඡාවක',
#  'අවසානය',
#  'වනවිට',
#  'දෙගුණ',
#  'වීමේ',
#  'අවදානමක',
#  'බංග්ලාදේශේ',
#  'පිපිරීකින්',
#  'ජීවිතක්ෂට',
#  'එල්',
#  'පිපිරී',
#  'සිදුවූ',
#  'සුන්බුන්',
#  'ට්\u200dරම්ප්ගෙන්',
#  'ඡන්ද',
#  'වැරදි',
#  'උග්\u200dර',
#  'අතට',
#  'රැගත්',
#  'නෞකාවක',
#  'මෙහෙයුක්',
#  'මීළඟ',
#  'තලෙයිබාන්',
#  'සිරකරුව',
#  'ලක්වූ',
#  'ඉන්ධන',
#  'ගිය',
#  'දින',
#  'ශෝක',
#  'කාලයක්',
#  'ලකුණු',
#  'නවසීලන්තයේ',
#  'ලිහිල්',
#  'කැබිනට්',
#  'සටනට',
#  'තමිල්නාඩුේ',
#  'හඬ',
#  'ගැටේ',
#  'තබයි',
#  'කඩාවැටී',
#  'වෛරස්',
#  'වාර්තාව්',
#  'චන්ඩ',
#  'මාරුතය',
#  'දිවයිනේ',
#  'පුරා',
#  'ජර්මනිේ',
#  'පුටින්',
#  'රුසියා',
#  'නගරයක',
#  'විරෝධතාවක්',
#  'විය',
#  'නොහැකි',
#  'සන්නද්ධ',
#  'ප්\u200dරධානියා',
#  'දිනට',
#  'නාවික',
#  'අභියෝගයක',
#  'ජල',
#  'ගැලීම්',
#  'යැවීමට',
#  'සිර',
#  'දඬුවම්',
#  'හිටපු',
#  'විපක්ෂ',
#  'දුන්',
#  'ප්\u200dරතික්ෂේප',
#  'දිවයින',
#  'වසරේී',
#  'විවෘත',
#  'නිළ',
#  'පොලීසිය',
#  'ප්\u200dරබල',
#  'සුළි',
#  'කුණාටු',
#  'කොංග්\u200dරස්',
#  'පක්ෂ',
#  'නායකත්වෙන්',
#  'ඉවත්වීට',
#  'සැරසෙයි',
#  'කැලිෆෝනියා',
#  'ජාතික',
#  'තත්ත්වයක්',
#  'ප්\u200dරකාශයට',
#  'පත්',
#  'වයස්ගත',
#  'පුද්ගලයා',
#  'යුවළ',
#  'වෙන්දේසි',
#  'පැමිණෙයි',
#  'මණ්ඩලේ',
#  'නැවත',
#  'ගං',
#  'පීඩා',
#  'ජනාධිපතිවරණ',
#  'ප්\u200dරතිඵල',
#  'මුදා',
#  'ගන්න',
#  'සූදානම්',
#  'හිම',
#  'කොරියා',
#  'ඔබාමාගෙන්',
#  'රුසියාවේ',
#  'නායක',
#  'රෝහලේ',
#  'මාලි',
#  'රාජ්\u200dයයට',
#  'නිල',
#  'ඔත්තු',
#  'නිලධාරියෙකු',
#  'කැනඩාේ',
#  'මුදල්',
#  'ඇමති',
#  'අස්වෙයි',
#  'ෆේස්බුක්',
#  'දේශපාලන',
#  'අර්බුදයක්',
#  'පාලනයට',
#  'ස්පාඤ්ඤ',
#  'ප්\u200dරසිද්ධ',
#  'තහනම්',
#  'එක්ව',
#  'කටයුතු',
#  'සූදානමි',
#  'මැතිවරණය',
#  'කල්',
#  'තායිවාන',
#  'ප්\u200dරහාරක',
#  'යානා',
#  'මිලදී',
#  'ගැනීමට',
#  'අසළ',
#  'තෙල්',
#  'රුසියාව',
#  'නිෂ්පාදනය',
#  'අරඹයි',
#  'ගැටළුව',
#  'අභාවප්\u200dරාප්ත',
#  'සමුළුට',
#  'එක්',
#  'නොවන',
#  'හඳුනා',
#  'මෙක්සිකෝේ',
#  'ආගමන',
#  'නිලධාරින්',
#  'යුද්ධේ',
#  'අවි',
#  'සම්බාධක',
#  'කිරීම',
#  'නිදහස',
#  'සමරයි',
#  'වියට්නාම',
#  'ධුරයට',
#  'නුසුදුසු',
#  'ඉඟිය',
#  'නරේන්ද්\u200dර',
#  'පත්වෙයි',
#  'ඊශ්\u200dරායලය',
#  'එක්සත',
#  'අරාබි',
#  'ඓතිහාසික',
#  'ගිවිසුමක',
#  'සියයට',
#  'ආහාර',
#  'න්\u200dයෂ්ටික',
#  'බලාගාර',
#  'අයහපත්',
#  'කාලගුණෙන්',
#  'බලන්න',
#  'පිලිපීන',
#  'ගාසා',
#  'දමයි',
#  'මන්දිර',
#  'පාර්ලිමේන්තුව',
#  'සයිබර්',
#  'හෙළිදරව්ක්',
#  'උපදෙස',
#  'තොරතුරු',
#  'භාණ්ඩ',
#  'ආනයනය',
#  'නතර',
#  'අමාත්\u200dයාංශය',
#  'ආධාර',
#  'සමුළු',
#  'හෝටලය',
#  'ගින්නකින්',
#  'ලක්ෂයක',
#  'තහනමට',
#  'කේරළයේ',
#  'නායයාම',
#  'රෝහලක',
#  'ප්\u200dරහාරයේ',
#  'ඩුබායි',
#  'වෙළඳපොලේ',
#  'එමීර්',
#  'රාජ්\u200dයයේ',
#  'සුපිරි',
#  'වෙළඳ',
#  'සංකීර්ණයක',
#  'පිපිරීෙන්',
#  'නිවාස',
#  'හානි',
#  'රජු',
#  'රට',
#  'හැකි',
#  'නැගෙනහිර',
#  'වෙරළ',
#  'මාරුතයක්',
#  'නාසා',
#  'පෘථිවිට',
#  'ජාත්\u200dයන්තර',
#  'අභ්\u200dයවකාශ',
#  'මත්පැන්',
#  'අප්\u200dරිකාවේ',
#  'නැව්',
#  'කඩා',
#  'වැටී',
#  'ගිවිසුම්',
#  'බී',
#  'පළමු',
#  'මරණය',
#  'ඇෆ්ගනිස්ථානේ',
#  'මරාගෙන',
#  'මැරෙන',
#  'ජනපතිවරණ',
#  'කරගැනීම',
#  'සිය',
#  'හමුදව',
#  'කාර්යාලය',
#  'දිනක',
#  'තවදුරටත',
#  'නුවර',
#  'ඉහළ',
#  'යෑක්',
#  'පුද්ගලයන්',
#  'දෙනා',
#  'අතරට',
#  'අභ්\u200dයාවකාශ',
#  'චෝදනාවක්',
#  'ආයතනයෙන්',
#  'රොබෝ',
#  'නවතයි',
#  'සුනාමි',
#  'ඇගවීම',
#  'ධුරයෙන්',
#  'නෙරපයි',
#  'බංග්ලාදේශට',
#  'වැසි',
#  'රථයක්',
#  'බ්\u200dරිතාන්\u200dයය',
#  'හොංකොං',
#  'මුහුදේ',
#  'යුද',
#  'අභ්\u200dයාසයක',
#  'හෙළිවෙයි',
#  'තරුණ',
#  'තරුණියන්',
#  'ඝාතන',
#  'දා',
#  'වතුරෙන්',
#  'පලස්තීන',
#  'ඊශ්\u200dරායල',
#  'සාමය',
#  'ලංකා',
#  'ඉල්ලීම',
#  'වතුර',
#  'හේතුවෙ',
#  'සමුළුක්',
#  'ඡායාරූප',
#  'මානව',
#  'පරීක්ෂා',
#  'මුහුණු',
#  'වලින්',
#  'හෙලිකොප්ටර්',
#  'ජය',
#  'මහජන',
#  'පක්ෂයට',
#  'නිරුවත',
#  'අසභ්\u200dය',
#  'සමාගම',
#  'හදිසියේ',
#  'තීරණය',
#  'තම',
#  'පුතු',
#  'සුරූපී',
#  'රංගන',
#  'සමුගනී',
#  'පොලිස්',
#  'පහරින්',
#  'සිංගප්පූරු',
#  'සොයන්න',
#  'ශ්\u200dරේෂ්ඨාධිකරණෙන්',
#  'සහාය',
#  'ලන්ඩන්',
#  'ත්\u200dරස්ත',
#  'අදයි',
#  'ඉන්දුනීසියාවේ',
#  'ව්\u200dයාජ',
#  'පෞද්ගලික',
#  'අධිකරණෙන්',
#  'ලැබුණු',
#  'නියෝගය',
#  'ප්\u200dරාන්ත',
#  'ඉන්දියානුවන්',
#  'යාමට',
#  'සිදුව',
#  'මිනිසා',
#  'නොමැති',
#  'ගැල්ෙන්',
#  'අකුණු',
#  'නිදහස්',
#  'උළෙලට',
#  'සියල්',
#  'නෞකා',
#  'ප්\u200dරකාශයක්',
#  'පාකිස්තානේ',
#  'දුම්රියක',
#  'ගැටී',
#  'වැදී',
#  'අපරාධ',
#  'හෙළිවේ',
#  'මත්ද්\u200dරව්\u200dය',
#  'ටොන්',
#  'ආයුධ',
#  'ගැනේ',
#  'සංචාරයක',
#  'මියන්මාරේ',
#  'නාය',
#  'මිය',
#  'අවස්ථාව',
#  'අමාත්\u200dයවරයා',
#  'මවක',
#  'එක්වර',
#  'දරුවෙකු',
#  'හැටි',
#  'කැමරාවක',
#  'සටහන්',
#  'ඉරානේ',
#  'යුරෝපා',
#  'සංගමයේ',
#  'විරෝධය',
#  'ජංගම',
#  'දුරකථන',
#  'කිරීමේ',
#  'ජාතීන්',
#  'තැබීමකින්',
#  'හමුදවට',
#  'සටන්',
#  'නවදිල්ලි',
#  'ආක්\u200dරමණය',
#  'අර්බුදයක',
#  'බැංකුවෙන්',
#  'කතා',
#  'ඊශ්\u200dරායලයෙන්',
#  'සංචාරකයින්',
#  'අභිබව',
#  'ගැටුම්',
#  'අවම',
#  'එකඟතාක්',
#  'නිකුත්',
#  'තීරණයක්',
#  'දෙන',
#  'පිළිගනී',
#  'කරන්න',
#  'ක්\u200dරමවේදය',
#  'කන්ද',
#  'පුපුරයි',
#  'කර්මාන්තය',
#  'පැමිණ',
#  'හමුවීට',
#  'අවස්ථාව්',
#  'තියුණු',
#  'පහරදී',
#  'තුන්දෙනෙකු',
#  'කරන්නැයි',
#  'ගොඩනැගිල්',
#  'තායිලන්ත',
#  'ජනප්\u200dරිය',
#  'සියදිවි',
#  'බොකෝහරාම්',
#  'පොලිසිය',
#  'අතින්',
#  'එරට',
#  'වර්ධන',
#  'ට්\u200dරක්',
#  'තර්ජන',
#  'හමුව',
#  'වේගවත්',
#  'අභිබවා',
#  'තැනට',
#  'වැට',
#  'ජෝර්ජ්',
#  'නිලධාරියා',
#  'සබඳතා',
#  'විරෝධතාකරුව',
#  'තීරණාත්මක',
#  'වසංගත',
#  'ඉදිරි',
#  'දෙක',
#  'උපරිම',
#  'ආර්ථිකය',
#  'හානිය',
#  'දස',
#  'දහස්',
#  'සංඛ්\u200dයාත',
#  'ලබයි',
#  'ඉතාලි',
#  'ප්\u200dරංශ',
#  'පමණක',
#  'භාවිත',
#  'ප්ලාස්ටික්',
#  'සැකකරු',
#  'හෙළා',
#  'පාසලක',
#  'ළමය',
#  'බ්\u200dරසීලය',
#  'මාරාන්තික',
#  'හිස',
#  'කඳුළ',
#  'ගෑස්',
#  'අල්',
#  'නගර',
#  'රැසක',
#  'සාර්ථකව',
#  'යානක',
#  'ජයලලිතා',
#  'භටයන්',
#  'කල',
#  'කණ්ඩාය',
#  'පාසල්',
#  'බලපෑ්',
#  'සජීවී',
#  'දර්ශන',
#  'ලොවම',
#  'හමුවට',
#  'අනතුරට',
#  'පාකිස්ථා',
#  'යානේ',
#  'විරාමක',
#  'අර්ධ',
#  'පරීක්ෂණ',
#  'නීති',
#  'බ්\u200dරිතාන්\u200dය',
#  'භාරය',
#  'ඊශ්\u200dරායලයේ',
#  'අභිරහස්',
#  'මධ්\u200dයස්ථානයක',
#  'කැනඩා',
#  'අන්තර්ජාල',
#  'ඔස්සේ',
#  'සංක්\u200dරමණික',
#  'සේවකයින්',
#  'පිලිපීනට',
#  'සුළඟ',
#  'සීතල',
#  'නිෂ්පාදන',
#  'සමාගමක',
#  'අමතයි',
#  'මියන්මාර',
#  'සාකච්ඡාවක්',
#  'දුම්රිය',
#  'සේවා',
#  'සෞදි',
#  'තුන්',
#  'නංවයි',
#  'අතරතුර',
#  'හමුදවේ',
#  'ඉලක්කය',
#  'වරදී',
#  'පෙරළී',
#  'පස්දෙනෙකු',
#  'ඇමෙරිකා',
#  'දේ',
#  'විදේශීය',
#  'බලාපොරොත්තු',
#  'ජෙට්',
#  'වැටේ',
#  'රැකියා',
#  'රසායනික',
#  'කම්හලක',
#  'පහළට',
#  'හදිසි',
#  'තත්ත්වය',
#  'බිලියන',
#  'කාශ්මීරේ',
#  'ගැටුමකින්',
#  'සාමාජිකය්',
#  'අවසන',
#  'මුම්බායි',
#  'නුවරදී',
#  'කිහිපයක',
#  'යථා',
#  'අවධානයෙන්',
#  'සුඛෝපභෝගී',
#  'සිරියාවේ',
#  'අවතැන්',
#  'වියදම්',
#  'ඉහළම',
#  'මියගොස්',
#  'පිරිසක්',
#  'ඇමෙරිකාේ',
#  'ඉරානෙන්',
#  'නිව්යෝක්',
#  'යෝජනාවට',
#  'අත්සන',
#  'දුර',
#  'නිවසට',
#  'ගිහින්',
#  'නිවස',
#  'හැවිරිදි',
#  'දැරිය',
#  'ජනපතිගේ',
#  'ප්\u200dරහාරයකට',
#  'අයිඑස්',
#  'වගකීම',
#  'භාර',
#  'පෘථිවි',
#  'වෙනස්',
#  'සිදුකළ',
#  'මැතිවරණයෙන්',
#  'මැතිවරණයේ',
#  'ගණන්',
#  'සංවිධානේ',
#  'වටිනා',
#  'පහදයි',
#  'දෙයි',
#  'දඬුවම',
#  'දිල්ලිය',
#  'ගැටුමක්',
#  'එකඟ',
#  'මහලේකම්',
#  'මණ්ඩලෙන්',
#  'සරණාගත',
#  'අඩුව',
#  'බංග්ලාදේශ',
#  'පියා',
#  'කින්',
#  'රටවල',
#  'ඊජිප්තුේ',
#  'සේවය',
#  'තාවකාලික',
#  'සූදානමක',
#  'චෝදනාව',
#  'ඒකාබද්ධ',
#  'යෝජනා',
#  'ගැනීම',
#  'පිළිතුරු',
#  'බැලීම',
#  'සහිතයි',
#  'අදත',
#  'බැලීමක',
#  'ගෙන',
#  'ඕස්ට්\u200dරේලියාව',
#  'වෙන්',
#  'අරාබිය',
#  'වළක',
#  'මිසයිලක්',
#  'අයර්ලන්ත',
#  'වැඩ',
#  'නොකරන',
#  'ෂී',
#  'මලයාසියාව',
#  'රැජින',
#  'ප්\u200dරහාරකයා',
#  'වරද',
#  'කාබුල්',
#  'කලාපයේ',
#  'ඇෆ්ගනිස්ථානට',
#  'බිලියනයක',
#  'කපා',
#  'හරී',
#  'ණය',
#  'අය',
#  'ඔලිම්පික්',
#  'වසයි',
#  'ටෝකියෝ',
#  'ඔස්ට්\u200dරේලියාව',
#  'නගරයේ',
#  'හිඟයක',
#  'ගොඩ',
#  'තරු',
#  'උත්සව',
#  'ගොඩනැගිලි',
#  'රෝහල්',
#  'ඉතාලිේ',
#  'මිනී',
#  'ඊයේ',
#  'සිඩ්නි',
#  'දැමීමට',
#  'පියවර',
#  'ආසියාවේ',
#  'මැලේසියාේ',
#  'සති',
#  'පිටුපසින්',
#  'අඟවයි',
#  'න්',
#  'පැමිණි',
#  'චන්ද්\u200dරිකා',
#  'යවයි',
#  'කඳවුරක',
#  'සිසුන්',
#  'දිවා',
#  'ආහාරය',
#  'නොමැතිව',
#  'මුල්',
#  'තැන',
#  'පාලනය',
#  'වෙනත්',
#  'උළෙල',
#  'සමාව',
#  'පාකිස්ථායේ',
#  'වගා',
#  'දැනුමදීමක්',
#  'ඉදිරියෙන්',
#  'සංගමයෙන්',
#  'දැඩි',
#  'සෙබලූන්',
#  'නුවරට',
#  'දිගු',
#  'නයිජීරියාව',
#  'අලුතින්',
#  'නීතිවිරෝධී',
#  'සංක්\u200dරමණිකය්',
#  'පිටුවහල්',
#  'රොකට්',
#  'කාල',
#  'තහවුරු',
#  'පෙට්\u200dරල්',
#  'මහඇමති',
#  'අරාබියේ',
#  'අත්හිටුවයි',
#  'කිරුළ',
#  'වැඩපිළිවෙල',
#  'අපේක්ෂක',
#  'ඉරාක',
#  'කටාර',
#  'ලක්',
#  'ආසියානු',
#  'වැටීෙන්',
#  'ජින්පින්',
#  'නගරයට',
#  'දිවුරුම',
#  'බ්\u200dරසීල',
#  'දෙකකි',
#  'මැලේසියා',
#  'තත්වය්',
#  'යාන',
#  'තිදෙනෙකු',
#  'පාපන්දු',
#  'තරුව',
#  'රන්',
#  'තොග',
#  'රජ',
#  'කුමරු',
#  'IS',
#  'සමාජ',
#  'උපකරණ',
#  'ඇතැයි',
#  'තුර්කිය',
#  'යුතුයි',
#  'ග්\u200dරීසියේ',
#  'කිහිපයක්',
#  'හමුවූ',
#  'ප්\u200dරාන්තයට',
#  'කන්දක',
#  'හමුවෙයි',
#  'යැවූ',
#  'පිලිපීනේ',
#  'සිරියානු',
#  'ආරක්ෂාව',
#  'තර',
#  'යාත්\u200dරා',
#  'සංචාර',
#  'ගිවිසුමට',
#  'යුක්රේන',
#  'අග්\u200dරාමාත්\u200dයවරයා',
#  'පැමිණෙන',
#  'සරණාගතයන්',
#  'දිල්ලි',
#  'ප්\u200dරහාරවලින්',
#  'තුර්කි',
#  'ජනපතිගෙන්',
#  'වෙළඳපොළ',
#  'වැටීක්',
#  'පෙර',
#  'ක්\u200dරිකට්',
#  'පිළිගැනීම',
#  'මොහොමඞ්',
#  'අපනයනය',
#  'වසරක්',
#  'මැතිවරණයට',
#  'සිවිල්',
#  ...]

# %%
len(tokens)
# Out:
# 2340

# %%
def save_vocabulary(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w', encoding="utf-8")
    file.write(data)
    file.close()

save_vocabulary(tokens, '../static/model/vocabulary.txt')

# %% [markdown]
# ### Dividing the dataset for training and testing

# %%
X = data['Title']
y = data['Label']

# %%
y.value_counts()
# Out:
# Label
# International    11880
# Sport             8928
# Business          4816
# Name: count, dtype: int64

# %%
# Define the mapping dictionary
mapping = {'International': 0, 'Sport': 1, 'Business': 2}

vect_y = y.map(mapping)

vect_y.value_counts()
# Out:
# Label
# 0    11880
# 1     8928
# 2     4816
# Name: count, dtype: int64

# %%
#!pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/77/85/bff3a1e818ec6aa3dd466ff4f4b0a727db9fdb41f2e849747ad902ddbe95/scikit_learn-1.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.3.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from scikit-learn) (1.25.2)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.5.0 from https://files.pythonhosted.org/packages/06/15/e73734f9170b66c6a84a0bd7e03586e87e77404e2eb8e34749fc49fa43f7/scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading scipy-1.11.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
#      ---------------------------------------- 0.0/59.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/59.1 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.1 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/59.1 kB 435.7 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/59.1 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 59.1/59.1 kB 390.9 kB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from scikit-learn) (1.3.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading scikit_learn-1.3.0-cp311-cp311-win_amd64.whl (9.2 MB)
#    ---------------------------------------- 0.0/9.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.2 MB 1.6 MB/s eta 0:00:06
#     --------------------------------------- 0.2/9.2 MB 2.3 MB/s eta 0:00:04
#    -- ------------------------------------- 0.5/9.2 MB 3.9 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/9.2 MB 5.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.5/9.2 MB 6.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.0/9.2 MB 7.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.6/9.2 MB 8.2 MB/s eta 0:00:01
#    ------------- -------------------------- 3.1/9.2 MB 8.6 MB/s eta 0:00:01
#    --------------- ------------------------ 3.6/9.2 MB 8.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.9/9.2 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 4.7/9.2 MB 9.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.2 MB 9.5 MB/s eta 0:00:01
#    ------------------------- -------------- 5.8/9.2 MB 9.7 MB/s eta 0:00:01
#    -------------------------- ------------- 6.2/9.2 MB 9.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.2 MB 9.8 MB/s eta 0:00:01
#    ------------------------------- -------- 7.2/9.2 MB 10.1 MB/s eta 0:00:01
#    --------------------------------- ------ 7.6/9.2 MB 10.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.2/9.2 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.2 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.2/9.2 MB 9.8 MB/s eta 0:00:00
# Downloading scipy-1.11.2-cp311-cp311-win_amd64.whl (44.0 MB)
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/44.0 MB 15.7 MB/s eta 0:00:03
#     --------------------------------------- 1.1/44.0 MB 13.4 MB/s eta 0:00:04
#    - -------------------------------------- 1.6/44.0 MB 13.0 MB/s eta 0:00:04
#    - -------------------------------------- 2.0/44.0 MB 11.6 MB/s eta 0:00:04
#    -- ------------------------------------- 2.6/44.0 MB 12.0 MB/s eta 0:00:04
#    -- ------------------------------------- 3.0/44.0 MB 12.1 MB/s eta 0:00:04
#    --- ------------------------------------ 3.6/44.0 MB 11.5 MB/s eta 0:00:04
#    --- ------------------------------------ 4.1/44.0 MB 11.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.6/44.0 MB 11.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.2/44.0 MB 11.5 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.7/44.0 MB 11.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.2/44.0 MB 11.6 MB/s eta 0:00:04
#    ------ --------------------------------- 6.7/44.0 MB 11.5 MB/s eta 0:00:04
#    ------ --------------------------------- 7.2/44.0 MB 11.6 MB/s eta 0:00:04
#    ------- -------------------------------- 7.8/44.0 MB 11.5 MB/s eta 0:00:04
#    ------- -------------------------------- 8.3/44.0 MB 11.6 MB/s eta 0:00:04
#    ------- -------------------------------- 8.8/44.0 MB 11.7 MB/s eta 0:00:04
#    -------- ------------------------------- 9.3/44.0 MB 11.7 MB/s eta 0:00:03
#    -------- ------------------------------- 9.9/44.0 MB 11.7 MB/s eta 0:00:03
#    --------- ------------------------------ 10.3/44.0 MB 11.5 MB/s eta 0:00:03
#    --------- ------------------------------ 10.9/44.0 MB 11.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.3/44.0 MB 11.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.8/44.0 MB 11.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.4/44.0 MB 11.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.9/44.0 MB 11.5 MB/s eta 0:00:03
#    ------------ --------------------------- 13.4/44.0 MB 11.5 MB/s eta 0:00:03
#    ------------ --------------------------- 13.9/44.0 MB 11.5 MB/s eta 0:00:03
#    ------------- -------------------------- 14.4/44.0 MB 11.5 MB/s eta 0:00:03
#    ------------- -------------------------- 14.9/44.0 MB 11.5 MB/s eta 0:00:03
#    -------------- ------------------------- 15.5/44.0 MB 11.7 MB/s eta 0:00:03
#    -------------- ------------------------- 16.0/44.0 MB 11.5 MB/s eta 0:00:03
#    --------------- ------------------------ 16.5/44.0 MB 11.3 MB/s eta 0:00:03
#    --------------- ------------------------ 17.0/44.0 MB 11.5 MB/s eta 0:00:03
#    --------------- ------------------------ 17.5/44.0 MB 11.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.0/44.0 MB 11.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 18.7/44.0 MB 11.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.1/44.0 MB 11.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.7/44.0 MB 11.3 MB/s eta 0:00:03
#    ------------------ --------------------- 20.2/44.0 MB 11.3 MB/s eta 0:00:03
#    ------------------ --------------------- 20.7/44.0 MB 11.3 MB/s eta 0:00:03
#    ------------------- -------------------- 21.0/44.0 MB 11.1 MB/s eta 0:00:03
#    ------------------- -------------------- 21.6/44.0 MB 11.3 MB/s eta 0:00:02
#    -------------------- ------------------- 22.0/44.0 MB 11.1 MB/s eta 0:00:02
#    -------------------- ------------------- 22.4/44.0 MB 10.9 MB/s eta 0:00:02
#    -------------------- ------------------- 22.9/44.0 MB 10.9 MB/s eta 0:00:02
#    --------------------- ------------------ 23.4/44.0 MB 10.9 MB/s eta 0:00:02
#    --------------------- ------------------ 23.9/44.0 MB 10.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.4/44.0 MB 10.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.9/44.0 MB 10.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 25.5/44.0 MB 11.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 26.1/44.0 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 26.6/44.0 MB 10.9 MB/s eta 0:00:02
#    ------------------------ --------------- 27.1/44.0 MB 10.9 MB/s eta 0:00:02
#    ------------------------- -------------- 27.6/44.0 MB 10.9 MB/s eta 0:00:02
#    ------------------------- -------------- 28.1/44.0 MB 10.9 MB/s eta 0:00:02
#    -------------------------- ------------- 28.7/44.0 MB 11.1 MB/s eta 0:00:02
#    -------------------------- ------------- 29.2/44.0 MB 11.1 MB/s eta 0:00:02
#    --------------------------- ------------ 29.9/44.0 MB 11.1 MB/s eta 0:00:02
#    --------------------------- ------------ 30.5/44.0 MB 11.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 30.9/44.0 MB 11.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.6/44.0 MB 11.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.1/44.0 MB 11.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 32.6/44.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 33.3/44.0 MB 12.1 MB/s eta 0:00:01
#    ------------------------------ --------- 33.9/44.0 MB 12.4 MB/s eta 0:00:01
#    ------------------------------- -------- 34.4/44.0 MB 12.4 MB/s eta 0:00:01
#    ------------------------------- -------- 35.0/44.0 MB 12.4 MB/s eta 0:00:01
#    -------------------------------- ------- 35.5/44.0 MB 12.3 MB/s eta 0:00:01
#    -------------------------------- ------- 36.1/44.0 MB 12.4 MB/s eta 0:00:01
#    --------------------------------- ------ 36.7/44.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------- ------ 37.3/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 37.9/44.0 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.4/44.0 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.0/44.0 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------ --- 39.6/44.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ --- 40.2/44.0 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- -- 40.8/44.0 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- -- 41.3/44.0 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 41.9/44.0 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 42.4/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  43.0/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  43.5/44.0 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  44.0/44.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 44.0/44.0 MB 9.8 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.3.0 scipy-1.11.2 threadpoolctl-3.2.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, vect_y, test_size=0.2)

# %%
# X_train

# %%
# X_test

# %%
# y_train

# %% [markdown]
# ### Vectorization

# %%
def vectorizer(ds, vocabulary):
    vectorized_lst = []
    
    for sentence in ds:
        sentence_lst = np.zeros(len(vocabulary))
        
        for i in range(len(vocabulary)):
            if vocabulary[i] in sentence.split():
                sentence_lst[i] = 1
                
        vectorized_lst.append(sentence_lst)
        
    vectorized_lst_new = np.asarray(vectorized_lst, dtype=np.float32)
    
    return vectorized_lst_new

# %%
vectorized_x_train = vectorizer(X_train, tokens)

# %%
vectorized_x_test = vectorizer(X_test, tokens)

# %%
# vectorized_x_train

# %%
# y_train

# %%
# vectorized_x_test

# %%
# y_test

# %%
y_train.value_counts()
# Out:
# Label
# 0    9450
# 1    7199
# 2    3850
# Name: count, dtype: int64

# %%
plt.pie(np.array([y_train.value_counts()[0], y_train.value_counts()[1], y_train.value_counts()[2]]), labels=['International', 'Sport', 'Business'])
plt.show()

# %% [markdown]
# ### Handling imbalances

# %%
#!pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/a3/9e/fbe60a768502af54563dcb59ca7856f5a8833b3ad5ada658922e1ab09b7f/imbalanced_learn-0.11.0-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.11.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from imbalanced-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from imbalanced-learn) (1.11.2)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from imbalanced-learn) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\6sp\e18-6sp-automatically-categorizing-sinhala-news-items-from-selected-news-sources\env\lib\site-packages (from imbalanced-learn) (3.2.0)
# Downloading imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
#    ---------------------------------------- 0.0/235.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/235.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/235.6 kB ? eta -:--:--
#    ----- --------------------------------- 30.7/235.6 kB 330.3 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/235.6 kB 245.8 kB/s eta 0:00:01
#    --------------- ----------------------- 92.2/235.6 kB 479.1 kB/s eta 0:00:01
#    -------------------------- ----------- 163.8/235.6 kB 756.6 kB/s eta 0:00:01
#    -------------------------------------- 235.6/235.6 kB 850.6 kB/s eta 0:00:00
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.11.0

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
vectorized_x_train_smote, y_train_smote = smote.fit_resample(vectorized_x_train, y_train)
print(vectorized_x_train_smote.shape, y_train_smote.shape)
# Out:
# (28620, 2340) (28620,)

# %%
y_train_smote.value_counts()
# Out:
# Label
# 0    9540
# 1    9540
# 2    9540
# Name: count, dtype: int64

# %%
plt.pie(np.array([y_train_smote.value_counts()[0], y_train_smote.value_counts()[1], y_train_smote.value_counts()[2]]), labels=['International', 'Sport', 'Business'])
plt.show()

# %%
# vectorized_x_train_smote

# %%
# y_train_smote

# %%
# vectorized_x_test

# %%
# y_test

# %% [markdown]
# ## Model Training and Evaluation

# %%
import warnings
warnings.filterwarnings('ignore') # Ignore warning messages

# %%
# from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# def training_scores(y_act, y_pred):
#     print(f'Training Scores:\n\tAccuracy = {accuracy_score(y_act, y_pred)}')
#     print(f'\tPrecision = {precision_score(y_act, y_pred)}')
#     print(f'\tRecall = {recall_score(y_act, y_pred)}')
#     print(f'\tF1-Score = {f1_score(y_act, y_pred)}')
    
# def validation_scores(y_act, y_pred):
#     print(f'Testing Scores:\n\tAccuracy = {accuracy_score(y_act, y_pred)}')
#     print(f'\tPrecision = {precision_score(y_act, y_pred)}')
#     print(f'\tRecall = {recall_score(y_act, y_pred)}')
#     print(f'\tF1-Score = {f1_score(y_act, y_pred)}')

# %%
from sklearn.metrics import accuracy_score

def training_accuracy(y_act, y_pred):
    print(f'Training Scores:\n\tAccuracy = {accuracy_score(y_act, y_pred)}')
    
def validation_accuracy(y_act, y_pred):
    print(f'Testing Scores:\n\tAccuracy = {accuracy_score(y_act, y_pred)}')

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = lr.predict(vectorized_x_train_smote)
y_test_pred = lr.predict(vectorized_x_test)

# training_scores(y_train_smote, y_train_pred)
# validation_scores(y_test, y_test_pred)
training_accuracy(y_train_smote, y_train_pred)
validation_accuracy(y_test, y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.9526205450733752
# Testing Scores:
# 	Accuracy = 0.9227317073170732

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

mnb = MultinomialNB()
mnb.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = mnb.predict(vectorized_x_train_smote)
y_test_pred = mnb.predict(vectorized_x_test)

# training_scores(y_train_smote, y_train_pred)
# validation_scores(y_test, y_test_pred)
training_accuracy(y_train_smote, y_train_pred)
validation_accuracy(y_test, y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.926135569531796
# Testing Scores:
# 	Accuracy = 0.9256585365853659

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = dt.predict(vectorized_x_train_smote)
y_test_pred = dt.predict(vectorized_x_test)

# training_scores(y_train_smote, y_train_pred)
# validation_scores(y_test, y_test_pred)
training_accuracy(y_train_smote, y_train_pred)
validation_accuracy(y_test, y_test_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\6sp\e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources\notebooks\02.model_building.ipynb Cell 92 line 4
#       <a href='vscode-notebook-cell:/c%3A/6sp/e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources/notebooks/02.model_building.ipynb#Y160sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.tree import DecisionTreeClassifier
#       <a href='vscode-notebook-cell:/c%3A/6sp/e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources/notebooks/02.model_building.ipynb#Y160sZmlsZQ%3D%3D?line=2'>3</a> dt = DecisionTreeClassifier()
# ----> <a href='vscode-notebook-cell:/c%3A/6sp/e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources/notebooks/02.model_building.ipynb#Y160sZmlsZQ%3D%3D?line=3'>4</a> dt.fit(vectorized_x_train_smote, y_train_smote)
#       <a href='vscode-notebook-cell:/c%3A/6sp/e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources/notebooks/02.model_building.ipynb#Y160sZmlsZQ%3D%3D?line=5'>6</a> y_train_pred = dt.predict(vectorized_x_train_smote)
#       <a href='vscode-notebook-cell:/c%3A/6sp/e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources/notebooks/02.model_building.ipynb#Y160sZmlsZQ%3D%3D?line=6'>7</a> y_test_pred = dt.predict(vectorized_x_test)
#
# File c:\6sp\e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources\env\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\6sp\e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources\env\Lib\site-packages\sklearn\tree\_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File c:\6sp\e18-6sp-Automatically-categorizing-Sinhala-news-items-from-selected-news-sources\env\Lib\site-packages\sklearn\tree\_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = rf.predict(vectorized_x_train_smote)
y_test_pred = rf.predict(vectorized_x_test)

# training_scores(y_train_smote, y_train_pred)
# validation_scores(y_test, y_test_pred)
training_accuracy(y_train_smote, y_train_pred)
validation_accuracy(y_test, y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.9900529100529101
# Testing Scores:
# 	Accuracy = 0.8790243902439024

# %% [markdown]
# #### Support Vector Machine

# %%
from sklearn.svm import SVC

svm = SVC()
svm.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = svm.predict(vectorized_x_train_smote)
y_test_pred = svm.predict(vectorized_x_test)


# training_scores(y_train_smote, y_train_pred)
# validation_scores(y_test, y_test_pred)
training_accuracy(y_train_smote, y_train_pred)
validation_accuracy(y_test, y_test_pred)
# Out:
# Training Scores:
# 	Accuracy = 0.9679012345679012
# Testing Scores:
# 	Accuracy = 0.9157073170731708

# %%
import pickle

with open('../static/model/model.pickle', 'wb') as file:
    pickle.dump(mnb, file)

# %%
with open('../static/model/new_model.pickle', 'wb') as file:
    pickle.dump(svm, file)
